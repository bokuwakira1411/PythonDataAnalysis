# %%
from github import Github
import datetime
import pandas as pd
import numpy as np
import os
from datetime import datetime

# %%
g = Github('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')
repo = g.get_repo('immich-app/immich')

# %%
pulls = repo.get_pulls(state='all')
pull_data =[]
for pr in pulls:
    pull_info= {
        'Pr_state': pr.state,
        'Created_at': pr.created_at,
        'Updated_at': pr.updated_at,
        'Additions': pr.additions,
        'Commits': pr.commits,
        'Merged_at': pr.merged_at 
    }
    pull_data.append(pull_info)

# %%
pr_df =pd.DataFrame(pull_data)
pr_df.to_csv('pr.csv')

# %%
pr_df
# Out:
#      Pr_state                Created_at                Updated_at  Additions  \
# 0        open 2024-06-08 22:16:00+00:00 2024-06-08 22:16:01+00:00          8
# 1      closed 2024-06-08 19:45:48+00:00 2024-06-08 19:51:37+00:00        854
# 2        open 2024-06-08 18:23:28+00:00 2024-06-08 21:41:06+00:00        133
# 3      closed 2024-06-08 17:01:24+00:00 2024-06-08 17:55:20+00:00          2
# 4      closed 2024-06-08 10:44:16+00:00 2024-06-08 10:50:15+00:00          1
# ...       ...                       ...                       ...        ...
# 4318   closed 2022-02-08 17:24:07+00:00 2024-03-12 15:28:50+00:00        343
# 4319   closed 2022-02-08 05:42:11+00:00 2024-02-13 22:15:20+00:00      10715
# 4320   closed 2022-02-07 02:28:28+00:00 2024-03-09 23:22:33+00:00        133
# 4321   closed 2022-02-06 18:08:06+00:00 2024-03-09 04:16:39+00:00         53
# 4322   closed 2022-02-06 06:07:43+00:00 2024-05-29 17:11:53+00:00        581
#
#       Commits                 Merged_at
# ...

# %%
issues = repo.get_issues(state='all')
issue_data=[]
for issue in issues:
    issue_info = {
        'Created_at': issue.created_at,
        'Closed_at': issue.closed_at,
        'State': issue.state,
        'Labels': [label.name for label in issue.labels],
        'Assignees': [assignee.login for assignee in issue.assignees]
    }
    issue_data.append(issue_info)

# %%
issue_df = pd.DataFrame(issue_data)
issue_df.to_csv('issue.csv')

# %%
issue_df
# Out:
#                     Created_at                 Closed_at   State  \
# 0    2024-06-08 22:16:00+00:00                       NaT    open
# 1    2024-06-08 19:45:48+00:00 2024-06-08 19:51:36+00:00  closed
# 2    2024-06-08 18:23:28+00:00                       NaT    open
# 3    2024-06-08 17:01:24+00:00 2024-06-08 17:55:19+00:00  closed
# 4    2024-06-08 10:44:16+00:00 2024-06-08 10:50:14+00:00  closed
# ...                        ...                       ...     ...
# 7254 2022-02-06 06:37:29+00:00 2022-02-08 06:27:24+00:00  closed
# 7255 2022-02-06 06:37:24+00:00 2022-02-08 03:44:44+00:00  closed
# 7256 2022-02-06 06:37:08+00:00 2022-02-06 06:50:47+00:00  closed
# 7257 2022-02-06 06:07:43+00:00 2022-02-06 06:07:56+00:00  closed
# 7258 2022-02-05 07:04:44+00:00 2022-02-06 06:26:15+00:00  closed
#
#                         Labels       Assignees
# 0     [dependencies, renovate]              []
# 1                    [📱mobile]              []
# ...

# %%
start_date = datetime.datetime(2022, 1,1)
end_date = datetime.datetime(2023,1,1)
commit_data = []
def get_commits():
    commits = repo.get_commits(since=start_date, end=end_date)
    for commit in commits:
        files_changed = [file.filename for file in commit.files]
        files_changed_count = len(files_changed)
        all_checks_passed = all(status == "success" for status in commit.get_combined_status().statuses)
        additions = commit.stats.additions,
        contributor = commit.author.login
        commit_info= {
            'Commit_message': commit.commit.message,
            'Author_email': commit.commit.author.email,
            'Author_name': commit.commit.author.name,
            'Updated at': commit.commit.author.date,
            'Files_changed': files_changed,
            'Files_changed_count': files_changed_count,
            'Contributor': contributor,
            'All_checks_passed': all_checks_passed,
            'Additions': additions 
        }
        commit_data.append(commit_info)
get_commits()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 start_date = datetime.datetime(2022, 1,1)
#       2 end_date = datetime.datetime(2023,1,1)
#       3 commit_data = []
#
# AttributeError: type object 'datetime.datetime' has no attribute 'datetime'

# %%
start_date = datetime.datetime(2023, 2,1)
end_date = datetime.datetime(2024, 1, 1)
get_commits()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 start_date = datetime.datetime(2023, 2,1)
#       2 end_date = datetime.datetime(2024, 1, 1)
# ----> 3 get_commits()
#
# Cell In[15], line 5, in get_commits()
#       4 def get_commits():
# ----> 5     commits = repo.get_commits(since=start_date, end=end_date)
#       6     for commit in commits:
#       7         files_changed = [file.filename for file in commit.files]
#
# TypeError: Repository.get_commits() got an unexpected keyword argument 'end'

# %%
commit_df_tmp = pd.DataFrame(commit_data)
commit_df_tmp.to_csv('commit_data_tmp.csv')

# %%
start_date = datetime.datetime(2024, 2,1)
end_date = datetime.datetime(2024, 7, 6)
get_commits()

# %%
df = pd.DataFrame(commit_data)
df.to_csv('commit_data.csv')

# %%
df['date'] = pd.to_datetime(df['date'], utc=False)
df['date'] = df['date'].dt.tz_localize(None)
df

# %%
df['author'] = df['author'].str.replace(r'[^a-zA-Z\s]', '', regex=True)
df

# %%
bot = np.where(df['author'].str.contains(r'bot'))[0]
df = df.drop(df.index[bot])
df
