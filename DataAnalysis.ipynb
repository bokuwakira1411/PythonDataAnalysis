# %%
import os
import pandas as pd
df = pd.read_csv('C:/Users/Admin/Downloads/commit.csv')
pr_df = pd.read_csv('C:/Users/Admin/Downloads/pr.csv')
issue_df = pd.read_csv('C:/Users/Admin/Downloads/issue.csv')
file_df = pd.read_csv('C:/Users/Admin/Downloads/file_data.csv')
language_df = pd.read_csv('C:/Users/Admin/Downloads/languages.csv')
df_commit_contrib = pd.read_csv('C:/Users/Admin/Downloads/df_commit_contrib.csv')
repo_df = pd.read_csv('C:/Users/Admin/Downloads/repo.csv')

# %%
import numpy as np
import datetime 
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn.objects as so
start = datetime.datetime(2022,2,3)
end = datetime.datetime(2024, 6, 10)

# %% [markdown]
# COMMITS

# %% [markdown]
# Số lượng commit theo ngày

# %%
df['Updated at'] = pd.to_datetime(df['Updated at'])
commit_counts = df.groupby(df['Updated at'].dt.date).size()
commit_counts = commit_counts.reset_index(name = 'Commit count')
commit_counts
# Out:
#      Updated at  Commit count
# 0    2022-02-03             6
# 1    2022-02-04             8
# 2    2022-02-05             1
# 3    2022-02-06             6
# 4    2022-02-07            10
# ..          ...           ...
# 731  2024-06-05            10
# 732  2024-06-06            10
# 733  2024-06-07            11
# 734  2024-06-08            11
# 735  2024-06-09             5
#
# [736 rows x 2 columns]

# %% [markdown]
# Trung bình số lượng từ thêm vào 1 commit

# %%
df['Additions'].sum()/df.shape[0]
# Out:
# 228.43386004514673

# %% [markdown]
# Top 5 commit message dài nhất

# %%
cm_length =[]
for cm in df['Commit_message']:
    cm_length.append(len(cm))
cm_length
df_temp = pd.DataFrame({'Commit message': df['Commit_message'],'Commit_message_length': cm_length})
df_temp.sort_values('Commit_message_length',ascending=False).head(5)
# Out:
#                                          Commit message  Commit_message_length
# 2960  fix(deps): update dependency com.google.guava:...                  33511
# 2963  chore(deps): update @immich/cli (#6412)\n\n[![...                  11601
# 2671  chore(server): Check asset permissions in bulk...                   7576
# 2872  fix(server): Reduce number of bound parameters...                   7097
# 1115  feat(server/web): Initial support for RAF and ...                   6861

# %% [markdown]
# Những từ được sử dụng trong commit message nhiều nhất

# %%
word_counts = {}
for cm in df['Commit_message']:
    words = cm.split()
    for w in words:
        if w in word_counts:
            word_counts[w] += 1
        else:
            word_counts[w] = 1
word_data = []
for word, count in word_counts.items():
    word_info = {
       'Word': word,
       'Count': count
    }
    word_data.append(word_info)
word_df = pd.DataFrame(word_data) 
word_df = word_df.sort_values('Count', ascending =False)
word_df = word_df.reset_index(drop = True)
word_df.head(10)
# Out:
#               Word  Count
# 0                *   9714
# 1               to   2461
# 2  Co-authored-by:   1323
# 3              for   1279
# 4              the   1104
# 5              and   1003
# 6               in    962
# 7           chore:    957
# 8           update    937
# 9             fix:    877

# %% [markdown]
# Những file hay được thay đổi cùng nhau trong 1 lần commit

# %%
df['Files_changed'].value_counts().head(10)
# Out:
# Files_changed
# ['README.md']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              64
# ['cli/src/api/open-api/api.ts', 'cli/src/api/open-api/base.ts', 'cli/src/api/open-api/common.ts', 'cli/src/api/open-api/configuration.ts', 'cli/src/api/open-api/index.ts', 'machine-learning/pyproject.toml', 'mobile/android/fastlane/Fastfile', 'mobile/ios/fastlane/Fastfile', 'mobile/openapi/README.md', 'mobile/pubspec.yaml', 'server/immich-openapi-specs.json', 'server/package-lock.json', 'server/package.json', 'web/src/api/open-api/api.ts', 'web/src/api/open-api/base.ts', 'web/src/api/open-api/common.ts', 'web/src/api/open-api/configuration.ts', 'web/src/api/open-api/index.ts']    48
# ['cli/package-lock.json']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  41
# ['server/package-lock.json']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               31
# ['.github/workflows/docker.yml']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           30
# ['server/Dockerfile']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      27
# ['server/package-lock.json', 'server/package.json']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        27
# ['web/package-lock.json']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  26
# ['.github/workflows/openapi-generator.yml']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                25
# ['renovate.json']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          23
# Name: count, dtype: int64

# %% [markdown]
# Số lượng commit theo contributor

# %% [markdown]
# CONTRIBUTORS

# %% [markdown]
# Số lượng commit theo contributor

# %%
commit_count = pd.DataFrame()
commit_count['Commit count'] = df['Contributor'].value_counts()
commit_count = commit_count.reset_index(names = 'Contributor')
commit_count
# Out:
#          Contributor  Commit count
# 0       alextran1502          1261
# 1            jrasm91           594
# 2      renovate[bot]           357
# 3           mertalev           196
# 4    michelheusschen           177
# ..               ...           ...
# 369          dpantel             1
# 370          opdelta             1
# 371      ishanjain28             1
# 372     davidacampos             1
# 373       GeorgeShao             1
#
# [374 rows x 2 columns]

# %% [markdown]
# Tổng số contributors đã đóng góp cho repo

# %%
df['Contributor'].nunique()
# Out:
# 374

# %% [markdown]
# Người đóng góp nhiều commit nhất và % trên tổng số commit

# %%
max_commits = df['Contributor'].value_counts().head(1)
len(df.index)
percentageContribution = max_commits/len(df.index)
print(percentageContribution)
# Out:
# Contributor
# alextran1502    0.28465
# Name: count, dtype: float64

# %% [markdown]
# Thời gian hoạt động của các contributor

# %%
df['Updated at'] = pd.to_datetime(df['Updated at'])
time_activity = df.groupby('Contributor')['Updated at'].agg(['min', 'max'])
print(time_activity)
# Out:
#                             min                 max
# Contributor
# 3urobeat    2023-11-22 12:49:01 2023-11-22 12:49:01
# 416c616e    2023-06-23 16:12:11 2023-06-23 16:12:11
# 8gb         2023-12-05 02:07:20 2023-12-05 02:07:20
# A-wels      2024-01-17 14:43:41 2024-01-17 14:43:41
# Aegeontis   2024-03-15 20:11:28 2024-03-15 20:11:28
# ...                         ...                 ...
# xpwmaosldk  2022-06-22 05:23:35 2023-07-14 13:20:04
# yparitcher  2024-04-15 18:24:13 2024-04-15 18:24:13
# zackpollard 2022-06-06 02:12:12 2024-06-07 15:01:41
# zeyadtamimi 2023-03-27 00:38:23 2023-03-27 00:38:23
# zkhan93     2022-10-17 18:04:17 2023-06-18 03:49:19
#
# [374 rows x 2 columns]

# %% [markdown]
# Top 10 người commit nhiều nhất

# %%
commit_count.head(10)
# Out:
#        Contributor  Commit count
# 0     alextran1502          1261
# 1          jrasm91           594
# 2    renovate[bot]           357
# 3         mertalev           196
# 4  michelheusschen           177
# 5         martabal           153
# 6  shenlong-tanwen           100
# 7   danieldietzler            97
# 8       martyfuhry            90
# 9           bo0tzz            88

# %%
commit_count = pd.DataFrame()
commit_count['Commit count'] = df['Contributor'].value_counts().head(10)
commit_count = commit_count.reset_index(names = 'Contributor')

# %%
total_commits = commit_count['Commit count'].sum()
others_commits = df.shape[0] - total_commits
new_row = pd.DataFrame({'Contributor': 'others', 
                        'Commit count': [others_commits],
                        })
commit_count = pd.concat([commit_count, new_row], ignore_index=True)

# %%
commit_count['Percentage_contrib'] = commit_count['Commit count']/df.shape[0]

# %%
commit_count
# Out:
#         Contributor  Commit count  Percentage_contrib
# 0      alextran1502          1261            0.284650
# 1           jrasm91           594            0.134086
# 2     renovate[bot]           357            0.080587
# 3          mertalev           196            0.044244
# 4   michelheusschen           177            0.039955
# 5          martabal           153            0.034537
# 6   shenlong-tanwen           100            0.022573
# 7    danieldietzler            97            0.021896
# 8        martyfuhry            90            0.020316
# 9            bo0tzz            88            0.019865
# 10           others          1317            0.297291

# %% [markdown]
# Top 5 contributor có tổng số files thay đổi lớn nhất

# %%
result = df.groupby('Contributor')['Files_changed_count'].sum().reset_index()
result.sort_values('Files_changed_count',ascending=False).head(5)
# Out:
#          Contributor  Files_changed_count
# 126     alextran1502                11548
# 233          jrasm91                10359
# 160   danieldietzler                 1643
# 267         mertalev                 1523
# 269  michelheusschen                 1353

# %% [markdown]
# Top 5 contributor thay đổi nhiều file nhất trong 1 lần

# %%
df.sort_values('Files_changed_count', ascending = False).head(5)
# Out:
#          Contributor                                     Commit_message  \
# 1608         jrasm91  refactor(server)*: tsconfigs (#2689)\n\n* refa...
# 4216         jrasm91                       chore: bump open-api (#9522)
# 3700         jrasm91              chore: migrate database files (#8126)
# 4263         jrasm91       chore: gitignore open api docs/tests (#9643)
# 3681  danieldietzler  chore(server): use absolute import paths (#808...
#
#                                           Author_email      Author_name  \
# 1608                                 jrasm91@gmail.com  Jason Rasmussen
# 4216                                 jrasm91@gmail.com  Jason Rasmussen
# 3700                                 jrasm91@gmail.com  Jason Rasmussen
# 4263                                 jrasm91@gmail.com  Jason Rasmussen
# 3681  36593685+danieldietzler@users.noreply.github.com  Daniel Dietzler
#
#               Updated at                                      Files_changed  \
# 1608 2023-06-08 15:01:07  ['.github/workflows/test.yml', 'docker/docker-...
# 4216 2024-05-15 21:52:52  ['mobile/openapi/.openapi-generator/VERSION', ...
# 3700 2024-03-20 21:02:51  ['.github/workflows/test.yml', 'docs/docs/deve...
# 4263 2024-05-21 15:35:20  ['.gitattributes', '.gitignore', 'mobile/opena...
# 3681 2024-03-20 18:32:04  ['.vscode/settings.json', 'server/.eslintrc.js...
#
#       Files_changed_count  All_checks_passed  Additions
# 1608                  300              False        209
# 4216                  300               True        437
# 3700                  300               True        358
# 4263                  300               True          4
# 3681                  300               True       1946

# %% [markdown]
# Top 5 người có nhiều từ nhất thêm nhất trong 1 lần commit

# %%
df.sort_values('Additions', ascending = False).head(5)
# Out:
#        Contributor                                     Commit_message  \
# 4401       weblate  chore: update translations (#10003)\n\n* chore...
# 665   alextran1502  feat(app) add documentation site template (#87...
# 3161     benmccann    chore: remove axios dependency from CLI (#6888)
# 1794         etnoy  feat(cli) Add new CLI (#3066)\n\n* Add new cli...
# 1845  alextran1502  chore(web): Update to Svelte 4 (#3196)\n\n* tr...
#
#                                    Author_email         Author_name  \
# 4401                         hosted@weblate.org         Weblate bot
# 665                     alex.tran1502@gmail.com                Alex
# 3161  322311+benmccann@users.noreply.github.com          Ben McCann
# 1794                      jonathan@jogenfors.se  Jonathan Jogenfors
# 1845                    alex.tran1502@gmail.com                Alex
#
#               Updated at                                      Files_changed  \
# 4401 2024-06-06 17:20:41  ['web/src/lib/constants.ts', 'web/src/lib/i18n...
# 665  2022-10-28 02:38:26  ['documentation/.gitignore', 'documentation/RE...
# 3161 2024-02-05 19:29:00  ['cli/package-lock.json', 'cli/package.json', ...
# 1794 2023-07-06 14:37:47  ['.github/workflows/test.yml', 'cli/.editorcon...
# 1845 2023-07-16 01:13:04  ['.github/workflows/test.yml', 'web/package-lo...
#
#       Files_changed_count  All_checks_passed  Additions
# 4401                   32               True      24245
# 665                    56               True      22826
# 3161                  218               True      22789
# 1794                   53              False      21349
# 1845                   17              False      20695

# %% [markdown]
# top 5 người có số lần all checks passed cao nhất và tỉ lệ all checks passed/ số lần commit

# %%
commit_count = df['Contributor'].value_counts()

# %%
top_all_checks_passed = df[df["All_checks_passed"]]
top_all_checks_passed = top_all_checks_passed['Contributor'].value_counts()
top_all_checks_passed.sort_values(ascending=False).head(5)
# Out:
# Contributor
# alextran1502       1006
# jrasm91             334
# renovate[bot]       264
# michelheusschen     146
# mertalev            125
# Name: count, dtype: int64

# %%
df_temp = pd.merge(top_all_checks_passed, commit_count, on="Contributor", how="inner")
df_temp = df_temp.rename(columns = {'count_x':'Acp count', 'count_y':'Commit count'})
df_temp['Scale'] = df_temp['Acp count']/df_temp['Commit count']
df_temp.head(10)
# Out:
#                  Acp count  Commit count     Scale
# Contributor
# alextran1502          1006          1261  0.797780
# jrasm91                334           594  0.562290
# renovate[bot]          264           357  0.739496
# michelheusschen        146           177  0.824859
# mertalev               125           196  0.637755
# martabal                85           153  0.555556
# martyfuhry              81            90  0.900000
# bo0tzz                  69            88  0.784091
# matthinc                58            59  0.983051
# danieldietzler          55            97  0.567010

# %% [markdown]
# Tỷ lệ files thay đổi của các contributor so với tỷ lệ all checks passed

# %%
total_files_changed = df.groupby('Contributor')['Files_changed_count'].sum()
total_checks_passed = df.groupby('Contributor')['All_checks_passed'].sum()
total_checks_passed/total_files_changed
# Out:
# Contributor
# 3urobeat       0.000000
# 416c616e       0.000000
# 8gb            0.000000
# A-wels         1.000000
# Aegeontis      1.000000
#                  ...
# xpwmaosldk     0.040000
# yparitcher     0.500000
# zackpollard    0.089744
# zeyadtamimi    1.000000
# zkhan93        0.048780
# Length: 374, dtype: float64

# %% [markdown]
# top 5 đuôi email nhiều người dùng nhất

# %%
df['email_types'] = df['Author_email'].str.extract(r'@([\w\.-]+)', expand=False)
df['email_types'].value_counts().head(5)
# Out:
# email_types
# gmail.com                   2178
# users.noreply.github.com    1718
# bo0tzz.me                     85
# jogenfors.se                  62
# posteo.de                     59
# Name: count, dtype: int64

# %% [markdown]
# Người hoạt động đều đặn nhất- người có thời gian đóng góp dài nhất

# %%
commit_contrib = df['Contributor'].value_counts()
commit_contrib.reset_index('Contributor')
# Out:
#          Contributor  count
# 0       alextran1502   1261
# 1            jrasm91    594
# 2      renovate[bot]    357
# 3           mertalev    196
# 4    michelheusschen    177
# ..               ...    ...
# 369          dpantel      1
# 370          opdelta      1
# 371      ishanjain28      1
# 372     davidacampos      1
# 373       GeorgeShao      1
#
# [374 rows x 2 columns]

# %%
time_activity = pd.merge(time_activity, commit_contrib, on="Contributor", how="inner")
time_activity = time_activity.reset_index('Contributor')
time_activity['duration'] = time_activity['max'] - time_activity['min']
time_activity = time_activity.sort_values('duration', ascending=False)
longest_contributor = time_activity.iloc[0]
longest_contributor
# Out:
# Contributor           alextran1502
# min            2022-02-03 15:56:28
# max            2024-06-08 19:51:36
# count                         1261
# duration         856 days 03:55:08
# Name: 126, dtype: object

# %%
time_activity['time_act/commits'] = time_activity['duration']/time_activity['count']
time_activity.sort_values('count', ascending=False).head(10)
# Out:
#          Contributor                 min                 max  count  \
# 126     alextran1502 2022-02-03 15:56:28 2024-06-08 19:51:36   1261
# 233          jrasm91 2022-10-28 18:57:52 2024-06-06 14:09:42    594
# 313    renovate[bot] 2023-06-16 15:22:52 2024-06-06 12:15:39    357
# 267         mertalev 2023-05-22 02:11:26 2024-06-08 17:55:19    196
# 269  michelheusschen 2023-02-09 16:08:19 2024-06-08 09:57:46    177
# 262         martabal 2023-05-17 14:20:32 2024-05-29 19:11:00    153
# 328  shenlong-tanwen 2023-07-22 04:56:49 2024-05-14 19:07:31    100
# 160   danieldietzler 2023-08-25 17:44:52 2024-06-07 19:52:40     97
# 263       martyfuhry 2023-01-27 05:16:28 2024-04-25 04:30:32     90
# 147           bo0tzz 2022-06-27 14:14:32 2024-05-24 20:06:08     88
#
#              duration          time_act/commits
# 126 856 days 03:55:08 0 days 16:17:41.782712133
# 233 586 days 19:11:50 0 days 23:42:32.710437710
# 313 355 days 20:52:47 0 days 23:55:26.518207282
# 267 383 days 15:43:53 1 days 22:58:41.596938775
# 269 484 days 17:49:27 2 days 17:43:40.152542372
# 262 378 days 04:50:28 2 days 11:19:32.732026143
# 328 297 days 14:10:42    2 days 23:25:18.420000
# 160 287 days 02:07:48 2 days 23:01:56.164948453
# 263 453 days 23:14:04 5 days 01:03:29.377777777
# 147 697 days 05:51:36           7 days 22:09:27

# %% [markdown]
# Số lượng contributor tăng lên theo ngày

# %%
time_activity['Month'] = time_activity['min'].dt.strftime('%Y')
Contributor_counts_by_month = time_activity.groupby('Month')['Contributor'].nunique()

# %%
time_activity = time_activity.sort_values('min', ascending = True)

# %%
df_temp = pd.DataFrame()
df_temp['Contributor'] = time_activity['Contributor']
df_temp['Date'] = time_activity['min'].dt.date
df_temp = df_temp.reset_index(drop = True)

# %%
df_temp = df_temp.value_counts('Date', ascending=True)
df_temp = pd.DataFrame(df_temp)
df_temp = df_temp.rename(columns = {'count':'Number of contributor'})
df_temp = df_temp.reset_index('Date')

# %%
df_temp['Month'] = pd.to_datetime(df_temp['Date']).dt.strftime('%m-%Y')
df_temp['Year']= pd.to_datetime(df_temp['Date']).dt.strftime('%Y')
df_temp = df_temp.sort_values('Date', ascending=True)

# %%
contrib_df = df_temp.copy()
contrib_df = contrib_df.reset_index(drop=True)

# %%
contrib_df
# Out:
#            Date  Number of contributor    Month  Year
# 0    2022-02-03                      1  02-2022  2022
# 1    2022-02-06                      1  02-2022  2022
# 2    2022-02-13                      1  02-2022  2022
# 3    2022-04-05                      2  04-2022  2022
# 4    2022-05-18                      1  05-2022  2022
# ..          ...                    ...      ...   ...
# 254  2024-05-30                      1  05-2024  2024
# 255  2024-06-02                      2  06-2024  2024
# 256  2024-06-04                      1  06-2024  2024
# 257  2024-06-06                      2  06-2024  2024
# 258  2024-06-08                      2  06-2024  2024
#
# [259 rows x 4 columns]

# %%
for i in range((len(df_temp) - 1)):
    contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# ...
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\2042395795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contrib_df['Number of contributor'].loc[i + 1] += contrib_df['Number of contributor'].loc[i]

# %%
i = 0
for i in range(len(commit_counts) - 1):
    commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
commit_counts = commit_counts.rename(columns = {'Updated at': 'Date'})
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# ...
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5312\3781053142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commit_counts['Commit count'].loc[i + 1] += commit_counts['Commit count'].loc[i]

# %%
commit_counts.dtypes
# Out:
# Date            object
# Commit count     int64
# dtype: object

# %%
contrib_df.dtypes
# Out:
# Date                     object
# Number of contributor     int64
# Month                    object
# Year                     object
# dtype: object

# %%
contrib_df
# Out:
#            Date  Number of contributor    Month  Year
# 0    2022-02-03                      1  02-2022  2022
# 1    2022-02-06                      2  02-2022  2022
# 2    2022-02-13                      3  02-2022  2022
# 3    2022-04-05                      5  04-2022  2022
# 4    2022-05-18                      6  05-2022  2022
# ..          ...                    ...      ...   ...
# 254  2024-05-30                    367  05-2024  2024
# 255  2024-06-02                    369  06-2024  2024
# 256  2024-06-04                    370  06-2024  2024
# 257  2024-06-06                    372  06-2024  2024
# 258  2024-06-08                    374  06-2024  2024
#
# [259 rows x 4 columns]

# %%
contrib_df['Date'] = pd.to_datetime(contrib_df['Date'])
commit_counts['Date'] = pd.to_datetime(commit_counts['Date'])

# %%
date_commit_contrib = commit_counts[commit_counts['Date'].isin(contrib_df['Date'])]
df_commit_contrib = pd.merge(date_commit_contrib, contrib_df, on="Date", how="inner")
df_commit_contrib
# Out:
#           Date  Commit count  Number of contributor    Month  Year
# 0   2022-02-03             6                      1  02-2022  2022
# 1   2022-02-06            21                      2  02-2022  2022
# 2   2022-02-13            53                      3  02-2022  2022
# 3   2022-04-05           139                      5  04-2022  2022
# 4   2022-05-18           158                      6  05-2022  2022
# ..         ...           ...                    ...      ...   ...
# 254 2024-05-30          4360                    367  05-2024  2024
# 255 2024-06-02          4371                    369  06-2024  2024
# 256 2024-06-04          4383                    370  06-2024  2024
# 257 2024-06-06          4403                    372  06-2024  2024
# 258 2024-06-08          4425                    374  06-2024  2024
#
# [259 rows x 5 columns]

# %%
df_commit_contrib.to_csv('C:/Users/Admin/Downloads/df_commit_contrib.csv', index=False)

# %% [markdown]
# ISSUES

# %% [markdown]
# Tổng số issues đã được mở và đóng góp trong repo này:

# %%
issue_df.shape[0]
# Out:
# 3038

# %%
issue_df
# Out:
#             Author  Comment user           Created_at            Closed_at  \
# 0     alextran1502           NaN  2022-02-05 07:04:44  2022-02-06 06:26:15
# 1     alextran1502           NaN  2022-02-06 06:37:08  2022-02-06 06:50:47
# 2     alextran1502  alextran1502  2022-02-06 06:37:24  2022-02-08 03:44:44
# 3     alextran1502  alextran1502  2022-02-06 06:37:29  2022-02-08 06:27:24
# 4     alextran1502           NaN  2022-02-06 06:57:52  2022-02-07 02:32:09
# ...            ...           ...                  ...                  ...
# 3033     Mubelotix      mmomjian  2024-06-14 15:21:48  2024-06-14 15:25:11
# 3034      seanmuth           NaN  2024-06-14 15:53:39  2024-06-14 15:55:07
# 3035      arnar-th        bo0tzz  2024-06-14 18:32:00  2024-06-14 21:26:48
# 3036  manuelcortez           NaN  2024-06-14 22:39:28                  NaN
# 3037      eygraber           NaN  2024-06-14 23:52:27  2024-06-15 00:56:58
#
#        State           Labels         Assignees
# 0     closed      ['feature']  ['alextran1502']
# 1     closed               []                []
# 2     closed  ['enhancement']                []
# 3     closed  ['enhancement']                []
# 4     closed  ['enhancement']                []
# ...      ...              ...               ...
# 3033  closed               []                []
# 3034  closed               []                []
# 3035  closed               []                []
# 3036    open               []                []
# 3037  closed               []                []
#
# [3038 rows x 7 columns]

# %%
issue_df = issue_df.sort_values('Created_at', ascending=True)

# %%
df_temp = pd.to_datetime(issue_df['Created_at']).dt.date
df_temp = df_temp.value_counts()
df_temp = df_temp.reset_index(name='Issues')
df_temp = df_temp.sort_values('Created_at', ascending=True)
df_temp.reset_index(drop=True)
# Out:
#      Created_at  Issues
# 0    2022-02-05       1
# 1    2022-02-06       5
# 2    2022-02-07       1
# 3    2022-02-08       1
# 4    2022-02-09       1
# ..          ...     ...
# 710  2024-06-10       3
# 711  2024-06-11      32
# 712  2024-06-12      24
# 713  2024-06-13      23
# 714  2024-06-14      17
#
# [715 rows x 2 columns]

# %%
issue_df['State'].value_counts()
# Out:
# State
# closed    2629
# open       409
# Name: count, dtype: int64

# %%
issue_df.dtypes
# Out:
# Author          object
# Comment user    object
# Created_at      object
# Closed_at       object
# State           object
# Labels          object
# Assignees       object
# dtype: object

# %%
issue_df['Closed_at'] = pd.to_datetime(issue_df['Closed_at'], utc= False)
issue_df['Created_at'] = pd.to_datetime(issue_df['Created_at'], utc=False)

# %% [markdown]
# Thời gian trung bình để một issue được giải quyết

# %%
issue_df['duration'] = pd.to_datetime(issue_df['Closed_at'])-pd.to_datetime(issue_df['Created_at'])
print(issue_df['duration'].mean())
# Out:
# 28 days 03:44:42.919360974

# %%
issue_df['State'].value_counts()
# Out:
# State
# closed    2629
# open       409
# Name: count, dtype: int64

# %% [markdown]
# PULL REQUEST

# %% [markdown]
# Tổng số pull request đã được tạo ra

# %%
pr_df.shape[0]
# Out:
# 4418

# %% [markdown]
# Tổng số pull request theo ngày

# %%
df_temp = pd.to_datetime(pr_df['Created_at']).dt.date
df_temp = df_temp.value_counts()
df_temp = df_temp.reset_index(name='pr')
df_temp = df_temp.sort_values('Created_at', ascending=True)
df_temp.reset_index(drop=True)
# Out:
#      Created_at  pr
# 0    2022-02-06   2
# 1    2022-02-07   1
# 2    2022-02-08   2
# 3    2022-02-09   1
# 4    2022-02-10   1
# ..          ...  ..
# 744  2024-06-09   5
# 745  2024-06-10  19
# 746  2024-06-11  32
# 747  2024-06-12  24
# 748  2024-06-13  10
#
# [749 rows x 2 columns]

# %%
pr_df
# Out:
#              Author         Reviewer Pr_state           Created_at  \
# 0      alextran1502              NaN   closed  2022-02-06 06:07:43
# 1           schklom              NaN   closed  2022-02-06 18:08:06
# 2      alextran1502              NaN   closed  2022-02-07 02:28:28
# 3      alextran1502              NaN   closed  2022-02-08 05:42:11
# 4      alextran1502              NaN   closed  2022-02-08 17:24:07
# ...             ...              ...      ...                  ...
# 4413    zackpollard           bo0tzz   closed  2024-06-13 11:13:55
# 4414   alextran1502          jrasm91     open  2024-06-13 12:33:47
# 4415    zackpollard          jrasm91   closed  2024-06-13 12:38:18
# 4416       waclaw66  michelheusschen     open  2024-06-13 12:48:13
# 4417  richard-salam              NaN     open  2024-06-13 13:31:14
#
#                Updated_at  Additions  Commits            Merged_at
# 0     2024-05-29 17:11:53        581       14  2022-02-06 06:07:56
# 1     2024-03-09 04:16:39         53        2  2022-02-06 19:06:01
# 2     2024-03-09 23:22:33        133        3  2022-02-07 02:31:32
# 3     2024-02-13 22:15:20      10715        2  2022-02-08 05:42:35
# 4     2024-03-12 15:28:50        343        2  2022-02-08 17:24:49
# ...                   ...        ...      ...                  ...
# 4413  2024-06-13 11:37:43          7        2  2024-06-13 11:37:15
# 4414  2024-06-13 13:18:29         36        4                  NaN
# 4415  2024-06-13 12:44:07          0        1  2024-06-13 12:44:06
# 4416  2024-06-13 13:41:07        102        1                  NaN
# 4417  2024-06-13 13:31:29          8        1                  NaN
#
# [4418 rows x 8 columns]

# %%
pr_df.dtypes
# Out:
# Author        object
# Reviewer      object
# Pr_state      object
# Created_at    object
# Updated_at    object
# Additions      int64
# Commits        int64
# Merged_at     object
# dtype: object

# %%
rej_prs = pr_df[(pr_df['Merged_at'].isnull()) & (pr_df['Pr_state'] == 'closed')].shape[0]
rej_prs
# Out:
# 514

# %%
open_prs = pr_df[(pr_df['Merged_at'].isnull()) & (pr_df['Pr_state'] == 'open')].shape[0]
open_prs
# Out:
# 48

# %% [markdown]
# Số lượng pull request đã được merge

# %%
mer_prs = pr_df.shape[0]-rej_prs-open_prs
mer_prs
# Out:
# 3856

# %% [markdown]
# Tỷ lệ pull request đã bị từ chối và được merge

# %%
rej_prs/mer_prs
# Out:
# 0.133298755186722

# %% [markdown]
# Top 10 người tạo nhiều pull request nhất

# %%
pr_df.value_counts('Author').head(10)
# Out:
# Author
# alextran1502       718
# jrasm91            631
# renovate[bot]      459
# mertalev           215
# michelheusschen    193
# martabal           177
# shenlong-tanwen    115
# martyfuhry         107
# danieldietzler     103
# fyfrey             103
# Name: count, dtype: int64

# %%
pr_df
# Out:
#              Author         Reviewer Pr_state           Created_at  \
# 0      alextran1502              NaN   closed  2022-02-06 06:07:43
# 1           schklom              NaN   closed  2022-02-06 18:08:06
# 2      alextran1502              NaN   closed  2022-02-07 02:28:28
# 3      alextran1502              NaN   closed  2022-02-08 05:42:11
# 4      alextran1502              NaN   closed  2022-02-08 17:24:07
# ...             ...              ...      ...                  ...
# 4413    zackpollard           bo0tzz   closed  2024-06-13 11:13:55
# 4414   alextran1502          jrasm91     open  2024-06-13 12:33:47
# 4415    zackpollard          jrasm91   closed  2024-06-13 12:38:18
# 4416       waclaw66  michelheusschen     open  2024-06-13 12:48:13
# 4417  richard-salam              NaN     open  2024-06-13 13:31:14
#
#                Updated_at  Additions  Commits            Merged_at
# 0     2024-05-29 17:11:53        581       14  2022-02-06 06:07:56
# 1     2024-03-09 04:16:39         53        2  2022-02-06 19:06:01
# 2     2024-03-09 23:22:33        133        3  2022-02-07 02:31:32
# 3     2024-02-13 22:15:20      10715        2  2022-02-08 05:42:35
# 4     2024-03-12 15:28:50        343        2  2022-02-08 17:24:49
# ...                   ...        ...      ...                  ...
# 4413  2024-06-13 11:37:43          7        2  2024-06-13 11:37:15
# 4414  2024-06-13 13:18:29         36        4                  NaN
# 4415  2024-06-13 12:44:07          0        1  2024-06-13 12:44:06
# 4416  2024-06-13 13:41:07        102        1                  NaN
# 4417  2024-06-13 13:31:29          8        1                  NaN
#
# [4418 rows x 8 columns]

# %%
pr_df['Date'] = pd.to_datetime(pr_df['Updated_at']).dt.strftime('%d-%m-%Y')
df_temp['Commit count'] = pr_df['Commits']

# %%
result = pr_df.groupby('Date').agg(
    pull_request_count = ('Updated_at', 'size'),
    total_commit_count = ('Commits', 'sum'),
    total_additions = ('Additions','sum')
)

# %%
result
# Out:
#             pull_request_count  total_commit_count  total_additions
# Date
# 01-01-2024                  20                  38             6799
# 01-02-2023                   6                  54             7336
# 01-02-2024                   5                 114             1761
# 01-03-2023                   8                  17              543
# 01-03-2024                   6                  39              913
# ...                        ...                 ...              ...
# 31-08-2022                   4                  25              178
# 31-08-2023                   2                   4              149
# 31-10-2022                   2                  10              100
# 31-10-2023                   8                  32             1042
# 31-12-2022                   1                   1                2
#
# [713 rows x 3 columns]

# %%
prs = result['pull_request_count'].sum()
commits = result['total_commit_count'].sum()
additions = result['total_additions'].sum()
p1 = commits/prs
p2= additions/commits
p3 = additions/prs
print(f'Tỷ lệ commit/pull request: {p1}')
print(f'Tỉ lệ addition/commit: {p2}')
print(f'Tỷ lệ addition/pull request:{p3}')
# Out:
# Tỷ lệ commit/pull request: 4.292213671344499
# Tỉ lệ addition/commit: 67.359225860887
# Tỷ lệ addition/pull request:289.1201901312811

# %% [markdown]
# LANGUAGES

# %% [markdown]
# Ngôn ngữ lập trình được sử dụng

# %%
total_lines = language_df['lines'].sum()
language_df['percentage(%)'] = language_df['lines']*100/total_lines

# %%
language_df
# Out:
#        language    lines  percentage(%)
# 0    TypeScript  2128711      44.800170
# 1          Dart  1478766      31.121636
# 2        Svelte   895829      18.853330
# 3        Python   105702       2.224570
# 4         Swift    29812       0.627414
# 5        Kotlin    28373       0.597129
# 6    JavaScript    22833       0.480536
# 7         Shell    14322       0.301416
# 8      Mustache    12571       0.264565
# 9           C++     9834       0.206963
# 10   Dockerfile     7148       0.150435
# 11         Ruby     5989       0.126043
# 12          HCL     5231       0.110090
# 13          CSS     3091       0.065052
# 14         HTML     1958       0.041207
# 15     Makefile     1361       0.028643
# 16  Objective-C       38       0.000800

# %% [markdown]
# FILES

# %% [markdown]
# Tổng số lượng các file của repo

# %%
file_df.shape[0]
# Out:
# 2481

# %% [markdown]
# Tổng kích thước các file của repo

# %%
total_size = file_df['Size'].sum()
total_size
# Out:
# 100048647

# %% [markdown]
# Kích thước trung bình của các files

# %%
total_size/file_df.shape[0]
# Out:
# 40325.93591293833

# %% [markdown]
# File có kích thước lớn nhất

# %%
file_df.sort_values('Size', ascending=False).head(1)
# Out:
#                                                  Path     Size
# 1184  docs/docs/features/img/moblie-smart-serach.webp  5150416

# %% [markdown]
# Phân tích tăng trưởng repo

# %% [markdown]
# Số lượng commit và contributor theo thời gian

# %%
df_temp = df.copy()
df_temp['Date'] = pd.to_datetime(df['Updated at']).dt.date

# %%
df_commit_contrib
# Out:
#      level_0       Date  Commit count  Number of contributor    Month  Year
# 0          0 2022-02-03             6                      1  02-2022  2022
# 1          3 2022-02-06            21                      2  02-2022  2022
# 2         10 2022-02-13            53                      3  02-2022  2022
# 3         35 2022-04-05           139                      5  04-2022  2022
# 4         44 2022-05-18           158                      6  05-2022  2022
# ..       ...        ...           ...                    ...      ...   ...
# 254      725 2024-05-30          4360                    367  05-2024  2024
# 255      728 2024-06-02          4371                    369  06-2024  2024
# 256      730 2024-06-04          4383                    370  06-2024  2024
# 257      732 2024-06-06          4403                    372  06-2024  2024
# 258      734 2024-06-08          4425                    374  06-2024  2024
#
# [259 rows x 6 columns]

# %%
pr_df['Date'] = pd.to_datetime(pr_df['Created_at']).dt.date
df_temp = pr_df.value_counts('Date')
df_temp = df_temp.reset_index(name = 'Prs')
df_temp.sort_values('Date', ascending=True)
# Out:
#            Date  Prs
# 537  2022-02-06    2
# 709  2022-02-07    1
# 628  2022-02-08    2
# 646  2022-02-09    1
# 640  2022-02-10    1
# ..          ...  ...
# 314  2024-06-09    5
# 21   2024-06-10   19
# 1    2024-06-11   32
# 11   2024-06-12   24
# 122  2024-06-13   10
#
# [749 rows x 2 columns]

# %%
issue_df['Date'] = pd.to_datetime(issue_df['Created_at']).dt.date
df_temp = issue_df.value_counts('Date')
df_temp = df_temp.reset_index(name = 'Issues')
df_temp.sort_values('Date', ascending=True)
# Out:
#            Date  Issues
# 714  2022-02-05       1
# 223  2022-02-06       5
# 573  2022-02-07       1
# 572  2022-02-08       1
# 569  2022-02-09       1
# ..          ...     ...
# 347  2024-06-10       3
# 0    2024-06-11      32
# 1    2024-06-12      24
# 2    2024-06-13      23
# 6    2024-06-14      17
#
# [715 rows x 2 columns]

# %%
repo_df = repo_df.drop(columns = 'releases')

# %%
repo_df
# Out:
#                       date    stars  forks
# 0      2022-02-06 06:51:16      1.0    NaN
# 1      2022-02-06 06:57:45      2.0    NaN
# 2      2022-02-06 07:06:13      3.0    NaN
# 3      2022-02-06 07:26:44      4.0    NaN
# 4      2022-02-06 07:34:32      5.0    NaN
# ...                    ...      ...    ...
# 38789  2024-06-15 13:39:33  37039.0    NaN
# 38790  2024-06-15 13:41:34  37040.0    NaN
# 38791  2024-06-15 13:43:36  37041.0    NaN
# 38792  2024-06-15 13:44:27  37042.0    NaN
# 38793  2024-06-15 13:51:55  37043.0    NaN
#
# [38794 rows x 3 columns]

# %%
repo_df[repo_df['forks'].notnull()]
# Out:
#                       date  stars   forks
# 65     2022-02-06 17:45:07    NaN     1.0
# 76     2022-02-06 19:48:11    NaN     2.0
# 104    2022-02-07 01:29:47    NaN     3.0
# 114    2022-02-07 03:28:50    NaN     4.0
# 245    2022-02-10 10:38:52    NaN     5.0
# ...                    ...    ...     ...
# 38734  2024-06-15 09:04:20    NaN  1801.0
# 38751  2024-06-15 11:49:49    NaN  1802.0
# 38753  2024-06-15 11:49:53    NaN  1803.0
# 38777  2024-06-15 12:55:51    NaN  1804.0
# 38783  2024-06-15 13:05:06    NaN  1805.0
#
# [1804 rows x 3 columns]
