# %%
from github import Github
import datetime
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv(os.path.join('commit.csv'))
pr_df = pd.read_csv(os.path.join('pr.csv'))
issue_df = pd.read_csv(os.path.join('issue.csv'))

# %%
g = Github('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')
repo = g.get_repo('immich-app/immich')

# %%
pulls = repo.get_pulls(state='all')
pull_data =[]
for pr in pulls:
    pull_info= {
        'Pr_state': pr.state,
        'Created_at': pr.created_at,
        'Updated_at': pr.updated_at,
        'Additions': pr.additions,
        'Commits': pr.commits,
        'Merged_at': pr.merged_at 
    }
    pull_data.append(pull_info)

# %%
pr_df =pd.DataFrame(pull_data)
pr_df.to_csv('pr_raw_data.csv', index=False)

# %%
pr_df
# Out:
#      Pr_state                Created_at                Updated_at  Additions  \
# 0        open 2024-06-10 10:38:14+00:00 2024-06-10 10:48:47+00:00          2
# 1        open 2024-06-09 21:48:28+00:00 2024-06-10 00:26:35+00:00         66
# 2      closed 2024-06-09 19:07:24+00:00 2024-06-09 19:18:02+00:00         39
# 3      closed 2024-06-09 17:43:42+00:00 2024-06-09 19:48:47+00:00          3
# 4      closed 2024-06-09 16:30:27+00:00 2024-06-09 19:18:41+00:00          0
# ...       ...                       ...                       ...        ...
# 4324   closed 2022-02-08 17:24:07+00:00 2024-03-12 15:28:50+00:00        343
# 4325   closed 2022-02-08 05:42:11+00:00 2024-02-13 22:15:20+00:00      10715
# 4326   closed 2022-02-07 02:28:28+00:00 2024-03-09 23:22:33+00:00        133
# 4327   closed 2022-02-06 18:08:06+00:00 2024-03-09 04:16:39+00:00         53
# 4328   closed 2022-02-06 06:07:43+00:00 2024-05-29 17:11:53+00:00        581
#
#       Commits                 Merged_at
# 0           1                       NaT
# 1           1                       NaT
# 2           1 2024-06-09 19:18:02+00:00
# 3           1                       NaT
# 4           1 2024-06-09 19:18:41+00:00
# ...       ...                       ...
# 4324        2 2022-02-08 17:24:49+00:00
# 4325        2 2022-02-08 05:42:35+00:00
# 4326        3 2022-02-07 02:31:32+00:00
# 4327        2 2022-02-06 19:06:01+00:00
# 4328       14 2022-02-06 06:07:56+00:00
#
# [4329 rows x 6 columns]

# %%
issues = repo.get_issues(state='all')
issue_data=[]
for issue in issues:
    issue_info = {
        'Created_at': issue.created_at,
        'Closed_at': issue.closed_at,
        'State': issue.state,
        'Labels': [label.name for label in issue.labels],
        'Assignees': [assignee.login for assignee in issue.assignees]
    }
    issue_data.append(issue_info)

# %%
issue_df = pd.DataFrame(issue_data)
issue_df.to_csv('issue_raw_data.csv',index=False)

# %%
issue_df
# Out:
#                     Created_at                 Closed_at   State  \
# 0    2024-06-10 11:58:48+00:00                       NaT    open
# 1    2024-06-10 10:38:14+00:00                       NaT    open
# 2    2024-06-10 09:03:16+00:00 2024-06-10 09:09:21+00:00  closed
# 3    2024-06-09 21:48:28+00:00                       NaT    open
# 4    2024-06-09 19:07:24+00:00 2024-06-09 19:18:02+00:00  closed
# ...                        ...                       ...     ...
# 7264 2022-02-06 06:37:29+00:00 2022-02-08 06:27:24+00:00  closed
# 7265 2022-02-06 06:37:24+00:00 2022-02-08 03:44:44+00:00  closed
# 7266 2022-02-06 06:37:08+00:00 2022-02-06 06:50:47+00:00  closed
# 7267 2022-02-06 06:07:43+00:00 2022-02-06 06:07:56+00:00  closed
# 7268 2022-02-05 07:04:44+00:00 2022-02-06 06:26:15+00:00  closed
#
#                               Labels       Assignees
# 0                                 []              []
# 1     [dependencies, github_actions]              []
# 2                                 []              []
# 3                          [📱mobile]              []
# 4                   [github_actions]              []
# ...                              ...             ...
# 7264                   [enhancement]              []
# 7265                   [enhancement]              []
# 7266                              []              []
# 7267                              []              []
# 7268                       [feature]  [alextran1502]
#
# [7269 rows x 5 columns]

# %%
start_date = datetime.datetime(2022, 1,1)
end_date = datetime.datetime(2023,1,1)
commit_data = []
def get_commits():
    commits = repo.get_commits(since=start_date, until=end_date)
    for commit in commits:
        files_changed = [file.filename for file in commit.files]
        files_changed_count = len(files_changed)
        all_checks_passed = all(status == "success" for status in commit.get_combined_status().statuses)
        additions = commit.stats.additions,
        contributor = commit.author
        commit_info= {
            'Contributor': contributor,
            'Commit_message': commit.commit.message,
            'Author_email': commit.commit.author.email,
            'Author_name': commit.commit.author.name,
            'Updated at': commit.commit.author.date,
            'Files_changed': files_changed,
            'Files_changed_count': files_changed_count,
            'All_checks_passed': all_checks_passed,
            'Additions': additions 
        }
        commit_data.append(commit_info)
get_commits()

# %%
start_date = datetime.datetime(2023, 2,1)
end_date = datetime.datetime(2024, 1, 1)
get_commits()

# %%
df = pd.DataFrame(commit_data)
df
# Out:
#                           Contributor  \
# 0          NamedUser(login="jrasm91")
# 1             NamedUser(login="bt90")
# 2          NamedUser(login="jrasm91")
# 3        NamedUser(login="vedhavyas")
# 4          NamedUser(login="Emalton")
# ...                               ...
# 2988  NamedUser(login="alextran1502")
# 2989       NamedUser(login="jrasm91")
# 2990       NamedUser(login="jrasm91")
# 2991       NamedUser(login="jrasm91")
# 2992  NamedUser(login="alextran1502")
#
#                                          Commit_message  \
# 0                   fix(web): pick deleted user (#1237)
# 1     feat(deployment): Consistent container names (...
# 2     refactor(server): imports and repository token...
# 3                           fix nginx conf file (#1229)
# 4                        Docs: Github -> GitHub (#1221)
# ...                                                 ...
# 2988  chore(server): openapi generation for Duplicat...
# 2989  refactor!: port env (#9559)\n\nrefactor: port env
# 2990        refactor(server): new version check (#9555)
# 2991  refactor!: LOG_LEVEL => IMMICH_LOG_LEVEL (#955...
# 2992  chore(web): light theme text color improvement...
#
#                         Author_email           Author_name  \
# 0                  jrasm91@gmail.com       Jason Rasmussen
# 1            btom1990@googlemail.com                  bt90
# 2                  jrasm91@gmail.com       Jason Rasmussen
# 3     vedhavyas.singareddi@gmail.com  Vedhavyas Singareddi
# 4              emaltonator@gmail.com                John P
# ...                              ...                   ...
# 2988         alex.tran1502@gmail.com                  Alex
# 2989               jrasm91@gmail.com       Jason Rasmussen
# 2990               jrasm91@gmail.com       Jason Rasmussen
# 2991               jrasm91@gmail.com       Jason Rasmussen
# 2992         alex.tran1502@gmail.com                  Alex
#
#                     Updated at  \
# 0    2022-12-31 03:30:48+00:00
# 1    2022-12-30 16:30:28+00:00
# 2    2022-12-30 13:22:06+00:00
# 3    2022-12-30 11:12:24+00:00
# 4    2022-12-30 04:45:25+00:00
# ...                        ...
# 2988 2024-05-17 17:05:23+00:00
# 2989 2024-05-17 16:59:05+00:00
# 2990 2024-05-17 16:22:39+00:00
# 2991 2024-05-17 15:44:22+00:00
# 2992 2024-05-17 15:05:59+00:00
#
#                                           Files_changed  Files_changed_count  \
# 0     [web/src/lib/components/album-page/user-select...                    1
# 1     [docker/docker-compose.dev.yml, docker/docker-...                    3
# 2     [server/apps/cli/src/app.module.ts, server/app...                   81
# 3                                    [nginx/nginx.conf]                    1
# 4     [docs/docs/overview/help.md, docs/docs/overvie...                    3
# ...                                                 ...                  ...
# 2988  [mobile/openapi/.openapi-generator/FILES, mobi...                    9
# 2989  [docs/docs/install/environment-variables.md, e...                    6
# 2990  [server/src/constants.ts, server/src/controlle...                   16
# 2991  [docs/docs/features/ml-hardware-acceleration.m...                    6
# 2992                                  [web/src/app.css]                    1
#
#       All_checks_passed Additions
# 0                  True      (2,)
# 1                  True     (12,)
# 2                  True    (130,)
# 3                  True      (4,)
# 4                  True      (4,)
# ...                 ...       ...
# 2988               True    (203,)
# 2989               True     (13,)
# 2990               True    (257,)
# 2991               True      (9,)
# 2992               True      (1,)
#
# [2993 rows x 9 columns]

# %%
start_date = '2024-05-17 15:06:00+00:00'
start_date = datetime.datetime.fromisoformat(start_date.replace('Z', '+00:00'))
end_date = datetime.datetime(2024, 7, 6)
commit_data2 = get_commits()

# %%
commit_data2

# %%
data_temp = pd.DataFrame(commit_data2)

# %%
data_temp
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
start_date = datetime.datetime(2024, 2,1)
end_date = datetime.datetime(2024, 7, 6)
commit_data2 = get_commits()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 3
#       1 start_date = datetime.datetime(2024, 2,1,17)
#       2 end_date = datetime.datetime(2024, 7, 6)
# ----> 3 commit_data2 = get_commits()
#
# Cell In[39], line 9, in get_commits()
#       7 files_changed = [file.filename for file in commit.files]
#       8 files_changed_count = len(files_changed)
# ----> 9 all_checks_passed = all(status == "success" for status in commit.get_combined_status().statuses)
#      10 additions = commit.stats.additions,
#      11 contributor = commit.author
#
# File ~/.python/current/lib/python3.10/site-packages/github/Commit.py:223, in Commit.get_combined_status(self)
#     219 def get_combined_status(self) -> CommitCombinedStatus:
#     220     """
#     221     :calls: `GET /repos/{owner}/{repo}/commits/{ref}/status/ <http://docs.github.com/en/rest/reference/repos#statuses>`_
#     222     """
# --> 223     headers, data = self._requester.requestJsonAndCheck("GET", f"{self.url}/status")
#     224     return github.CommitCombinedStatus.CommitCombinedStatus(self._requester, headers, data, completed=True)
#
# File ~/.python/current/lib/python3.10/site-packages/github/Requester.py:548, in Requester.requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     540 def requestJsonAndCheck(
#     541     self,
#     542     verb: str,
#    (...)
#     546     input: Optional[Any] = None,
#     547 ) -> Tuple[Dict[str, Any], Any]:
# --> 548     return self.__check(*self.requestJson(verb, url, parameters, headers, input, self.__customConnection(url)))
#
# File ~/.python/current/lib/python3.10/site-packages/github/Requester.py:713, in Requester.requestJson(self, verb, url, parameters, headers, input, cnx)
#     710 def encode(input: Any) -> Tuple[str, str]:
#     711     return "application/json", json.dumps(input)
# --> 713 return self.__requestEncode(cnx, verb, url, parameters, headers, input, encode)
#
# File ~/.python/current/lib/python3.10/site-packages/github/Requester.py:810, in Requester.__requestEncode(self, cnx, verb, url, parameters, requestHeaders, input, encode)
#     806     requestHeaders["Content-Type"], encoded_input = encode(input)
#     808 self.NEW_DEBUG_FRAME(requestHeaders)
# --> 810 status, responseHeaders, output = self.__requestRaw(cnx, verb, url, requestHeaders, encoded_input)
#     812 if Consts.headerRateRemaining in responseHeaders and Consts.headerRateLimit in responseHeaders:
#     813     self.rate_limiting = (
#     814         # ints expected but sometimes floats returned: https://github.com/PyGithub/PyGithub/pull/2697
#     815         int(float(responseHeaders[Consts.headerRateRemaining])),
#     816         int(float(responseHeaders[Consts.headerRateLimit])),
#     817     )
#
# File ~/.python/current/lib/python3.10/site-packages/github/Requester.py:844, in Requester.__requestRaw(self, cnx, verb, url, requestHeaders, input)
#     842     cnx = self.__createConnection()
#     843 cnx.request(verb, url, input, requestHeaders)
# --> 844 response = cnx.getresponse()
#     846 status = response.status
#     847 responseHeaders = {k.lower(): v for k, v in response.getheaders()}
#
# File ~/.python/current/lib/python3.10/site-packages/github/Requester.py:196, in HTTPSRequestsConnectionClass.getresponse(self)
#     194 verb = getattr(self.session, self.verb.lower())
#     195 url = f"{self.protocol}://{self.host}:{self.port}{self.url}"
# --> 196 r = verb(
#     197     url,
#     198     headers=self.headers,
#     199     data=self.input,
#     200     timeout=self.timeout,
#     201     verify=self.verify,
#     202     allow_redirects=False,
#     203 )
#     204 return RequestsResponse(r)
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.local/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/.python/current/lib/python3.10/site-packages/urllib3/connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 response_conn = conn if not release_conn else None
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#     807 clean_exit = True
#
# File ~/.python/current/lib/python3.10/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/.python/current/lib/python3.10/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File ~/.python/current/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~/.python/current/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/.python/current/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/.python/current/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/.python/current/lib/python3.10/ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.python/current/lib/python3.10/ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(commit_data)
df.to_csv('commit_raw_data.csv', index=False)

# %% [markdown]
# Xử lý phần Commit Data

# %%
df['Contributor'] = df['Contributor'].str.extract(r'NamedUser\(login="([^"]+)"\)')
df

# %%
df['Updated at'] = pd.to_datetime(df['Updated at'], utc=False)
df['Updated at'] = df['Updated at'].dt.tz_localize(None)

# %%
df['Author_name'] = df['Author_name'].str.replace(r'[^a-zA-Z\s]', '', regex=True)
df
# Out:
#                                          Commit_message  \
# 0                   fix(web): pick deleted user (#1237)
# 1     feat(deployment): Consistent container names (...
# 2     refactor(server): imports and repository token...
# 3                           fix nginx conf file (#1229)
# 4                        Docs: Github -> GitHub (#1221)
# ...                                                 ...
# 4006  feat(web): improved album view UI & album card...
# 4007                  chore: simplify API build (#6841)
# 4008  fix(web): Admin Settings banner/scrolling issu...
# 4009  docs: provide details on storage engine album ...
# 4010            docs(ml): hardware acceleration (#6821)
#
#                                       Author_email           Author_name  \
# 0                                jrasm91@gmail.com       Jason Rasmussen
# 1                          btom1990@googlemail.com                    bt
# 2                                jrasm91@gmail.com       Jason Rasmussen
# 3                   vedhavyas.singareddi@gmail.com  Vedhavyas Singareddi
# 4                            emaltonator@gmail.com                John P
# ...                                            ...                   ...
# 4006  66187991+azroberts8@users.noreply.github.com        Andrew Roberts
# 4007     322311+benmccann@users.noreply.github.com            Ben McCann
# 4008  66187991+azroberts8@users.noreply.github.com        Andrew Roberts
# 4009    50788000+mmomjian@users.noreply.github.com              mmomjian
# 4010   101130780+mertalev@users.noreply.github.com                  Mert
#
#               Updated at                                      Files_changed  \
# 0    2022-12-31 03:30:48  ['web/src/lib/components/album-page/user-selec...
# 1    2022-12-30 16:30:28  ['docker/docker-compose.dev.yml', 'docker/dock...
# 2    2022-12-30 13:22:06  ['server/apps/cli/src/app.module.ts', 'server/...
# 3    2022-12-30 11:12:24                               ['nginx/nginx.conf']
# 4    2022-12-30 04:45:25  ['docs/docs/overview/help.md', 'docs/docs/over...
# ...                  ...                                                ...
# 4006 2024-02-02 02:50:14  ['web/src/lib/components/album-page/album-card...
# 4007 2024-02-01 22:55:21  ['open-api/typescript-sdk/package.json', 'open...
# 4008 2024-02-01 21:05:30  ['web/src/routes/admin/system-settings/+page.s...
# 4009 2024-02-01 03:28:30        ['docs/docs/partials/_storage-template.md']
# 4010 2024-02-01 01:12:57  ['docker/hwaccel.ml.yml', 'docker/hwaccel.tran...
#
#       Files_changed_count  Contributor  All_checks_passed  Additions
# 0                       1          NaN               True          2
# 1                       3          NaN               True         12
# 2                      81          NaN               True        130
# 3                       1          NaN               True          4
# 4                       3          NaN               True          4
# ...                   ...          ...                ...        ...
# 4006                    3          NaN               True          6
# 4007                    4          NaN               True         11
# 4008                    1          NaN               True         44
# 4009                    1          NaN               True          1
# 4010                    5          NaN               True         91
#
# [4011 rows x 9 columns]

# %%
df.dtypes
# Out:
# Commit_message                 object
# Author_email                   object
# Author_name                    object
# Updated at             datetime64[ns]
# Files_changed                  object
# Files_changed_count             int64
# Contributor                    object
# All_checks_passed                bool
# Additions                       int64
# dtype: object

# %%
df['Additions'] = df['Additions'].str.split('(', expand=True)[1].str.rstrip(',)').astype(int)

# %%
df.dtypes
# Out:
# Commit_message                 object
# Author_email                   object
# Author_name                    object
# Updated at             datetime64[ns]
# Files_changed                  object
# Files_changed_count             int64
# Contributor                    object
# All_checks_passed                bool
# Additions                       int64
# dtype: object

# %%
df.to_csv('commit.csv', index=False)

# %%
df
# Out:
#                                          Commit_message   Contributor  \
# 0                   fix(web): pick deleted user (#1237)       aviv926
# 1     feat(deployment): Consistent container names (...    roschaefer
# 2     refactor(server): imports and repository token...        fyfrey
# 3                           fix nginx conf file (#1229)    roschaefer
# 4                        Docs: Github -> GitHub (#1221)    roschaefer
# ...                                                 ...           ...
# 4006  feat(web): improved album view UI & album card...  alextran1502
# 4007                  chore: simplify API build (#6841)        panoti
# 4008  fix(web): Admin Settings banner/scrolling issu...      badbreze
# 4009  docs: provide details on storage engine album ...        panoti
# 4010            docs(ml): hardware acceleration (#6821)        panoti
#
#                                       Author_email           Author_name  \
# 0                                jrasm91@gmail.com       Jason Rasmussen
# 1                          btom1990@googlemail.com                    bt
# 2                                jrasm91@gmail.com       Jason Rasmussen
# 3                   vedhavyas.singareddi@gmail.com  Vedhavyas Singareddi
# 4                            emaltonator@gmail.com                John P
# ...                                            ...                   ...
# 4006  66187991+azroberts8@users.noreply.github.com        Andrew Roberts
# 4007     322311+benmccann@users.noreply.github.com            Ben McCann
# 4008  66187991+azroberts8@users.noreply.github.com        Andrew Roberts
# 4009    50788000+mmomjian@users.noreply.github.com              mmomjian
# 4010   101130780+mertalev@users.noreply.github.com                  Mert
#
#                Updated at                                      Files_changed  \
# 0     2022-12-31 03:30:48  ['web/src/lib/components/album-page/user-selec...
# 1     2022-12-30 16:30:28  ['docker/docker-compose.dev.yml', 'docker/dock...
# 2     2022-12-30 13:22:06  ['server/apps/cli/src/app.module.ts', 'server/...
# 3     2022-12-30 11:12:24                               ['nginx/nginx.conf']
# 4     2022-12-30 04:45:25  ['docs/docs/overview/help.md', 'docs/docs/over...
# ...                   ...                                                ...
# 4006  2024-02-02 02:50:14  ['web/src/lib/components/album-page/album-card...
# 4007  2024-02-01 22:55:21  ['open-api/typescript-sdk/package.json', 'open...
# 4008  2024-02-01 21:05:30  ['web/src/routes/admin/system-settings/+page.s...
# 4009  2024-02-01 03:28:30        ['docs/docs/partials/_storage-template.md']
# 4010  2024-02-01 01:12:57  ['docker/hwaccel.ml.yml', 'docker/hwaccel.tran...
#
#       Files_changed_count  All_checks_passed  Additions
# 0                       1               True          2
# 1                       3               True         12
# 2                      81               True        130
# 3                       1               True          4
# 4                       3               True          4
# ...                   ...                ...        ...
# 4006                    3               True          6
# 4007                    4               True         11
# 4008                    1               True         44
# 4009                    1               True          1
# 4010                    5               True         91
#
# [4011 rows x 9 columns]

# %% [markdown]
# Xử lý phần Pull request data

# %%
pr_df
# Out:
#       Unnamed: 0 Pr_state                 Created_at  \
# 0              0     open  2024-06-08 22:16:00+00:00
# 1              1   closed  2024-06-08 19:45:48+00:00
# 2              2     open  2024-06-08 18:23:28+00:00
# 3              3   closed  2024-06-08 17:01:24+00:00
# 4              4   closed  2024-06-08 10:44:16+00:00
# ...          ...      ...                        ...
# 4318        4318   closed  2022-02-08 17:24:07+00:00
# 4319        4319   closed  2022-02-08 05:42:11+00:00
# 4320        4320   closed  2022-02-07 02:28:28+00:00
# 4321        4321   closed  2022-02-06 18:08:06+00:00
# 4322        4322   closed  2022-02-06 06:07:43+00:00
#
#                      Updated_at  Additions  Commits                  Merged_at
# 0     2024-06-08 22:16:01+00:00          8        1                        NaN
# 1     2024-06-08 19:51:37+00:00        854        1  2024-06-08 19:51:36+00:00
# 2     2024-06-08 21:41:06+00:00        133        4                        NaN
# 3     2024-06-08 17:55:20+00:00          2        1  2024-06-08 17:55:19+00:00
# 4     2024-06-08 10:50:15+00:00          1        1  2024-06-08 10:50:14+00:00
# ...                         ...        ...      ...                        ...
# 4318  2024-03-12 15:28:50+00:00        343        2  2022-02-08 17:24:49+00:00
# 4319  2024-02-13 22:15:20+00:00      10715        2  2022-02-08 05:42:35+00:00
# 4320  2024-03-09 23:22:33+00:00        133        3  2022-02-07 02:31:32+00:00
# 4321  2024-03-09 04:16:39+00:00         53        2  2022-02-06 19:06:01+00:00
# 4322  2024-05-29 17:11:53+00:00        581       14  2022-02-06 06:07:56+00:00
#
# [4323 rows x 7 columns]

# %%
pr_df['Updated_at'] = pd.to_datetime(pr_df['Updated_at'], utc=False)
pr_df['Updated_at'] = pr_df['Updated_at'].dt.tz_localize(None)

# %%
pr_df['Created_at'] = pd.to_datetime(pr_df['Created_at'], utc=False)
pr_df['Created_at'] = pr_df['Created_at'].dt.tz_localize(None)

# %%
pr_df['Merged_at'] = pd.to_datetime(pr_df['Merged_at'], utc=False)
pr_df['Merged_at'] = pr_df['Merged_at'].dt.tz_localize(None)

# %%
pr_df.loc[pr_df['Merged_at'].isnull() & (pr_df['Pr_state'] == 'closed'), 'Merged_at'] = 'Rejected'
# Out:
# /tmp/ipykernel_6070/4010121747.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Rejected' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   pr_df.loc[pr_df['Merged_at'].isnull() & (pr_df['Pr_state'] == 'closed'), 'Merged_at'] = 'Rejected'

# %%
pr_df
# Out:
#      Pr_state          Created_at          Updated_at  Additions  Commits  \
# 0        open 2024-06-08 22:16:00 2024-06-08 22:16:01          8        1
# 1      closed 2024-06-08 19:45:48 2024-06-08 19:51:37        854        1
# 2        open 2024-06-08 18:23:28 2024-06-08 21:41:06        133        4
# 3      closed 2024-06-08 17:01:24 2024-06-08 17:55:20          2        1
# 4      closed 2024-06-08 10:44:16 2024-06-08 10:50:15          1        1
# ...       ...                 ...                 ...        ...      ...
# 4318   closed 2022-02-08 17:24:07 2024-03-12 15:28:50        343        2
# 4319   closed 2022-02-08 05:42:11 2024-02-13 22:15:20      10715        2
# 4320   closed 2022-02-07 02:28:28 2024-03-09 23:22:33        133        3
# 4321   closed 2022-02-06 18:08:06 2024-03-09 04:16:39         53        2
# 4322   closed 2022-02-06 06:07:43 2024-05-29 17:11:53        581       14
#
#                 Merged_at
# 0                     NaT
# 1     2024-06-08 19:51:36
# 2                     NaT
# 3     2024-06-08 17:55:19
# 4     2024-06-08 10:50:14
# ...                   ...
# 4318  2022-02-08 17:24:49
# 4319  2022-02-08 05:42:35
# 4320  2022-02-07 02:31:32
# 4321  2022-02-06 19:06:01
# 4322  2022-02-06 06:07:56
#
# [4323 rows x 6 columns]

# %%
pr_df[pr_df['Merged_at'] == 'Rejected']
# Out:
#      Pr_state          Created_at          Updated_at  Additions  Commits  \
# 11     closed 2024-06-07 20:03:08 2024-06-07 20:04:14          0       40
# 29     closed 2024-06-05 20:37:02 2024-06-05 20:53:14       1562        2
# 62     closed 2024-06-01 08:34:54 2024-06-04 10:12:58          8        1
# 65     closed 2024-05-30 21:37:34 2024-05-30 21:37:56        209        9
# 84     closed 2024-05-29 13:39:31 2024-05-29 18:14:50          2        1
# ...       ...                 ...                 ...        ...      ...
# 4260   closed 2022-05-11 02:20:58 2022-05-12 13:01:26         86        2
# 4262   closed 2022-05-08 13:14:21 2022-05-11 05:15:15          1        1
# 4270   closed 2022-04-30 21:04:15 2022-05-03 07:00:32        222        7
# 4273   closed 2022-04-28 13:19:14 2022-05-23 22:24:19         20        4
# 4274   closed 2022-04-28 10:30:31 2022-05-06 10:28:06          4        1
#
#      Merged_at
# 11    Rejected
# 29    Rejected
# 62    Rejected
# 65    Rejected
# 84    Rejected
# ...        ...
# 4260  Rejected
# 4262  Rejected
# 4270  Rejected
# 4273  Rejected
# 4274  Rejected
#
# [505 rows x 6 columns]

# %%
pr_df.to_csv('pr.csv')

# %% [markdown]
# Xử lý phần issues data

# %%
issue_df
# Out:
#       Unnamed: 0                 Created_at                  Closed_at  \
# 0              0  2024-06-08 22:16:00+00:00                        NaN
# 1              1  2024-06-08 19:45:48+00:00  2024-06-08 19:51:36+00:00
# 2              2  2024-06-08 18:23:28+00:00                        NaN
# 3              3  2024-06-08 17:01:24+00:00  2024-06-08 17:55:19+00:00
# 4              4  2024-06-08 10:44:16+00:00  2024-06-08 10:50:14+00:00
# ...          ...                        ...                        ...
# 7254        7254  2022-02-06 06:37:29+00:00  2022-02-08 06:27:24+00:00
# 7255        7255  2022-02-06 06:37:24+00:00  2022-02-08 03:44:44+00:00
# 7256        7256  2022-02-06 06:37:08+00:00  2022-02-06 06:50:47+00:00
# 7257        7257  2022-02-06 06:07:43+00:00  2022-02-06 06:07:56+00:00
# 7258        7258  2022-02-05 07:04:44+00:00  2022-02-06 06:26:15+00:00
#
#        State                        Labels         Assignees
# 0       open  ['dependencies', 'renovate']                []
# 1     closed                   ['📱mobile']                []
# 2       open                     ['🖥️web']                []
# 3     closed                  ['🗄️server']                []
# 4     closed                   ['📱mobile']                []
# ...      ...                           ...               ...
# 7254  closed               ['enhancement']                []
# 7255  closed               ['enhancement']                []
# 7256  closed                            []                []
# 7257  closed                            []                []
# 7258  closed                   ['feature']  ['alextran1502']
#
# [7259 rows x 6 columns]

# %%
issue_df['Closed_at'] = pd.to_datetime(issue_df['Closed_at'], utc=False)
issue_df['Closed_at'] = issue_df['Closed_at'].dt.tz_localize(None)
issue_df['Created_at'] = pd.to_datetime(issue_df['Created_at'], utc=False)
issue_df['Created_at'] = issue_df['Created_at'].dt.tz_localize(None)

# %%
issue_df = issue_df.drop(columns ='Unnamed: 0')

# %%
issue_df.loc[issue_df['Closed_at'] == 'Not yet closed', 'Closed_at'].isnull()
# Out:
# 0       False
# 2       False
# 7       False
# 12      False
# 14      False
#         ...
# 5935    False
# 5956    False
# 6388    False
# 6785    False
# 7123    False
# Name: Closed_at, Length: 437, dtype: bool

# %%
issue_df
# Out:
#               Created_at            Closed_at   State  \
# 0    2024-06-08 22:16:00       Not yet closed    open
# 1    2024-06-08 19:45:48  2024-06-08 19:51:36  closed
# 2    2024-06-08 18:23:28       Not yet closed    open
# 3    2024-06-08 17:01:24  2024-06-08 17:55:19  closed
# 4    2024-06-08 10:44:16  2024-06-08 10:50:14  closed
# ...                  ...                  ...     ...
# 7254 2022-02-06 06:37:29  2022-02-08 06:27:24  closed
# 7255 2022-02-06 06:37:24  2022-02-08 03:44:44  closed
# 7256 2022-02-06 06:37:08  2022-02-06 06:50:47  closed
# 7257 2022-02-06 06:07:43  2022-02-06 06:07:56  closed
# 7258 2022-02-05 07:04:44  2022-02-06 06:26:15  closed
#
#                             Labels         Assignees
# 0     ['dependencies', 'renovate']                []
# 1                      ['📱mobile']                []
# 2                        ['🖥️web']                []
# 3                     ['🗄️server']                []
# 4                      ['📱mobile']                []
# ...                            ...               ...
# 7254               ['enhancement']                []
# 7255               ['enhancement']                []
# 7256                            []                []
# 7257                            []                []
# 7258                   ['feature']  ['alextran1502']
#
# [7259 rows x 5 columns]

# %%
issue_df.to_csv('issue.csv')

# %%
languages = repo.get_languages()
total_lines = sum(languages.values())
language_data = [
    {'language': language, 'lines': lines, 'percentage': (lines / total_lines) * 100}
    for language, lines in languages.items()
]
language_df = pd.DataFrame(language_data)
csv_file = 'languages.csv'
language_df.to_csv(csv_file, index=False)

# %%
contents = repo.get_contents("")

# Duyệt qua các file và tính kích thước
file_sizes = {}
for content_file in contents:
    if content_file.type == "file":
        file_sizes[content_file.name] = content_file.size

# In kích thước các file
for file_name, file_size in file_sizes.items():
    print(f"{file_name}: {file_size} bytes")
# Out:
# .dockerignore: 362 bytes
# .editorconfig: 321 bytes
# .gitattributes: 390 bytes
# .gitignore: 378 bytes
# .gitmodules: 190 bytes
# CODEOWNERS: 111 bytes
# CODE_OF_CONDUCT.md: 5221 bytes
# LICENSE: 32388 bytes
# Makefile: 1056 bytes
# README.md: 5512 bytes
# SECURITY.md: 107 bytes
# install.sh: 2890 bytes
# localizely.yml: 3222 bytes
# renovate.json: 2021 bytes
