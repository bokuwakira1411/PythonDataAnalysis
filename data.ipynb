# %%
from github import Github
import datetime
import pandas as pd
import numpy as np
import os

# %%
g = Github('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')
repo = g.get_repo('immich-app/immich')

# %%
pulls = repo.get_pulls(state='all')
pull_data =[]
for pr in pulls:
    user = pr.user.login
    reviews = pr.get_reviews()
    reviewers = []
    for review in reviews:
        reviewer = review.user
        if reviewer:
            reviewers.append(reviewer)
    pull_info= {
        'Author': user,
        'Reviewer': reviewers,
        'Pr_state': pr.state,
        'Created_at': pr.created_at,
        'Updated_at': pr.updated_at,
        'Additions': pr.additions,
        'Commits': pr.commits,
        'Merged_at': pr.merged_at 
    }
    pull_data.append(pull_info)

# %%
pr_df
# Out:
#              Author                                           Reviewer  \
# 0     richard-salam                                                 []
# 1          waclaw66               [NamedUser(login="michelheusschen")]
# 2       zackpollard                       [NamedUser(login="jrasm91")]
# 3      alextran1502                       [NamedUser(login="jrasm91")]
# 4       zackpollard  [NamedUser(login="bo0tzz"), NamedUser(login="m...
# ...             ...                                                ...
# 4413   alextran1502                                                 []
# 4414   alextran1502                                                 []
# 4415   alextran1502                                                 []
# 4416        schklom                                                 []
# 4417   alextran1502                                                 []
#
#      Pr_state                Created_at                Updated_at  Additions  \
# 0        open 2024-06-13 13:31:14+00:00 2024-06-13 13:31:29+00:00          8
# 1        open 2024-06-13 12:48:13+00:00 2024-06-13 13:41:07+00:00        102
# 2      closed 2024-06-13 12:38:18+00:00 2024-06-13 12:44:07+00:00          0
# 3        open 2024-06-13 12:33:47+00:00 2024-06-13 13:18:29+00:00         36
# 4      closed 2024-06-13 11:13:55+00:00 2024-06-13 11:37:43+00:00          7
# ...       ...                       ...                       ...        ...
# 4413   closed 2022-02-08 17:24:07+00:00 2024-03-12 15:28:50+00:00        343
# 4414   closed 2022-02-08 05:42:11+00:00 2024-02-13 22:15:20+00:00      10715
# 4415   closed 2022-02-07 02:28:28+00:00 2024-03-09 23:22:33+00:00        133
# 4416   closed 2022-02-06 18:08:06+00:00 2024-03-09 04:16:39+00:00         53
# 4417   closed 2022-02-06 06:07:43+00:00 2024-05-29 17:11:53+00:00        581
#
#       Commits                 Merged_at
# 0           1                       NaT
# 1           1                       NaT
# 2           1 2024-06-13 12:44:06+00:00
# 3           4                       NaT
# 4           2 2024-06-13 11:37:15+00:00
# ...       ...                       ...
# 4413        2 2022-02-08 17:24:49+00:00
# 4414        2 2022-02-08 05:42:35+00:00
# 4415        3 2022-02-07 02:31:32+00:00
# 4416        2 2022-02-06 19:06:01+00:00
# 4417       14 2022-02-06 06:07:56+00:00
#
# [4418 rows x 8 columns]

# %%
pr_df =pd.DataFrame(pull_data)
pr_df.to_csv('pr_raw_data.csv', index=False)

# %%
pr_df
# Out:
#      Pr_state                Created_at                Updated_at  Additions  \
# 0        open 2024-06-10 10:38:14+00:00 2024-06-10 10:48:47+00:00          2
# 1        open 2024-06-09 21:48:28+00:00 2024-06-10 00:26:35+00:00         66
# 2      closed 2024-06-09 19:07:24+00:00 2024-06-09 19:18:02+00:00         39
# 3      closed 2024-06-09 17:43:42+00:00 2024-06-09 19:48:47+00:00          3
# 4      closed 2024-06-09 16:30:27+00:00 2024-06-09 19:18:41+00:00          0
# ...       ...                       ...                       ...        ...
# 4324   closed 2022-02-08 17:24:07+00:00 2024-03-12 15:28:50+00:00        343
# 4325   closed 2022-02-08 05:42:11+00:00 2024-02-13 22:15:20+00:00      10715
# 4326   closed 2022-02-07 02:28:28+00:00 2024-03-09 23:22:33+00:00        133
# 4327   closed 2022-02-06 18:08:06+00:00 2024-03-09 04:16:39+00:00         53
# 4328   closed 2022-02-06 06:07:43+00:00 2024-05-29 17:11:53+00:00        581
#
#       Commits                 Merged_at
# 0           1                       NaT
# 1           1                       NaT
# 2           1 2024-06-09 19:18:02+00:00
# 3           1                       NaT
# 4           1 2024-06-09 19:18:41+00:00
# ...       ...                       ...
# 4324        2 2022-02-08 17:24:49+00:00
# 4325        2 2022-02-08 05:42:35+00:00
# 4326        3 2022-02-07 02:31:32+00:00
# 4327        2 2022-02-06 19:06:01+00:00
# 4328       14 2022-02-06 06:07:56+00:00
#
# [4329 rows x 6 columns]

# %%
issues = repo.get_issues(state='all')
issue_data=[]
for issue in issues:
    issue_info = { 
        'Author': issue.user.login,
        'Created_at': issue.created_at,
        'Closed_at': issue.closed_at,
        'State': issue.state,
        'Labels': [label.name for label in issue.labels],
        'Assignees': [assignee.login for assignee in issue.assignees]
    }
    issue_data.append(issue_info)

# %%
issues = repo.get_issues(state='all')
issue_comment_user = []
for issue in issues:
    comments = issue.get_comments()
    commentUser = []
    for comment in comments:    
        if comment.user:
            commentUser.append(comment.user)
    issue_comment_user.append(commentUser)

# %%
issue_df = pd.DataFrame(issue_data)
issue_df.to_csv('issue_raw_data.csv',index=False)

# %%
issue_df = pd.read_csv(os.path.join('data', 'issue_raw_data.csv'))

# %%
issue_comment_user
# Out:
# [[NamedUser(login="mertalev")],
#  [NamedUser(login="alextran1502")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="diyoyo")],
#  [NamedUser(login="jrasm91")],
#  [NamedUser(login="jrasm91")],
#  [NamedUser(login="bo0tzz"), NamedUser(login="alextran1502")],
#  [NamedUser(login="bo0tzz"), NamedUser(login="alextran1502")],
#  [NamedUser(login="alextran1502"), NamedUser(login="lyossius")],
#  [NamedUser(login="alextran1502"), NamedUser(login="lyossius")],
#  [NamedUser(login="bo0tzz")],
#  [NamedUser(login="zackpollard"),
#   NamedUser(login="mluettermann"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="junder873")],
#  [NamedUser(login="zackpollard"),
#   NamedUser(login="mluettermann"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="junder873")],
#  [NamedUser(login="zackpollard"),
#   NamedUser(login="mluettermann"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="junder873")],
#  [NamedUser(login="zackpollard"),
#   NamedUser(login="mluettermann"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="junder873")],
#  [NamedUser(login="bo0tzz")],
#  [NamedUser(login="waclaw66")],
#  [NamedUser(login="a12591771")],
#  [NamedUser(login="michelheusschen")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="betterthanever2"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="betterthanever2"),
#   NamedUser(login="alextran1502")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="betterthanever2"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="betterthanever2"),
#   NamedUser(login="alextran1502")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="betterthanever2"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="betterthanever2"),
#   NamedUser(login="alextran1502")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="betterthanever2"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="betterthanever2"),
#   NamedUser(login="alextran1502")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="betterthanever2"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="betterthanever2"),
#   NamedUser(login="alextran1502")],
#  [NamedUser(login="michelheusschen"),
#   NamedUser(login="PolarisGitYHNL"),
#   NamedUser(login="PolarisGitYHNL")],
#  [NamedUser(login="michelheusschen"),
#   NamedUser(login="PolarisGitYHNL"),
#   NamedUser(login="PolarisGitYHNL")],
#  [NamedUser(login="michelheusschen"),
#   NamedUser(login="PolarisGitYHNL"),
#   NamedUser(login="PolarisGitYHNL")],
#  [NamedUser(login="mertalev"),
#   NamedUser(login="lordkitsuna"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="lordkitsuna"),
#   NamedUser(login="lordkitsuna"),
#   NamedUser(login="mertalev")],
#  [NamedUser(login="mertalev"),
#   NamedUser(login="lordkitsuna"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="lordkitsuna"),
#   NamedUser(login="lordkitsuna"),
#   NamedUser(login="mertalev")],
#  [NamedUser(login="mertalev"),
#   NamedUser(login="lordkitsuna"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="lordkitsuna"),
#   NamedUser(login="lordkitsuna"),
#   NamedUser(login="mertalev")],
#  [NamedUser(login="mertalev"),
#   NamedUser(login="lordkitsuna"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="lordkitsuna"),
#   NamedUser(login="lordkitsuna"),
#   NamedUser(login="mertalev")],
#  [NamedUser(login="mertalev"),
#   NamedUser(login="lordkitsuna"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="lordkitsuna"),
#   NamedUser(login="lordkitsuna"),
#   NamedUser(login="mertalev")],
#  [NamedUser(login="mertalev"),
#   NamedUser(login="lordkitsuna"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="lordkitsuna"),
#   NamedUser(login="lordkitsuna"),
#   NamedUser(login="mertalev")],
#  [NamedUser(login="mertalev"),
#   NamedUser(login="lordkitsuna"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="lordkitsuna"),
#   NamedUser(login="lordkitsuna"),
#   NamedUser(login="mertalev")],
#  [NamedUser(login="mmomjian"), NamedUser(login="Cookie-Monster-Coder")],
#  [NamedUser(login="mmomjian"), NamedUser(login="Cookie-Monster-Coder")],
#  [NamedUser(login="mmomjian"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="jrasm91")],
#  [NamedUser(login="mmomjian"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="jrasm91")],
#  [NamedUser(login="mmomjian"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="jrasm91")],
#  [NamedUser(login="mmomjian"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="jrasm91")],
#  [NamedUser(login="mmomjian"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="jrasm91")],
#  [NamedUser(login="aviv926")],
#  [NamedUser(login="Snowknight26")],
#  [NamedUser(login="alextran1502"),
#   NamedUser(login="noosters"),
#   NamedUser(login="MegaShinySnivy"),
#   NamedUser(login="alextran1502")],
#  [NamedUser(login="alextran1502"),
#   NamedUser(login="noosters"),
#   NamedUser(login="MegaShinySnivy"),
#   NamedUser(login="alextran1502")],
#  [NamedUser(login="alextran1502"),
#   NamedUser(login="noosters"),
#   NamedUser(login="MegaShinySnivy"),
#   NamedUser(login="alextran1502")],
#  [NamedUser(login="alextran1502"),
#   NamedUser(login="noosters"),
#   NamedUser(login="MegaShinySnivy"),
#   NamedUser(login="alextran1502")],
#  [NamedUser(login="mertalev"),
#   NamedUser(login="f0ff886f"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="f0ff886f")],
#  [NamedUser(login="mertalev"),
#   NamedUser(login="f0ff886f"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="f0ff886f")],
#  [NamedUser(login="mertalev"),
#   NamedUser(login="f0ff886f"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="f0ff886f")],
#  [NamedUser(login="mertalev"),
#   NamedUser(login="f0ff886f"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="f0ff886f")],
#  [NamedUser(login="michelheusschen"), NamedUser(login="bloedboemmel")],
#  [NamedUser(login="michelheusschen"), NamedUser(login="bloedboemmel")],
#  [NamedUser(login="mmomjian"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="bo0tzz")],
#  [NamedUser(login="mmomjian"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="bo0tzz")],
#  [NamedUser(login="mmomjian"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="bo0tzz")],
#  [NamedUser(login="mmomjian"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="bo0tzz")],
#  [NamedUser(login="mmomjian"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="bo0tzz")],
#  [NamedUser(login="mmomjian"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="bo0tzz")],
#  [NamedUser(login="dronnikovigor"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="mmomjian")],
#  [NamedUser(login="dronnikovigor"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="mmomjian")],
#  [NamedUser(login="dronnikovigor"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="mmomjian")],
#  [NamedUser(login="dronnikovigor"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="mmomjian")],
#  [NamedUser(login="dronnikovigor"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="mmomjian")],
#  [NamedUser(login="dronnikovigor"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="mmomjian")],
#  [NamedUser(login="zackpollard"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="JordyEGNL"),
#   NamedUser(login="Claud10R"),
#   NamedUser(login="jimeelicious"),
#   NamedUser(login="hermesespinola"),
#   NamedUser(login="JordyEGNL"),
#   NamedUser(login="RubenHCCH"),
#   NamedUser(login="jimeelicious"),
#   NamedUser(login="samschultzponsys")],
#  [NamedUser(login="zackpollard"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="JordyEGNL"),
#   NamedUser(login="Claud10R"),
#   NamedUser(login="jimeelicious"),
#   NamedUser(login="hermesespinola"),
#   NamedUser(login="JordyEGNL"),
#   NamedUser(login="RubenHCCH"),
#   NamedUser(login="jimeelicious"),
#   NamedUser(login="samschultzponsys")],
#  [NamedUser(login="zackpollard"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="JordyEGNL"),
#   NamedUser(login="Claud10R"),
#   NamedUser(login="jimeelicious"),
#   NamedUser(login="hermesespinola"),
#   NamedUser(login="JordyEGNL"),
#   NamedUser(login="RubenHCCH"),
#   NamedUser(login="jimeelicious"),
#   NamedUser(login="samschultzponsys")],
#  [NamedUser(login="zackpollard"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="JordyEGNL"),
#   NamedUser(login="Claud10R"),
#   NamedUser(login="jimeelicious"),
#   NamedUser(login="hermesespinola"),
#   NamedUser(login="JordyEGNL"),
#   NamedUser(login="RubenHCCH"),
#   NamedUser(login="jimeelicious"),
#   NamedUser(login="samschultzponsys")],
#  [NamedUser(login="zackpollard"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="JordyEGNL"),
#   NamedUser(login="Claud10R"),
#   NamedUser(login="jimeelicious"),
#   NamedUser(login="hermesespinola"),
#   NamedUser(login="JordyEGNL"),
#   NamedUser(login="RubenHCCH"),
#   NamedUser(login="jimeelicious"),
#   NamedUser(login="samschultzponsys")],
#  [NamedUser(login="zackpollard"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="JordyEGNL"),
#   NamedUser(login="Claud10R"),
#   NamedUser(login="jimeelicious"),
#   NamedUser(login="hermesespinola"),
#   NamedUser(login="JordyEGNL"),
#   NamedUser(login="RubenHCCH"),
#   NamedUser(login="jimeelicious"),
#   NamedUser(login="samschultzponsys")],
#  [NamedUser(login="zackpollard"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="JordyEGNL"),
#   NamedUser(login="Claud10R"),
#   NamedUser(login="jimeelicious"),
#   NamedUser(login="hermesespinola"),
#   NamedUser(login="JordyEGNL"),
#   NamedUser(login="RubenHCCH"),
#   NamedUser(login="jimeelicious"),
#   NamedUser(login="samschultzponsys")],
#  [NamedUser(login="zackpollard"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="JordyEGNL"),
#   NamedUser(login="Claud10R"),
#   NamedUser(login="jimeelicious"),
#   NamedUser(login="hermesespinola"),
#   NamedUser(login="JordyEGNL"),
#   NamedUser(login="RubenHCCH"),
#   NamedUser(login="jimeelicious"),
#   NamedUser(login="samschultzponsys")],
#  [NamedUser(login="zackpollard"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="JordyEGNL"),
#   NamedUser(login="Claud10R"),
#   NamedUser(login="jimeelicious"),
#   NamedUser(login="hermesespinola"),
#   NamedUser(login="JordyEGNL"),
#   NamedUser(login="RubenHCCH"),
#   NamedUser(login="jimeelicious"),
#   NamedUser(login="samschultzponsys")],
#  [NamedUser(login="zackpollard"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="JordyEGNL"),
#   NamedUser(login="Claud10R"),
#   NamedUser(login="jimeelicious"),
#   NamedUser(login="hermesespinola"),
#   NamedUser(login="JordyEGNL"),
#   NamedUser(login="RubenHCCH"),
#   NamedUser(login="jimeelicious"),
#   NamedUser(login="samschultzponsys")],
#  [NamedUser(login="zackpollard"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="JordyEGNL"),
#   NamedUser(login="Claud10R"),
#   NamedUser(login="jimeelicious"),
#   NamedUser(login="hermesespinola"),
#   NamedUser(login="JordyEGNL"),
#   NamedUser(login="RubenHCCH"),
#   NamedUser(login="jimeelicious"),
#   NamedUser(login="samschultzponsys")],
#  [NamedUser(login="zackpollard"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="JordyEGNL"),
#   NamedUser(login="Claud10R"),
#   NamedUser(login="jimeelicious"),
#   NamedUser(login="hermesespinola"),
#   NamedUser(login="JordyEGNL"),
#   NamedUser(login="RubenHCCH"),
#   NamedUser(login="jimeelicious"),
#   NamedUser(login="samschultzponsys")],
#  [NamedUser(login="zackpollard"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="samschultzponsys"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="JordyEGNL"),
#   NamedUser(login="Claud10R"),
#   NamedUser(login="jimeelicious"),
#   NamedUser(login="hermesespinola"),
#   NamedUser(login="JordyEGNL"),
#   NamedUser(login="RubenHCCH"),
#   NamedUser(login="jimeelicious"),
#   NamedUser(login="samschultzponsys")],
#  [NamedUser(login="zackpollard")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="simonhoellein"),
#   NamedUser(login="simonhoellein"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="simonhoellein")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="simonhoellein"),
#   NamedUser(login="simonhoellein"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="simonhoellein")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="simonhoellein"),
#   NamedUser(login="simonhoellein"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="simonhoellein")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="simonhoellein"),
#   NamedUser(login="simonhoellein"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="simonhoellein")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="simonhoellein"),
#   NamedUser(login="simonhoellein"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="simonhoellein")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="simonhoellein"),
#   NamedUser(login="simonhoellein"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="simonhoellein")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="Snowknight26"),
#   NamedUser(login="PolarisGitYHNL"),
#   NamedUser(login="PolarisGitYHNL")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="Snowknight26"),
#   NamedUser(login="PolarisGitYHNL"),
#   NamedUser(login="PolarisGitYHNL")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="Snowknight26"),
#   NamedUser(login="PolarisGitYHNL"),
#   NamedUser(login="PolarisGitYHNL")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="Snowknight26"),
#   NamedUser(login="PolarisGitYHNL"),
#   NamedUser(login="PolarisGitYHNL")],
#  [NamedUser(login="alextran1502"), NamedUser(login="CapSel")],
#  [NamedUser(login="alextran1502"), NamedUser(login="CapSel")],
#  [NamedUser(login="alextran1502"),
#   NamedUser(login="DX37"),
#   NamedUser(login="bencefr")],
#  [NamedUser(login="alextran1502"),
#   NamedUser(login="DX37"),
#   NamedUser(login="bencefr")],
#  [NamedUser(login="alextran1502"),
#   NamedUser(login="DX37"),
#   NamedUser(login="bencefr")],
#  [NamedUser(login="danieldietzler"),
#   NamedUser(login="waclaw66"),
#   NamedUser(login="michelheusschen"),
#   NamedUser(login="danieldietzler"),
#   NamedUser(login="zackpollard"),
#   NamedUser(login="waclaw66"),
#   NamedUser(login="michelheusschen"),
#   NamedUser(login="waclaw66")],
#  [NamedUser(login="danieldietzler"),
#   NamedUser(login="waclaw66"),
#   NamedUser(login="michelheusschen"),
#   NamedUser(login="danieldietzler"),
#   NamedUser(login="zackpollard"),
#   NamedUser(login="waclaw66"),
#   NamedUser(login="michelheusschen"),
#   NamedUser(login="waclaw66")],
#  [NamedUser(login="danieldietzler"),
#   NamedUser(login="waclaw66"),
#   NamedUser(login="michelheusschen"),
#   NamedUser(login="danieldietzler"),
#   NamedUser(login="zackpollard"),
#   NamedUser(login="waclaw66"),
#   NamedUser(login="michelheusschen"),
#   NamedUser(login="waclaw66")],
#  [NamedUser(login="danieldietzler"),
#   NamedUser(login="waclaw66"),
#   NamedUser(login="michelheusschen"),
#   NamedUser(login="danieldietzler"),
#   NamedUser(login="zackpollard"),
#   NamedUser(login="waclaw66"),
#   NamedUser(login="michelheusschen"),
#   NamedUser(login="waclaw66")],
#  [NamedUser(login="danieldietzler"),
#   NamedUser(login="waclaw66"),
#   NamedUser(login="michelheusschen"),
#   NamedUser(login="danieldietzler"),
#   NamedUser(login="zackpollard"),
#   NamedUser(login="waclaw66"),
#   NamedUser(login="michelheusschen"),
#   NamedUser(login="waclaw66")],
#  [NamedUser(login="danieldietzler"),
#   NamedUser(login="waclaw66"),
#   NamedUser(login="michelheusschen"),
#   NamedUser(login="danieldietzler"),
#   NamedUser(login="zackpollard"),
#   NamedUser(login="waclaw66"),
#   NamedUser(login="michelheusschen"),
#   NamedUser(login="waclaw66")],
#  [NamedUser(login="danieldietzler"),
#   NamedUser(login="waclaw66"),
#   NamedUser(login="michelheusschen"),
#   NamedUser(login="danieldietzler"),
#   NamedUser(login="zackpollard"),
#   NamedUser(login="waclaw66"),
#   NamedUser(login="michelheusschen"),
#   NamedUser(login="waclaw66")],
#  [NamedUser(login="danieldietzler"),
#   NamedUser(login="waclaw66"),
#   NamedUser(login="michelheusschen"),
#   NamedUser(login="danieldietzler"),
#   NamedUser(login="zackpollard"),
#   NamedUser(login="waclaw66"),
#   NamedUser(login="michelheusschen"),
#   NamedUser(login="waclaw66")],
#  [NamedUser(login="michelheusschen"),
#   NamedUser(login="zackpollard"),
#   NamedUser(login="PolarisGitYHNL")],
#  [NamedUser(login="michelheusschen"),
#   NamedUser(login="zackpollard"),
#   NamedUser(login="PolarisGitYHNL")],
#  [NamedUser(login="michelheusschen"),
#   NamedUser(login="zackpollard"),
#   NamedUser(login="PolarisGitYHNL")],
#  [NamedUser(login="Ador-able")],
#  [NamedUser(login="bo0tzz"), NamedUser(login="zackpollard")],
#  [NamedUser(login="bo0tzz"), NamedUser(login="zackpollard")],
#  [NamedUser(login="santi8ago8")],
#  [NamedUser(login="alextran1502")],
#  [NamedUser(login="Snowknight26"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="willianpaixao"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alex-cardenas"),
#   NamedUser(login="strannick-ru"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="alex-cardenas"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="junder873"),
#   NamedUser(login="HarryKodden"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="mluettermann"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="willianpaixao"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="pietrouk")],
#  [NamedUser(login="Snowknight26"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="willianpaixao"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alex-cardenas"),
#   NamedUser(login="strannick-ru"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="alex-cardenas"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="junder873"),
#   NamedUser(login="HarryKodden"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="mluettermann"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="willianpaixao"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="pietrouk")],
#  [NamedUser(login="Snowknight26"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="willianpaixao"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alex-cardenas"),
#   NamedUser(login="strannick-ru"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="alex-cardenas"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="junder873"),
#   NamedUser(login="HarryKodden"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="mluettermann"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="willianpaixao"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="pietrouk")],
#  [NamedUser(login="Snowknight26"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="willianpaixao"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alex-cardenas"),
#   NamedUser(login="strannick-ru"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="alex-cardenas"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="junder873"),
#   NamedUser(login="HarryKodden"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="mluettermann"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="willianpaixao"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="pietrouk")],
#  [NamedUser(login="Snowknight26"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="willianpaixao"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alex-cardenas"),
#   NamedUser(login="strannick-ru"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="alex-cardenas"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="junder873"),
#   NamedUser(login="HarryKodden"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="mluettermann"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="willianpaixao"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="pietrouk")],
#  [NamedUser(login="Snowknight26"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="willianpaixao"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alex-cardenas"),
#   NamedUser(login="strannick-ru"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="alex-cardenas"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="junder873"),
#   NamedUser(login="HarryKodden"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="mluettermann"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="willianpaixao"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="pietrouk")],
#  [NamedUser(login="Snowknight26"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="willianpaixao"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alex-cardenas"),
#   NamedUser(login="strannick-ru"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="alex-cardenas"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="junder873"),
#   NamedUser(login="HarryKodden"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="mluettermann"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="willianpaixao"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="pietrouk")],
#  [NamedUser(login="Snowknight26"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="willianpaixao"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alex-cardenas"),
#   NamedUser(login="strannick-ru"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="alex-cardenas"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="junder873"),
#   NamedUser(login="HarryKodden"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="mluettermann"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="willianpaixao"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="pietrouk")],
#  [NamedUser(login="Snowknight26"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="willianpaixao"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alex-cardenas"),
#   NamedUser(login="strannick-ru"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="alex-cardenas"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="junder873"),
#   NamedUser(login="HarryKodden"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="mluettermann"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="willianpaixao"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="pietrouk")],
#  [NamedUser(login="Snowknight26"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="pietrouk"),
#   NamedUser(login="willianpaixao"),
#   NamedUser(login="RosaEinhorn"),
#   NamedUser(login="alex-cardenas"),
#   NamedUser(login="strannick-ru"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="igbjnI05bF"),
#   NamedUser(login="dronnikovigor"),
#   NamedUser(login="iamtherobin"),
#   NamedUser(login="igbjnI05bF"),
# ...
#   NamedUser(login="Str1atum"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="Str1atum"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="Str1atum"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="Str1atum"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="Str1atum"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="vuongtt92"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="vuongtt92"),
#   NamedUser(login="mertalev")],
#  [NamedUser(login="mertalev"),
#   NamedUser(login="Str1atum"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="Str1atum"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="Str1atum"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="Str1atum"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="Str1atum"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="Str1atum"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="vuongtt92"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="vuongtt92"),
#   NamedUser(login="mertalev")],
#  [NamedUser(login="mertalev"),
#   NamedUser(login="Str1atum"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="Str1atum"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="Str1atum"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="Str1atum"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="Str1atum"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="Str1atum"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="vuongtt92"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="vuongtt92"),
#   NamedUser(login="mertalev")],
#  [NamedUser(login="cloudflare-pages[bot]")],
#  [NamedUser(login="cloudflare-pages[bot]")],
#  [NamedUser(login="cloudflare-pages[bot]")],
#  [NamedUser(login="cloudflare-pages[bot]")],
#  [NamedUser(login="mmomjian"), NamedUser(login="gboudreau")],
#  [NamedUser(login="mmomjian"), NamedUser(login="gboudreau")],
#  [NamedUser(login="mertalev"),
#   NamedUser(login="picarica"),
#   NamedUser(login="mdafer"),
#   NamedUser(login="mertalev")],
#  [NamedUser(login="mertalev"),
#   NamedUser(login="picarica"),
#   NamedUser(login="mdafer"),
#   NamedUser(login="mertalev")],
#  [NamedUser(login="mertalev"),
#   NamedUser(login="picarica"),
#   NamedUser(login="mdafer"),
#   NamedUser(login="mertalev")],
#  [NamedUser(login="mertalev"),
#   NamedUser(login="picarica"),
#   NamedUser(login="mdafer"),
#   NamedUser(login="mertalev")],
#  [NamedUser(login="bo0tzz"), NamedUser(login="PR4SAN")],
#  [NamedUser(login="bo0tzz"), NamedUser(login="PR4SAN")],
#  [NamedUser(login="danieldietzler"),
#   NamedUser(login="frejaya"),
#   NamedUser(login="danieldietzler")],
#  [NamedUser(login="danieldietzler"),
#   NamedUser(login="frejaya"),
#   NamedUser(login="danieldietzler")],
#  [NamedUser(login="danieldietzler"),
#   NamedUser(login="frejaya"),
#   NamedUser(login="danieldietzler")],
#  [NamedUser(login="mertalev")],
#  [NamedUser(login="cloudflare-pages[bot]")],
#  [NamedUser(login="mertalev"), NamedUser(login="mertalev")],
#  [NamedUser(login="mertalev"), NamedUser(login="mertalev")],
#  [NamedUser(login="cloudflare-pages[bot]"), NamedUser(login="renovate[bot]")],
#  [NamedUser(login="cloudflare-pages[bot]"), NamedUser(login="renovate[bot]")],
#  [NamedUser(login="alextran1502"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="loveyu")],
#  [NamedUser(login="alextran1502"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="loveyu")],
#  [NamedUser(login="alextran1502"),
#   NamedUser(login="mertalev"),
#   NamedUser(login="loveyu")],
#  [NamedUser(login="Snowknight26"),
#   NamedUser(login="Snowknight26"),
#   NamedUser(login="jrasm91")],
#  [NamedUser(login="Snowknight26"),
#   NamedUser(login="Snowknight26"),
#   NamedUser(login="jrasm91")],
#  [NamedUser(login="Snowknight26"),
#   NamedUser(login="Snowknight26"),
#   NamedUser(login="jrasm91")],
#  [NamedUser(login="bo0tzz")],
#  [NamedUser(login="cloudflare-pages[bot]")],
#  [NamedUser(login="alextran1502"),
#   NamedUser(login="cristian98149"),
#   NamedUser(login="Deathproof76"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="Deathproof76")],
#  [NamedUser(login="alextran1502"),
#   NamedUser(login="cristian98149"),
#   NamedUser(login="Deathproof76"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="Deathproof76")],
#  [NamedUser(login="alextran1502"),
#   NamedUser(login="cristian98149"),
#   NamedUser(login="Deathproof76"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="Deathproof76")],
#  [NamedUser(login="alextran1502"),
#   NamedUser(login="cristian98149"),
#   NamedUser(login="Deathproof76"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="Deathproof76")],
#  [NamedUser(login="alextran1502"),
#   NamedUser(login="cristian98149"),
#   NamedUser(login="Deathproof76"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="Deathproof76")],
#  [NamedUser(login="alextran1502"),
#   NamedUser(login="cristian98149"),
#   NamedUser(login="Deathproof76"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="Deathproof76")],
#  [NamedUser(login="bo0tzz")],
#  [NamedUser(login="cloudflare-pages[bot]"),
#   NamedUser(login="NicholasFlamy"),
#   NamedUser(login="mertalev")],
#  [NamedUser(login="cloudflare-pages[bot]"),
#   NamedUser(login="NicholasFlamy"),
#   NamedUser(login="mertalev")],
#  [NamedUser(login="cloudflare-pages[bot]"),
#   NamedUser(login="NicholasFlamy"),
#   NamedUser(login="mertalev")],
#  [NamedUser(login="cloudflare-pages[bot]")],
#  [NamedUser(login="renovate[bot]"), NamedUser(login="cloudflare-pages[bot]")],
#  [NamedUser(login="renovate[bot]"), NamedUser(login="cloudflare-pages[bot]")],
#  [NamedUser(login="cloudflare-pages[bot]")],
#  [NamedUser(login="cloudflare-pages[bot]")],
#  [NamedUser(login="cloudflare-pages[bot]"), NamedUser(login="zackpollard")],
#  [NamedUser(login="cloudflare-pages[bot]"), NamedUser(login="zackpollard")],
#  [NamedUser(login="cloudflare-pages[bot]")],
#  [NamedUser(login="cloudflare-pages[bot]")],
#  [NamedUser(login="cloudflare-pages[bot]")],
#  [NamedUser(login="cloudflare-pages[bot]")],
#  [NamedUser(login="cloudflare-pages[bot]"), NamedUser(login="fyfrey")],
#  [NamedUser(login="cloudflare-pages[bot]"), NamedUser(login="fyfrey")],
#  [NamedUser(login="cloudflare-pages[bot]")],
#  [NamedUser(login="cloudflare-pages[bot]")],
#  [NamedUser(login="alextran1502")],
#  [NamedUser(login="mertalev"), NamedUser(login="gerwim")],
#  [NamedUser(login="mertalev"), NamedUser(login="gerwim")],
#  [NamedUser(login="cloudflare-pages[bot]")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="mrxorao"),
#   NamedUser(login="austinvaness"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="dominik666692")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="mrxorao"),
#   NamedUser(login="austinvaness"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="dominik666692")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="mrxorao"),
#   NamedUser(login="austinvaness"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="dominik666692")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="mrxorao"),
#   NamedUser(login="austinvaness"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="dominik666692")],
#  [NamedUser(login="bo0tzz"),
#   NamedUser(login="mrxorao"),
#   NamedUser(login="austinvaness"),
#   NamedUser(login="alextran1502"),
#   NamedUser(login="dominik666692")],
#  [NamedUser(login="cloudflare-pages[bot]"), NamedUser(login="NicholasFlamy")],
#  [NamedUser(login="cloudflare-pages[bot]"), NamedUser(login="NicholasFlamy")],
#  [NamedUser(login="cloudflare-pages[bot]")],
#  [NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="bo0tzz")],
#  [NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="bo0tzz")],
#  [NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="bo0tzz")],
#  [NamedUser(login="PR4SAN"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="hungbm")],
#  [NamedUser(login="PR4SAN"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="hungbm")],
#  [NamedUser(login="PR4SAN"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="hungbm")],
#  [NamedUser(login="PR4SAN"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="hungbm")],
#  [NamedUser(login="PR4SAN"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="hungbm")],
#  [NamedUser(login="PR4SAN"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="hungbm")],
#  [NamedUser(login="PR4SAN"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="hungbm")],
#  [NamedUser(login="PR4SAN"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="hungbm")],
#  [NamedUser(login="PR4SAN"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="hungbm")],
#  [NamedUser(login="PR4SAN"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="hungbm")],
#  [NamedUser(login="PR4SAN"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="hungbm")],
#  [NamedUser(login="PR4SAN"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="hungbm")],
#  [NamedUser(login="PR4SAN"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="hungbm")],
#  [NamedUser(login="PR4SAN"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="hungbm")],
#  [NamedUser(login="PR4SAN"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="hungbm")],
#  [NamedUser(login="PR4SAN"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="bo0tzz"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="krystaDev"),
#   NamedUser(login="mmomjian"),
#   NamedUser(login="hungbm")],
#  [NamedUser(login="ThreeAurora"),
#   NamedUser(login="monarc83"),
#   NamedUser(login="guidovw"),
#   NamedUser(login="gitneko"),
#   NamedUser(login="alextran1502")],
#  ...]

# %%
len(issue_comment_user)
# Out:
# 1

# %%
issue_df['Comment user'] = issue_comment_user
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 issue_df['Comment user'] = issue_comment_user
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
#    4528         and value.ndim == 1
#    4529         and not isinstance(value.dtype, ExtensionDtype)
#    4530     ):
#    4531         # broadcast across multiple columns if necessary
#    4532         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:5266, in DataFrame._sanitize_column(self, value)
#    5263     return _reindex_for_setitem(value, self.index)
#    5265 if is_list_like(value):
# -> 5266     com.require_length_match(value, self.index)
#    5267 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5268 if (
#    5269     isinstance(value, Index)
#    5270     and value.dtype == "object"
#    (...)
#    5273     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5274     # this deprecation
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (21925) does not match length of index (7269)

# %%
issue_df
# Out:
#                     Created_at                 Closed_at   State  \
# 0    2024-06-10 11:58:48+00:00                       NaT    open
# 1    2024-06-10 10:38:14+00:00                       NaT    open
# 2    2024-06-10 09:03:16+00:00 2024-06-10 09:09:21+00:00  closed
# 3    2024-06-09 21:48:28+00:00                       NaT    open
# 4    2024-06-09 19:07:24+00:00 2024-06-09 19:18:02+00:00  closed
# ...                        ...                       ...     ...
# 7264 2022-02-06 06:37:29+00:00 2022-02-08 06:27:24+00:00  closed
# 7265 2022-02-06 06:37:24+00:00 2022-02-08 03:44:44+00:00  closed
# 7266 2022-02-06 06:37:08+00:00 2022-02-06 06:50:47+00:00  closed
# 7267 2022-02-06 06:07:43+00:00 2022-02-06 06:07:56+00:00  closed
# 7268 2022-02-05 07:04:44+00:00 2022-02-06 06:26:15+00:00  closed
#
#                               Labels       Assignees
# 0                                 []              []
# 1     [dependencies, github_actions]              []
# 2                                 []              []
# 3                          [📱mobile]              []
# 4                   [github_actions]              []
# ...                              ...             ...
# 7264                   [enhancement]              []
# 7265                   [enhancement]              []
# 7266                              []              []
# 7267                              []              []
# 7268                       [feature]  [alextran1502]
#
# [7269 rows x 5 columns]

# %%
start_date = datetime.datetime(2022, 1,1)
end_date = datetime.datetime(2023,1,1)
def get_commits():
    commit_data = []
    commits = repo.get_commits(since=start_date, until=end_date)
    for commit in commits:
        files_changed = [file.filename for file in commit.files]
        files_changed_count = len(files_changed)
        all_checks_passed = all(status == "success" for status in commit.get_combined_status().statuses)
        additions = commit.stats.additions,
        contributor = commit.author
        commit_info= {
            'Contributor': contributor,
            'Commit_message': commit.commit.message,
            'Author_email': commit.commit.author.email,
            'Author_name': commit.commit.author.name,
            'Updated at': commit.commit.author.date,
            'Files_changed': files_changed,
            'Files_changed_count': files_changed_count,
            'All_checks_passed': all_checks_passed,
            'Additions': additions 
        }
        commit_data.append(commit_info)
    return commit_data

# %%
commit_data1 = get_commits()

# %%
start_date = datetime.datetime(2023, 1,2)
end_date = datetime.datetime(2024, 1, 1)
commit_data2 = get_commits()
# Out:
# Request GET /repos/immich-app/immich/commits/3b1f27b67402e7c8a3bf4d7df87aaf4f4d13a315 failed with 403: Forbidden
# Setting next backoff to 205.803279s

# %%
start_date = datetime.datetime(2024,1,2)
end_date = datetime.datetime(2024,6,10)
commit_data3 = get_commits()

# %%
df1 = pd.DataFrame(commit_data1)
df2 = pd.DataFrame(commit_data2)
df3 = pd.DataFrame(commit_data3)
df = pd.concat([df1, df2,df3], ignore_index=True)

# %%
df
# Out:
#                            Contributor  \
# 0           NamedUser(login="jrasm91")
# 1              NamedUser(login="bt90")
# 2           NamedUser(login="jrasm91")
# 3         NamedUser(login="vedhavyas")
# 4           NamedUser(login="Emalton")
# ...                                ...
# 4425  NamedUser(login="renovate[bot]")
# 4426  NamedUser(login="renovate[bot]")
# 4427      NamedUser(login="jcianci12")
# 4428       NamedUser(login="martabal")
# 4429        NamedUser(login="jrasm91")
#
#                                          Commit_message  \
# 0                   fix(web): pick deleted user (#1237)
# 1     feat(deployment): Consistent container names (...
# 2     refactor(server): imports and repository token...
# 3                           fix nginx conf file (#1229)
# 4                        Docs: Github -> GitHub (#1221)
# ...                                                 ...
# 4425  chore(deps): update @immich/cli (#6118)\n\nCo-...
# 4426  fix(deps): update dependency @nestjs/schedule ...
# 4427  docs: add step by step set up guide for extern...
# 4428  fix: use loading spinner for library spinner (...
# 4429             feat(mobile): use new endpoint (#6108)
#
#                                          Author_email           Author_name  \
# 0                                   jrasm91@gmail.com       Jason Rasmussen
# 1                             btom1990@googlemail.com                  bt90
# 2                                   jrasm91@gmail.com       Jason Rasmussen
# 3                      vedhavyas.singareddi@gmail.com  Vedhavyas Singareddi
# 4                               emaltonator@gmail.com                John P
# ...                                               ...                   ...
# 4425  29139614+renovate[bot]@users.noreply.github.com         renovate[bot]
# 4426  29139614+renovate[bot]@users.noreply.github.com         renovate[bot]
# 4427                              jcianci12@gmail.com             jcianci12
# 4428       74269598+martabal@users.noreply.github.com                martin
# 4429                                jrasm91@gmail.com       Jason Rasmussen
#
#                     Updated at  \
# 0    2022-12-31 03:30:48+00:00
# 1    2022-12-30 16:30:28+00:00
# 2    2022-12-30 13:22:06+00:00
# 3    2022-12-30 11:12:24+00:00
# 4    2022-12-30 04:45:25+00:00
# ...                        ...
# 4425 2024-01-02 03:35:50+00:00
# 4426 2024-01-02 03:25:25+00:00
# 4427 2024-01-02 03:18:28+00:00
# 4428 2024-01-02 03:10:48+00:00
# 4429 2024-01-02 00:02:30+00:00
#
#                                           Files_changed  Files_changed_count  \
# 0     [web/src/lib/components/album-page/user-select...                    1
# 1     [docker/docker-compose.dev.yml, docker/docker-...                    3
# 2     [server/apps/cli/src/app.module.ts, server/app...                   81
# 3                                    [nginx/nginx.conf]                    1
# 4     [docs/docs/overview/help.md, docs/docs/overvie...                    3
# ...                                                 ...                  ...
# 4425                            [cli/package-lock.json]                    1
# 4426  [server/package-lock.json, server/package.json...                    3
# 4427                  [docs/docs/features/libraries.md]                    1
# 4428  [web/package-lock.json, web/package.json, web/...                    4
# 4429  [mobile/lib/modules/backup/services/backup.ser...                    1
#
#       All_checks_passed Additions
# 0                  True      (2,)
# 1                  True     (12,)
# 2                  True    (130,)
# 3                  True      (4,)
# 4                  True      (4,)
# ...                 ...       ...
# 4425               True    (371,)
# 4426               True     (19,)
# 4427               True     (20,)
# 4428               True      (9,)
# 4429               True      (1,)
#
# [4430 rows x 9 columns]

# %%
df = pd.read_csv(os.path.join('data', 'commit_raw_data.csv'))

# %%
df['Updated at'] = pd.to_datetime(df['Updated at'])
df = df.sort_values(by='Updated at', ascending=True)

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#                           Contributor  \
# 0     NamedUser(login="alextran1502")
# 1     NamedUser(login="alextran1502")
# 2     NamedUser(login="alextran1502")
# 3     NamedUser(login="alextran1502")
# 4     NamedUser(login="alextran1502")
# ...                               ...
# 4425    NamedUser(login="roschaefer")
# 4426    NamedUser(login="roschaefer")
# 4427        NamedUser(login="fyfrey")
# 4428    NamedUser(login="roschaefer")
# 4429       NamedUser(login="aviv926")
#
#                                          Commit_message  \
# 0                                        Initial commit
# 1                       Transfer repository from Gitlab
# 2     Added successfully built docker-compose and co...
# 3     Add readme for top level folder, clean up dead...
# 4     Update readme with known problem of cpu missin...
# ...                                                 ...
# 4425  ci: automatically apply PR labels (#10064)\n\n...
# 4426  refactor: remove dead code from Makefile (#100...
# 4427  fix(server): proper asset sync (#10019)\n\n* f...
# 4428  refactor: dedicated icon for permanently delet...
# 4429  docs: Add Email Notifications info (#9930)\n\n...
#
#                                    Author_email         Author_name  \
# 0                       alex.tran1502@gmail.com                Alex
# 1                       alex.tran1502@gmail.com          Tran, Alex
# 2                       alex.tran1502@gmail.com           Alex Tran
# 3                       alex.tran1502@gmail.com           Alex Tran
# 4                       alex.tran1502@gmail.com           Alex Tran
# ...                                         ...                 ...
# 4425                          git@roschaefer.de      Robert Schäfer
# 4426                          git@roschaefer.de      Robert Schäfer
# 4427   10599762+fyfrey@users.noreply.github.com  Fynn Petersen-Frey
# 4428                          git@roschaefer.de      Robert Schäfer
# 4429  51673860+aviv926@users.noreply.github.com             aviv926
#
#                     Updated at  \
# 0    2022-02-03 15:56:28+00:00
# 1    2022-02-03 16:06:44+00:00
# 2    2022-02-03 20:42:27+00:00
# 3    2022-02-03 21:27:31+00:00
# 4    2022-02-03 21:46:41+00:00
# ...                        ...
# 4425 2024-06-09 19:18:02+00:00
# 4426 2024-06-09 19:18:41+00:00
# 4427 2024-06-09 19:19:28+00:00
# 4428 2024-06-09 19:25:27+00:00
# 4429 2024-06-09 20:07:08+00:00
#
#                                           Files_changed  Files_changed_count  \
# 0                                           ['LICENSE']                    1
# 1     ['mobile/.gitignore', 'mobile/.metadata', 'mob...                  177
# 2     ['mobile/lib/modules/home/views/home_page.dart...                   15
# 3     ['README.md', 'server/Dockerfile', 'server/REA...                    7
# 4                                         ['README.md']                    1
# ...                                                 ...                  ...
# 4425  ['.github/labeler.yml', '.github/workflows/pr-...                    3
# 4426                                       ['Makefile']                    1
# 4427  ['mobile/lib/services/asset.service.dart', 'mo...                   11
# 4428  ['web/src/lib/components/asset-viewer/delete-b...                    3
# 4429  ['docs/docs/administration/email-notification....                    9
#
#       All_checks_passed Additions
# 0                  True     (21,)
# 1                  True  (13300,)
# 2                  True    (198,)
# 3                  True     (90,)
# 4                  True     (14,)
# ...                 ...       ...
# 4425               True     (39,)
# 4426               True      (0,)
# 4427               True     (38,)
# 4428               True      (6,)
# 4429               True     (57,)
#
# [4430 rows x 9 columns]

# %%
df.to_csv('commit_raw_data.csv', index=False)

# %%
df = pd.read_csv(os.path.join('data','commit_raw_data.csv'))
pr_df = pd.read_csv(os.path.join('data','pr_raw_data.csv'))
issue_df = pd.read_csv(os.path.join('data','issue_raw_data.csv'))

# %%
df
# Out:
#                           Contributor  \
# 0     NamedUser(login="alextran1502")
# 1     NamedUser(login="alextran1502")
# 2     NamedUser(login="alextran1502")
# 3     NamedUser(login="alextran1502")
# 4     NamedUser(login="alextran1502")
# ...                               ...
# 4425    NamedUser(login="roschaefer")
# 4426    NamedUser(login="roschaefer")
# 4427        NamedUser(login="fyfrey")
# 4428    NamedUser(login="roschaefer")
# 4429       NamedUser(login="aviv926")
#
#                                          Commit_message  \
# 0                                        Initial commit
# 1                       Transfer repository from Gitlab
# 2     Added successfully built docker-compose and co...
# 3     Add readme for top level folder, clean up dead...
# 4     Update readme with known problem of cpu missin...
# ...                                                 ...
# 4425  ci: automatically apply PR labels (#10064)\n\n...
# 4426  refactor: remove dead code from Makefile (#100...
# 4427  fix(server): proper asset sync (#10019)\n\n* f...
# 4428  refactor: dedicated icon for permanently delet...
# 4429  docs: Add Email Notifications info (#9930)\n\n...
#
#                                    Author_email         Author_name  \
# 0                       alex.tran1502@gmail.com                Alex
# 1                       alex.tran1502@gmail.com          Tran, Alex
# 2                       alex.tran1502@gmail.com           Alex Tran
# 3                       alex.tran1502@gmail.com           Alex Tran
# 4                       alex.tran1502@gmail.com           Alex Tran
# ...                                         ...                 ...
# 4425                          git@roschaefer.de      Robert Schäfer
# 4426                          git@roschaefer.de      Robert Schäfer
# 4427   10599762+fyfrey@users.noreply.github.com  Fynn Petersen-Frey
# 4428                          git@roschaefer.de      Robert Schäfer
# 4429  51673860+aviv926@users.noreply.github.com             aviv926
#
#                      Updated at  \
# 0     2022-02-03 15:56:28+00:00
# 1     2022-02-03 16:06:44+00:00
# 2     2022-02-03 20:42:27+00:00
# 3     2022-02-03 21:27:31+00:00
# 4     2022-02-03 21:46:41+00:00
# ...                         ...
# 4425  2024-06-09 19:18:02+00:00
# 4426  2024-06-09 19:18:41+00:00
# 4427  2024-06-09 19:19:28+00:00
# 4428  2024-06-09 19:25:27+00:00
# 4429  2024-06-09 20:07:08+00:00
#
#                                           Files_changed  Files_changed_count  \
# 0                                           ['LICENSE']                    1
# 1     ['mobile/.gitignore', 'mobile/.metadata', 'mob...                  177
# 2     ['mobile/lib/modules/home/views/home_page.dart...                   15
# 3     ['README.md', 'server/Dockerfile', 'server/REA...                    7
# 4                                         ['README.md']                    1
# ...                                                 ...                  ...
# 4425  ['.github/labeler.yml', '.github/workflows/pr-...                    3
# 4426                                       ['Makefile']                    1
# 4427  ['mobile/lib/services/asset.service.dart', 'mo...                   11
# 4428  ['web/src/lib/components/asset-viewer/delete-b...                    3
# 4429  ['docs/docs/administration/email-notification....                    9
#
#       All_checks_passed Additions
# 0                  True     (21,)
# 1                  True  (13300,)
# 2                  True    (198,)
# 3                  True     (90,)
# 4                  True     (14,)
# ...                 ...       ...
# 4425               True     (39,)
# 4426               True      (0,)
# 4427               True     (38,)
# 4428               True      (6,)
# 4429               True     (57,)
#
# [4430 rows x 9 columns]

# %%
null_counts = df['Commit_message'].isnull().sum()
print(null_counts)
null_counts = df['Updated at'].isnull().sum()
print(null_counts)
null_counts = df['All_checks_passed'].isnull().sum()
print(null_counts)
null_counts = df['Files_changed'].isnull().sum()
print(null_counts)
null_counts = df['Contributor'].isnull().sum()
print(null_counts)
null_counts = df['Author_name'].isnull().sum()
print(null_counts)
# Out:
# 0
# 0
# 0
# 0
# 63
# 0

# %% [markdown]
# Xử lý phần Commit Data

# %%
df['Contributor'] = df['Contributor'].str.extract(r'NamedUser\(login="([^"]+)"\)')
df
# Out:
#        Contributor                                     Commit_message  \
# 0     alextran1502                                     Initial commit
# 1     alextran1502                    Transfer repository from Gitlab
# 2     alextran1502  Added successfully built docker-compose and co...
# 3     alextran1502  Add readme for top level folder, clean up dead...
# 4     alextran1502  Update readme with known problem of cpu missin...
# ...            ...                                                ...
# 4425    roschaefer  ci: automatically apply PR labels (#10064)\n\n...
# 4426    roschaefer  refactor: remove dead code from Makefile (#100...
# 4427        fyfrey  fix(server): proper asset sync (#10019)\n\n* f...
# 4428    roschaefer  refactor: dedicated icon for permanently delet...
# 4429       aviv926  docs: Add Email Notifications info (#9930)\n\n...
#
#                                    Author_email         Author_name  \
# 0                       alex.tran1502@gmail.com                Alex
# 1                       alex.tran1502@gmail.com          Tran, Alex
# 2                       alex.tran1502@gmail.com           Alex Tran
# 3                       alex.tran1502@gmail.com           Alex Tran
# 4                       alex.tran1502@gmail.com           Alex Tran
# ...                                         ...                 ...
# 4425                          git@roschaefer.de      Robert Schäfer
# 4426                          git@roschaefer.de      Robert Schäfer
# 4427   10599762+fyfrey@users.noreply.github.com  Fynn Petersen-Frey
# 4428                          git@roschaefer.de      Robert Schäfer
# 4429  51673860+aviv926@users.noreply.github.com             aviv926
#
#                      Updated at  \
# 0     2022-02-03 15:56:28+00:00
# 1     2022-02-03 16:06:44+00:00
# 2     2022-02-03 20:42:27+00:00
# 3     2022-02-03 21:27:31+00:00
# 4     2022-02-03 21:46:41+00:00
# ...                         ...
# 4425  2024-06-09 19:18:02+00:00
# 4426  2024-06-09 19:18:41+00:00
# 4427  2024-06-09 19:19:28+00:00
# 4428  2024-06-09 19:25:27+00:00
# 4429  2024-06-09 20:07:08+00:00
#
#                                           Files_changed  Files_changed_count  \
# 0                                           ['LICENSE']                    1
# 1     ['mobile/.gitignore', 'mobile/.metadata', 'mob...                  177
# 2     ['mobile/lib/modules/home/views/home_page.dart...                   15
# 3     ['README.md', 'server/Dockerfile', 'server/REA...                    7
# 4                                         ['README.md']                    1
# ...                                                 ...                  ...
# 4425  ['.github/labeler.yml', '.github/workflows/pr-...                    3
# 4426                                       ['Makefile']                    1
# 4427  ['mobile/lib/services/asset.service.dart', 'mo...                   11
# 4428  ['web/src/lib/components/asset-viewer/delete-b...                    3
# 4429  ['docs/docs/administration/email-notification....                    9
#
#       All_checks_passed Additions
# 0                  True     (21,)
# 1                  True  (13300,)
# 2                  True    (198,)
# 3                  True     (90,)
# 4                  True     (14,)
# ...                 ...       ...
# 4425               True     (39,)
# 4426               True      (0,)
# 4427               True     (38,)
# 4428               True      (6,)
# 4429               True     (57,)
#
# [4430 rows x 9 columns]

# %%
null_contributor_rows = df[df['Contributor'].isnull()]
df.loc[null_contributor_rows.index, 'Contributor'] = null_contributor_rows['Author_name']

# %%
df['Updated at'] = pd.to_datetime(df['Updated at'], utc=False)
df['Updated at'] = df['Updated at'].dt.tz_localize(None)

# %%
df['Author_name'] = df['Author_name'].str.replace(r'[^a-zA-Z\s]', '', regex=True)
df
# Out:
#        Contributor                                     Commit_message  \
# 0     alextran1502                                     Initial commit
# 1     alextran1502                    Transfer repository from Gitlab
# 2     alextran1502  Added successfully built docker-compose and co...
# 3     alextran1502  Add readme for top level folder, clean up dead...
# 4     alextran1502  Update readme with known problem of cpu missin...
# ...            ...                                                ...
# 4425    roschaefer  ci: automatically apply PR labels (#10064)\n\n...
# 4426    roschaefer  refactor: remove dead code from Makefile (#100...
# 4427        fyfrey  fix(server): proper asset sync (#10019)\n\n* f...
# 4428    roschaefer  refactor: dedicated icon for permanently delet...
# 4429       aviv926  docs: Add Email Notifications info (#9930)\n\n...
#
#                                    Author_email        Author_name  \
# 0                       alex.tran1502@gmail.com               Alex
# 1                       alex.tran1502@gmail.com          Tran Alex
# 2                       alex.tran1502@gmail.com          Alex Tran
# 3                       alex.tran1502@gmail.com          Alex Tran
# 4                       alex.tran1502@gmail.com          Alex Tran
# ...                                         ...                ...
# 4425                          git@roschaefer.de      Robert Schfer
# 4426                          git@roschaefer.de      Robert Schfer
# 4427   10599762+fyfrey@users.noreply.github.com  Fynn PetersenFrey
# 4428                          git@roschaefer.de      Robert Schfer
# 4429  51673860+aviv926@users.noreply.github.com               aviv
#
#               Updated at                                      Files_changed  \
# 0    2022-02-03 15:56:28                                        ['LICENSE']
# 1    2022-02-03 16:06:44  ['mobile/.gitignore', 'mobile/.metadata', 'mob...
# 2    2022-02-03 20:42:27  ['mobile/lib/modules/home/views/home_page.dart...
# 3    2022-02-03 21:27:31  ['README.md', 'server/Dockerfile', 'server/REA...
# 4    2022-02-03 21:46:41                                      ['README.md']
# ...                  ...                                                ...
# 4425 2024-06-09 19:18:02  ['.github/labeler.yml', '.github/workflows/pr-...
# 4426 2024-06-09 19:18:41                                       ['Makefile']
# 4427 2024-06-09 19:19:28  ['mobile/lib/services/asset.service.dart', 'mo...
# 4428 2024-06-09 19:25:27  ['web/src/lib/components/asset-viewer/delete-b...
# 4429 2024-06-09 20:07:08  ['docs/docs/administration/email-notification....
#
#       Files_changed_count  All_checks_passed Additions
# 0                       1               True     (21,)
# 1                     177               True  (13300,)
# 2                      15               True    (198,)
# 3                       7               True     (90,)
# 4                       1               True     (14,)
# ...                   ...                ...       ...
# 4425                    3               True     (39,)
# 4426                    1               True      (0,)
# 4427                   11               True     (38,)
# 4428                    3               True      (6,)
# 4429                    9               True     (57,)
#
# [4430 rows x 9 columns]

# %%
df.dtypes
# Out:
# Contributor                    object
# Commit_message                 object
# Author_email                   object
# Author_name                    object
# Updated at             datetime64[ns]
# Files_changed                  object
# Files_changed_count             int64
# All_checks_passed                bool
# Additions                      object
# dtype: object

# %%
df['Additions'] = df['Additions'].str.split('(', expand=True)[1].str.rstrip(',)').astype(int)

# %%
df.dtypes
# Out:
# Contributor                    object
# Commit_message                 object
# Author_email                   object
# Author_name                    object
# Updated at             datetime64[ns]
# Files_changed                  object
# Files_changed_count             int64
# All_checks_passed                bool
# Additions                       int64
# dtype: object

# %%
df.to_csv('commit.csv', index=False)

# %% [markdown]
# Xử lý phần Pull request data

# %%
pr_df
# Out:
#      Pr_state                 Created_at                 Updated_at  \
# 0        open  2024-06-10 10:38:14+00:00  2024-06-10 10:48:47+00:00
# 1        open  2024-06-09 21:48:28+00:00  2024-06-10 00:26:35+00:00
# 2      closed  2024-06-09 19:07:24+00:00  2024-06-09 19:18:02+00:00
# 3      closed  2024-06-09 17:43:42+00:00  2024-06-09 19:48:47+00:00
# 4      closed  2024-06-09 16:30:27+00:00  2024-06-09 19:18:41+00:00
# ...       ...                        ...                        ...
# 4324   closed  2022-02-08 17:24:07+00:00  2024-03-12 15:28:50+00:00
# 4325   closed  2022-02-08 05:42:11+00:00  2024-02-13 22:15:20+00:00
# 4326   closed  2022-02-07 02:28:28+00:00  2024-03-09 23:22:33+00:00
# 4327   closed  2022-02-06 18:08:06+00:00  2024-03-09 04:16:39+00:00
# 4328   closed  2022-02-06 06:07:43+00:00  2024-05-29 17:11:53+00:00
#
#       Additions  Commits                  Merged_at
# 0             2        1                        NaN
# 1            66        1                        NaN
# 2            39        1  2024-06-09 19:18:02+00:00
# 3             3        1                        NaN
# 4             0        1  2024-06-09 19:18:41+00:00
# ...         ...      ...                        ...
# 4324        343        2  2022-02-08 17:24:49+00:00
# 4325      10715        2  2022-02-08 05:42:35+00:00
# 4326        133        3  2022-02-07 02:31:32+00:00
# 4327         53        2  2022-02-06 19:06:01+00:00
# 4328        581       14  2022-02-06 06:07:56+00:00
#
# [4329 rows x 6 columns]

# %%
pr_df['Updated_at'] = pd.to_datetime(pr_df['Updated_at'], utc=False)
pr_df['Updated_at'] = pr_df['Updated_at'].dt.tz_localize(None)

# %%
pr_df['Created_at'] = pd.to_datetime(pr_df['Created_at'], utc=False)
pr_df['Created_at'] = pr_df['Created_at'].dt.tz_localize(None)

# %%
pr_df['Merged_at'] = pd.to_datetime(pr_df['Merged_at'], utc=False)
pr_df['Merged_at'] = pr_df['Merged_at'].dt.tz_localize(None)

# %%
pr_df['Rejected'] = pr_df['Merged_at'] == 'Rejected'

# %%
pr_df
# Out:
#      Pr_state          Created_at          Updated_at  Additions  Commits  \
# 0        open 2024-06-10 10:38:14 2024-06-10 10:48:47          2        1
# 1        open 2024-06-09 21:48:28 2024-06-10 00:26:35         66        1
# 2      closed 2024-06-09 19:07:24 2024-06-09 19:18:02         39        1
# 3      closed 2024-06-09 17:43:42 2024-06-09 19:48:47          3        1
# 4      closed 2024-06-09 16:30:27 2024-06-09 19:18:41          0        1
# ...       ...                 ...                 ...        ...      ...
# 4324   closed 2022-02-08 17:24:07 2024-03-12 15:28:50        343        2
# 4325   closed 2022-02-08 05:42:11 2024-02-13 22:15:20      10715        2
# 4326   closed 2022-02-07 02:28:28 2024-03-09 23:22:33        133        3
# 4327   closed 2022-02-06 18:08:06 2024-03-09 04:16:39         53        2
# 4328   closed 2022-02-06 06:07:43 2024-05-29 17:11:53        581       14
#
#                 Merged_at
# 0                     NaT
# 1                     NaT
# 2     2024-06-09 19:18:02
# 3                Rejected
# 4     2024-06-09 19:18:41
# ...                   ...
# 4324  2022-02-08 17:24:49
# 4325  2022-02-08 05:42:35
# 4326  2022-02-07 02:31:32
# 4327  2022-02-06 19:06:01
# 4328  2022-02-06 06:07:56
#
# [4329 rows x 6 columns]

# %%
pr_df.to_csv('pr.csv', index=False)

# %% [markdown]
# Xử lý phần issues data

# %%
issue_df
# Out:
#                      Created_at                  Closed_at   State  \
# 0     2024-06-10 11:58:48+00:00                        NaN    open
# 1     2024-06-10 10:38:14+00:00                        NaN    open
# 2     2024-06-10 09:03:16+00:00  2024-06-10 09:09:21+00:00  closed
# 3     2024-06-09 21:48:28+00:00                        NaN    open
# 4     2024-06-09 19:07:24+00:00  2024-06-09 19:18:02+00:00  closed
# ...                         ...                        ...     ...
# 7264  2022-02-06 06:37:29+00:00  2022-02-08 06:27:24+00:00  closed
# 7265  2022-02-06 06:37:24+00:00  2022-02-08 03:44:44+00:00  closed
# 7266  2022-02-06 06:37:08+00:00  2022-02-06 06:50:47+00:00  closed
# 7267  2022-02-06 06:07:43+00:00  2022-02-06 06:07:56+00:00  closed
# 7268  2022-02-05 07:04:44+00:00  2022-02-06 06:26:15+00:00  closed
#
#                                   Labels         Assignees
# 0                                     []                []
# 1     ['dependencies', 'github_actions']                []
# 2                                     []                []
# 3                            ['📱mobile']                []
# 4                     ['github_actions']                []
# ...                                  ...               ...
# 7264                     ['enhancement']                []
# 7265                     ['enhancement']                []
# 7266                                  []                []
# 7267                                  []                []
# 7268                         ['feature']  ['alextran1502']
#
# [7269 rows x 5 columns]

# %%
issue_df['Closed_at'] = pd.to_datetime(issue_df['Closed_at'], utc=False)
issue_df['Closed_at'] = issue_df['Closed_at'].dt.tz_localize(None)
issue_df['Created_at'] = pd.to_datetime(issue_df['Created_at'], utc=False)
issue_df['Created_at'] = issue_df['Created_at'].dt.tz_localize(None)

# %%
issue_df
# Out:
#               Created_at           Closed_at   State  \
# 0    2024-06-10 11:58:48                 NaT    open
# 1    2024-06-10 10:38:14                 NaT    open
# 2    2024-06-10 09:03:16 2024-06-10 09:09:21  closed
# 3    2024-06-09 21:48:28                 NaT    open
# 4    2024-06-09 19:07:24 2024-06-09 19:18:02  closed
# ...                  ...                 ...     ...
# 7264 2022-02-06 06:37:29 2022-02-08 06:27:24  closed
# 7265 2022-02-06 06:37:24 2022-02-08 03:44:44  closed
# 7266 2022-02-06 06:37:08 2022-02-06 06:50:47  closed
# 7267 2022-02-06 06:07:43 2022-02-06 06:07:56  closed
# 7268 2022-02-05 07:04:44 2022-02-06 06:26:15  closed
#
#                                   Labels         Assignees
# 0                                     []                []
# 1     ['dependencies', 'github_actions']                []
# 2                                     []                []
# 3                            ['📱mobile']                []
# 4                     ['github_actions']                []
# ...                                  ...               ...
# 7264                     ['enhancement']                []
# 7265                     ['enhancement']                []
# 7266                                  []                []
# 7267                                  []                []
# 7268                         ['feature']  ['alextran1502']
#
# [7269 rows x 5 columns]

# %%
issue_df.to_csv('issue.csv',index=False)

# %%
issue_df
# Out:
#               Created_at           Closed_at   State  \
# 0    2024-06-10 11:58:48                 NaT    open
# 1    2024-06-10 10:38:14                 NaT    open
# 2    2024-06-10 09:03:16 2024-06-10 09:09:21  closed
# 3    2024-06-09 21:48:28                 NaT    open
# 4    2024-06-09 19:07:24 2024-06-09 19:18:02  closed
# ...                  ...                 ...     ...
# 7264 2022-02-06 06:37:29 2022-02-08 06:27:24  closed
# 7265 2022-02-06 06:37:24 2022-02-08 03:44:44  closed
# 7266 2022-02-06 06:37:08 2022-02-06 06:50:47  closed
# 7267 2022-02-06 06:07:43 2022-02-06 06:07:56  closed
# 7268 2022-02-05 07:04:44 2022-02-06 06:26:15  closed
#
#                                   Labels         Assignees
# 0                                     []                []
# 1     ['dependencies', 'github_actions']                []
# 2                                     []                []
# 3                            ['📱mobile']                []
# 4                     ['github_actions']                []
# ...                                  ...               ...
# 7264                     ['enhancement']                []
# 7265                     ['enhancement']                []
# 7266                                  []                []
# 7267                                  []                []
# 7268                         ['feature']  ['alextran1502']
#
# [7269 rows x 5 columns]

# %%
languages = repo.get_languages()
total_lines = sum(languages.values())
language_data = [{
    'language': language, 
    'lines': lines}
    for language, lines in languages.items()
]
language_df = pd.DataFrame(language_data)
language_df.to_csv('languages.csv', index=False)

# %%
from collections import defaultdict
file_info = defaultdict(lambda: {'size': 0, 'commits': 0})
commits = repo.get_commits()
for commit in commits:
    for file in commit.files:
        file_path = file.filename
        file_size = file.changes
        file_info[file_path]['size'] = file_size
        file_info[file_path]['commits'] += 1
for file_path, info in file_info.items():
    print(f'File: {file_path}, Size: {info["size"]} bytes, Commits: {info["commits"]}')
# Out:
# File: server/src/services/person.service.spec.ts, Size: 2 bytes, Commits: 11
# File: server/src/services/person.service.ts, Size: 0 bytes, Commits: 14
# File: server/test/fixtures/asset.stub.ts, Size: 291 bytes, Commits: 29
# File: mobile/android/fastlane/report.xml, Size: 20 bytes, Commits: 60
# File: mobile/ios/Runner.xcodeproj/project.pbxproj, Size: 551 bytes, Commits: 73
# File: mobile/ios/Runner/Info.plist, Size: 49 bytes, Commits: 98
# File: mobile/ios/fastlane/report.xml, Size: 18 bytes, Commits: 67
# File: cli/package-lock.json, Size: 6261 bytes, Commits: 127
# File: cli/package.json, Size: 49 bytes, Commits: 51
# File: docs/static/archived-versions.json, Size: 6 bytes, Commits: 7
# File: e2e/package-lock.json, Size: 383 bytes, Commits: 75
# File: e2e/package.json, Size: 22 bytes, Commits: 36
# File: machine-learning/pyproject.toml, Size: 56 bytes, Commits: 106
# File: mobile/android/fastlane/Fastfile, Size: 25 bytes, Commits: 177
# File: mobile/ios/fastlane/Fastfile, Size: 28 bytes, Commits: 199
# File: mobile/openapi/README.md, Size: 158 bytes, Commits: 289
# File: mobile/pubspec.yaml, Size: 39 bytes, Commits: 280
# File: open-api/immich-openapi-specs.json, Size: 0 bytes, Commits: 127
# File: open-api/typescript-sdk/package-lock.json, Size: 132 bytes, Commits: 53
# File: open-api/typescript-sdk/package.json, Size: 27 bytes, Commits: 33
# File: open-api/typescript-sdk/src/fetch-client.ts, Size: 0 bytes, Commits: 82
# File: server/package-lock.json, Size: 8043 bytes, Commits: 319
# File: server/package.json, Size: 100 bytes, Commits: 339
# File: web/package-lock.json, Size: 5783 bytes, Commits: 171
# File: web/package.json, Size: 45 bytes, Commits: 129
# File: mobile/lib/pages/common/video_viewer.page.dart, Size: 0 bytes, Commits: 5
# File: mobile/lib/providers/asset_viewer/video_player_controls_provider.dart, Size: 0 bytes, Commits: 2
# File: mobile/lib/widgets/asset_viewer/custom_video_player_controls.dart, Size: 4 bytes, Commits: 3
# File: server/Dockerfile, Size: 65 bytes, Commits: 106
# File: web/src/lib/components/faces-page/merge-face-selector.svelte, Size: 145 bytes, Commits: 30
# File: web/src/lib/components/faces-page/merge-suggestion-modal.svelte, Size: 128 bytes, Commits: 18
# File: web/src/lib/components/faces-page/show-hide.svelte, Size: 30 bytes, Commits: 14
# File: web/src/lib/components/photos-page/asset-select-control-bar.svelte, Size: 39 bytes, Commits: 13
# File: web/src/lib/components/shared-components/navigation-bar/account-info-panel.svelte, Size: 79 bytes, Commits: 30
# File: web/src/lib/components/shared-components/navigation-bar/navigation-bar.svelte, Size: 73 bytes, Commits: 49
# File: web/src/lib/components/shared-components/side-bar/more-information-albums.svelte, Size: 24 bytes, Commits: 2
# File: web/src/lib/components/shared-components/side-bar/more-information-assets.svelte, Size: 17 bytes, Commits: 2
# File: web/src/lib/components/shared-components/status-box.svelte, Size: 0 bytes, Commits: 29
# File: web/src/lib/i18n/en.json, Size: 0 bytes, Commits: 13
# File: web/src/routes/(user)/albums/[albumId=id]/[[photos=photos]]/[[assetId=id]]/+page.svelte, Size: 10 bytes, Commits: 16
# File: web/src/routes/(user)/people/+page.svelte, Size: 48 bytes, Commits: 53
# File: web/src/routes/(user)/people/[personId]/[[photos=photos]]/[[assetId=id]]/+page.svelte, Size: 0 bytes, Commits: 9
# File: web/src/routes/(user)/sharing/sharedlinks/+page.svelte, Size: 0 bytes, Commits: 26
# File: web/src/routes/(user)/trash/[[photos=photos]]/[[assetId=id]]/+page.svelte, Size: 0 bytes, Commits: 8
# File: web/src/routes/(user)/utilities/[duplicates]/[[photos=photos]]/[[assetId=id]]/+page.svelte, Size: 66 bytes, Commits: 5
# File: mobile/openapi/lib/model/duplicate_detection_config.dart, Size: 108 bytes, Commits: 2
# File: mobile/openapi/lib/model/facial_recognition_config.dart, Size: 57 bytes, Commits: 2
# File: mobile/openapi/lib/model/server_storage_response_dto.dart, Size: 36 bytes, Commits: 2
# File: server/src/dtos/model-config.dto.ts, Size: 0 bytes, Commits: 5
# File: server/src/dtos/server-info.dto.ts, Size: 2 bytes, Commits: 10
# File: server/src/utils/misc.ts, Size: 32 bytes, Commits: 12
# File: web/src/lib/i18n/cs.json, Size: 781 bytes, Commits: 8
# File: web/src/lib/i18n/es.json, Size: 781 bytes, Commits: 11
# File: web/src/lib/i18n/nl.json, Size: 781 bytes, Commits: 11
# File: web/src/lib/i18n/pl.json, Size: 781 bytes, Commits: 10
# File: renovate.json, Size: 20 bytes, Commits: 30
# File: web/src/lib/i18n/ar.json, Size: 781 bytes, Commits: 5
# File: web/src/lib/i18n/ca.json, Size: 781 bytes, Commits: 7
# File: web/src/lib/i18n/da.json, Size: 781 bytes, Commits: 5
# File: web/src/lib/i18n/fi.json, Size: 781 bytes, Commits: 7
# File: web/src/lib/i18n/fr.json, Size: 781 bytes, Commits: 9
# File: web/src/lib/i18n/he.json, Size: 781 bytes, Commits: 7
# File: web/src/lib/i18n/hi.json, Size: 781 bytes, Commits: 5
# File: web/src/lib/i18n/hu.json, Size: 781 bytes, Commits: 7
# File: web/src/lib/i18n/it.json, Size: 781 bytes, Commits: 8
# File: web/src/lib/i18n/ja.json, Size: 781 bytes, Commits: 7
# File: web/src/lib/i18n/ko.json, Size: 781 bytes, Commits: 6
# File: web/src/lib/i18n/lv.json, Size: 781 bytes, Commits: 5
# File: web/src/lib/i18n/mn.json, Size: 781 bytes, Commits: 5
# File: web/src/lib/i18n/nb_NO.json, Size: 781 bytes, Commits: 6
# File: web/src/lib/i18n/pt.json, Size: 781 bytes, Commits: 5
# File: web/src/lib/i18n/ro.json, Size: 781 bytes, Commits: 6
# File: web/src/lib/i18n/ru.json, Size: 781 bytes, Commits: 10
# File: web/src/lib/i18n/sk.json, Size: 781 bytes, Commits: 6
# File: web/src/lib/i18n/sl.json, Size: 781 bytes, Commits: 6
# File: web/src/lib/i18n/sr.json, Size: 0 bytes, Commits: 5
# File: web/src/lib/i18n/sv.json, Size: 781 bytes, Commits: 6
# File: web/src/lib/i18n/th.json, Size: 781 bytes, Commits: 5
# File: web/src/lib/i18n/uk.json, Size: 781 bytes, Commits: 6
# File: web/src/lib/i18n/vi.json, Size: 781 bytes, Commits: 8
# File: web/src/lib/i18n/zh_Hant.json, Size: 791 bytes, Commits: 2
# File: web/src/lib/i18n/de.json, Size: 781 bytes, Commits: 9
# File: web/src/lib/i18n/zh_SIMPLIFIED.json, Size: 781 bytes, Commits: 12
# File: docker/scripts/get-cpus.sh, Size: 49 bytes, Commits: 2
# File: e2e/src/api/specs/asset.e2e-spec.ts, Size: 481 bytes, Commits: 24
# File: e2e/src/utils.ts, Size: 104 bytes, Commits: 38
# File: server/src/interfaces/asset.interface.ts, Size: 4 bytes, Commits: 19
# File: server/src/repositories/asset.repository.ts, Size: 10 bytes, Commits: 27
# File: server/src/services/asset-media.service.ts, Size: 177 bytes, Commits: 4
# File: web/src/lib/components/utilities-page/duplicates/duplicates-compare-control.svelte, Size: 133 bytes, Commits: 5
# File: server/src/utils/healthcheck.ts, Size: 29 bytes, Commits: 2
# File: web/src/lib/components/admin-page/settings/storage-template/storage-template-settings.svelte, Size: 6 bytes, Commits: 29
# File: web/src/lib/components/asset-viewer/asset-viewer-nav-bar.svelte, Size: 2 bytes, Commits: 56
# File: web/src/lib/components/asset-viewer/photo-viewer.svelte, Size: 25 bytes, Commits: 56
# File: web/src/lib/components/faces-page/person-side-panel.svelte, Size: 278 bytes, Commits: 22
# File: web/src/lib/components/forms/admin-registration-form.svelte, Size: 78 bytes, Commits: 22
# File: web/src/lib/components/photos-page/actions/archive-action.svelte, Size: 51 bytes, Commits: 15
# File: web/src/lib/components/photos-page/actions/favorite-action.svelte, Size: 50 bytes, Commits: 14
# File: web/src/lib/components/assets/thumbnail/thumbnail.svelte, Size: 140 bytes, Commits: 40
# File: web/src/routes/(user)/explore/+page.svelte, Size: 173 bytes, Commits: 30
# File: web/src/routes/(user)/places/+page.svelte, Size: 52 bytes, Commits: 6
# File: server/src/cores/storage.core.ts, Size: 2 bytes, Commits: 12
# File: server/src/cores/system-config.core.ts, Size: 0 bytes, Commits: 17
# File: server/src/services/asset.service.ts, Size: 0 bytes, Commits: 27
# File: server/src/services/auth.service.ts, Size: 0 bytes, Commits: 16
# File: server/src/services/cli.service.ts, Size: 70 bytes, Commits: 4
# File: server/src/services/duplicate.service.ts, Size: 133 bytes, Commits: 4
# File: server/src/services/job.service.ts, Size: 0 bytes, Commits: 14
# File: server/src/services/library.service.ts, Size: 0 bytes, Commits: 17
# File: server/src/services/map.service.ts, Size: 59 bytes, Commits: 2
# File: server/src/services/media.service.ts, Size: 0 bytes, Commits: 20
# File: server/src/services/metadata.service.ts, Size: 0 bytes, Commits: 19
# File: server/src/services/notification.service.ts, Size: 98 bytes, Commits: 8
# File: server/src/services/search.service.ts, Size: 0 bytes, Commits: 12
# File: server/src/services/server-info.service.ts, Size: 0 bytes, Commits: 13
# File: server/src/services/smart-info.service.ts, Size: 0 bytes, Commits: 11
# File: server/src/services/storage-template.service.ts, Size: 0 bytes, Commits: 10
# File: server/src/services/system-config.service.ts, Size: 0 bytes, Commits: 15
# File: server/src/services/user.service.ts, Size: 0 bytes, Commits: 14
# File: server/src/services/version.service.ts, Size: 105 bytes, Commits: 3
# File: docs/docs/features/hardware-transcoding.md, Size: 60 bytes, Commits: 9
# File: web/src/lib/utils/file-uploader.ts, Size: 113 bytes, Commits: 66
# File: web/src/lib/components/admin-page/delete-confirm-dialogue.svelte, Size: 3 bytes, Commits: 7
# File: web/src/lib/components/admin-page/jobs/job-tile.svelte, Size: 52 bytes, Commits: 34
# File: web/src/lib/components/admin-page/jobs/jobs-panel.svelte, Size: 138 bytes, Commits: 50
# File: web/src/lib/components/admin-page/server-stats/server-stats-panel.svelte, Size: 42 bytes, Commits: 24
# File: web/src/lib/components/admin-page/settings/admin-settings.svelte, Size: 75 bytes, Commits: 10
# File: web/src/lib/components/admin-page/settings/ffmpeg/ffmpeg-settings.svelte, Size: 126 bytes, Commits: 47
# File: web/src/lib/components/admin-page/settings/job-settings/job-settings.svelte, Size: 103 bytes, Commits: 17
# File: web/src/lib/components/forms/create-user-form.svelte, Size: 74 bytes, Commits: 37
# File: web/src/lib/components/forms/edit-user-form.svelte, Size: 103 bytes, Commits: 39
# File: web/src/lib/components/forms/library-exclusion-pattern-form.svelte, Size: 55 bytes, Commits: 12
# File: web/src/lib/components/forms/library-import-path-form.svelte, Size: 53 bytes, Commits: 10
# File: web/src/lib/components/forms/library-import-paths-form.svelte, Size: 174 bytes, Commits: 14
# File: web/src/lib/components/forms/library-scan-settings-form.svelte, Size: 175 bytes, Commits: 12
# File: web/src/lib/components/forms/library-user-picker-form.svelte, Size: 54 bytes, Commits: 9
# File: web/src/lib/components/user-settings-page/app-settings.svelte, Size: 18 bytes, Commits: 9
# File: web/src/lib/components/user-settings-page/change-password-settings.svelte, Size: 78 bytes, Commits: 14
# File: web/src/lib/components/user-settings-page/notifications-settings.svelte, Size: 75 bytes, Commits: 3
# File: web/src/lib/components/user-settings-page/oauth-settings.svelte, Size: 86 bytes, Commits: 14
# File: web/src/lib/components/user-settings-page/partner-settings.svelte, Size: 98 bytes, Commits: 25
# File: web/src/lib/components/user-settings-page/user-api-key-list.svelte, Size: 180 bytes, Commits: 22
# File: web/src/lib/utils.ts, Size: 33 bytes, Commits: 28
# File: web/src/routes/(user)/user-settings/+page.ts, Size: 19 bytes, Commits: 5
# File: web/src/routes/admin/jobs-status/+page.svelte, Size: 11 bytes, Commits: 18
# File: web/src/routes/admin/jobs-status/+page.ts, Size: 17 bytes, Commits: 4
# File: web/src/routes/admin/library-management/+page.svelte, Size: 450 bytes, Commits: 15
# File: web/src/routes/admin/library-management/+page.ts, Size: 16 bytes, Commits: 3
# File: web/src/routes/admin/repair/+page.svelte, Size: 336 bytes, Commits: 15
# File: web/src/routes/admin/repair/+page.ts, Size: 19 bytes, Commits: 4
# File: web/src/routes/admin/server-status/+page.ts, Size: 16 bytes, Commits: 4
# File: web/src/routes/admin/system-settings/+page.svelte, Size: 2 bytes, Commits: 42
# File: web/src/routes/admin/system-settings/+page.ts, Size: 16 bytes, Commits: 4
# File: web/src/routes/admin/user-management/+page.svelte, Size: 232 bytes, Commits: 46
# File: web/src/routes/admin/user-management/+page.ts, Size: 16 bytes, Commits: 6
# File: server/src/repositories/metadata.repository.ts, Size: 6 bytes, Commits: 9
# File: server/src/repositories/media.repository.ts, Size: 2 bytes, Commits: 9
# File: server/src/utils/media.ts, Size: 0 bytes, Commits: 20
# File: docker/docker-compose.dev.yml, Size: 87 bytes, Commits: 87
# File: docker/docker-compose.prod.yml, Size: 114 bytes, Commits: 53
# File: docker/docker-compose.yml, Size: 41 bytes, Commits: 97
# File: mobile/lib/providers/asset_viewer/video_player_controller_provider.dart, Size: 0 bytes, Commits: 3
# File: mobile/lib/providers/asset_viewer/video_player_controller_provider.g.dart, Size: 0 bytes, Commits: 2
# File: mobile/lib/providers/map/map_state.provider.g.dart, Size: 0 bytes, Commits: 2
# File: web/src/lib/components/asset-viewer/asset-viewer.svelte, Size: 234 bytes, Commits: 153
# File: web/src/lib/components/photos-page/asset-date-group.svelte, Size: 157 bytes, Commits: 55
# File: web/src/lib/components/shared-components/gallery-viewer/gallery-viewer.svelte, Size: 118 bytes, Commits: 32
# File: machine-learning/poetry.lock, Size: 2444 bytes, Commits: 59
# File: web/src/lib/utils/asset-utils.ts, Size: 21 bytes, Commits: 63
# File: server/src/workers/api.ts, Size: 68 bytes, Commits: 7
# File: .github/workflows/cli.yml, Size: 90 bytes, Commits: 9
# File: misc/release/pump-version.sh, Size: 31 bytes, Commits: 17
# File: web/.prettierrc, Size: 7 bytes, Commits: 10
# File: web/src/lib/i18n/lt.json, Size: 781 bytes, Commits: 4
# File: web/static/manifest.json, Size: 35 bytes, Commits: 4
# File: web/tsconfig.json, Size: 20 bytes, Commits: 14
# File: misc/release/archive-version.js, Size: 17 bytes, Commits: 3
# File: mobile/lib/widgets/forms/login/login_form.dart, Size: 279 bytes, Commits: 2
# File: docs/docusaurus.config.js, Size: 0 bytes, Commits: 33
# File: docs/src/components/version-switcher.tsx, Size: 59 bytes, Commits: 1
# File: docs/src/theme/NavbarItem/ComponentTypes.js, Size: 7 bytes, Commits: 1
# File: web/src/lib/constants.ts, Size: 1 bytes, Commits: 52
# File: web/src/lib/i18n.spec.ts, Size: 36 bytes, Commits: 3
# File: docs/docs/administration/system-settings.md, Size: 173 bytes, Commits: 4
# File: docs/src/pages/roadmap.tsx, Size: 839 bytes, Commits: 4
# File: docs/docs/install/environment-variables.md, Size: 186 bytes, Commits: 40
# File: mobile/lib/pages/login/login.page.dart, Size: 0 bytes, Commits: 3
# File: mobile/lib/utils/version_compatibility.dart, Size: 17 bytes, Commits: 1
# File: mobile/lib/widgets/forms/login/email_input.dart, Size: 49 bytes, Commits: 1
# File: mobile/lib/widgets/forms/login/loading_icon.dart, Size: 21 bytes, Commits: 1
# File: mobile/lib/widgets/forms/login/login_button.dart, Size: 27 bytes, Commits: 1
# File: mobile/lib/widgets/forms/login/o_auth_login_button.dart, Size: 34 bytes, Commits: 1
# File: mobile/lib/widgets/forms/login/password_input.dart, Size: 49 bytes, Commits: 1
# File: mobile/lib/widgets/forms/login/server_endpoint_input.dart, Size: 54 bytes, Commits: 1
# File: mobile/test/modules/utils/version_compatibility_test.dart, Size: 35 bytes, Commits: 1
# File: e2e/src/api/specs/library.e2e-spec.ts, Size: 456 bytes, Commits: 9
# File: server/src/interfaces/job.interface.ts, Size: 0 bytes, Commits: 10
# File: server/src/services/asset.service.spec.ts, Size: 2 bytes, Commits: 19
# File: server/src/services/library.service.spec.ts, Size: 2 bytes, Commits: 16
# File: server/src/services/metadata.service.spec.ts, Size: 2 bytes, Commits: 15
# File: server/src/services/trash.service.spec.ts, Size: 2 bytes, Commits: 6
# File: server/src/services/trash.service.ts, Size: 0 bytes, Commits: 5
# File: .github/workflows/pr-require-label.yml, Size: 13 bytes, Commits: 3
# File: docker/prometheus.yml, Size: 12 bytes, Commits: 2
# File: server/src/config.ts, Size: 35 bytes, Commits: 19
# File: server/src/services/microservices.service.ts, Size: 0 bytes, Commits: 9
# File: server/src/utils/instrumentation.ts, Size: 2 bytes, Commits: 5
# File: server/src/workers/microservices.ts, Size: 32 bytes, Commits: 5
# File: .github/workflows/docker.yml, Size: 90 bytes, Commits: 47
# File: web/.prettierignore, Size: 13 bytes, Commits: 6
# File: web/src/lib/assets/immich-logo.json, Size: 1 bytes, Commits: 2
# File: docs/docs/administration/email-notification.mdx, Size: 23 bytes, Commits: 1
# File: docs/docs/administration/img/email-settings.png, Size: 0 bytes, Commits: 1
# File: docs/docs/administration/img/immich-email-notefaction.webp, Size: 0 bytes, Commits: 1
# File: docs/docs/administration/img/send-user-email-notification.webp, Size: 0 bytes, Commits: 1
# File: docs/docs/administration/img/user-notifications-settings.png, Size: 0 bytes, Commits: 1
# File: docs/docs/administration/user-management.mdx, Size: 0 bytes, Commits: 4
# File: docs/docs/guides/img/email-settings.png, Size: 0 bytes, Commits: 1
# File: docs/docs/guides/img/google-app-password.webp, Size: 0 bytes, Commits: 1
# File: docs/docs/guides/smtp-gmail.md, Size: 20 bytes, Commits: 1
# File: web/src/lib/components/asset-viewer/delete-button.svelte, Size: 27 bytes, Commits: 2
# File: web/src/lib/components/photos-page/actions/delete-assets.svelte, Size: 45 bytes, Commits: 21
# File: mobile/lib/services/asset.service.dart, Size: 8 bytes, Commits: 4
# File: mobile/openapi/lib/model/asset_full_sync_dto.dart, Size: 158 bytes, Commits: 3
# File: server/src/dtos/asset-response.dto.ts, Size: 24 bytes, Commits: 12
# File: server/src/dtos/sync.dto.ts, Size: 38 bytes, Commits: 3
# File: server/src/entities/asset-stack.entity.ts, Size: 2 bytes, Commits: 2
# File: server/src/queries/asset.repository.sql, Size: 0 bytes, Commits: 19
# File: server/src/services/sync.service.ts, Size: 77 bytes, Commits: 4
# File: Makefile, Size: 5 bytes, Commits: 39
# File: .github/labeler.yml, Size: 23 bytes, Commits: 1
# File: .github/workflows/pr-labeler.yml, Size: 12 bytes, Commits: 1
# File: web/src/lib/utils/navigation.ts, Size: 3 bytes, Commits: 7
# File: web/src/lib/components/asset-viewer/asset-viewer-nav-bar.spec.ts, Size: 41 bytes, Commits: 1
# File: web/src/lib/components/asset-viewer/delete-button.spec.ts, Size: 34 bytes, Commits: 1
# File: web/src/test-data/factories/user-factory.ts, Size: 18 bytes, Commits: 13
# File: mobile/assets/i18n/ar-JO.json, Size: 513 bytes, Commits: 5
# File: mobile/assets/i18n/cs-CZ.json, Size: 4 bytes, Commits: 28
# File: mobile/assets/i18n/da-DK.json, Size: 106 bytes, Commits: 33
# File: mobile/assets/i18n/de-DE.json, Size: 98 bytes, Commits: 42
# File: mobile/assets/i18n/el-GR.json, Size: 513 bytes, Commits: 5
# File: mobile/assets/i18n/en-US.json, Size: 98 bytes, Commits: 149
# File: mobile/assets/i18n/es-ES.json, Size: 106 bytes, Commits: 33
# File: mobile/assets/i18n/es-MX.json, Size: 293 bytes, Commits: 20
# File: mobile/assets/i18n/es-PE.json, Size: 293 bytes, Commits: 20
# File: mobile/assets/i18n/es-US.json, Size: 388 bytes, Commits: 9
# File: mobile/assets/i18n/fi-FI.json, Size: 106 bytes, Commits: 31
# File: mobile/assets/i18n/fr-CA.json, Size: 384 bytes, Commits: 7
# File: mobile/assets/i18n/fr-FR.json, Size: 106 bytes, Commits: 38
# File: mobile/assets/i18n/he-IL.json, Size: 513 bytes, Commits: 5
# File: mobile/assets/i18n/hi-IN.json, Size: 293 bytes, Commits: 20
# File: mobile/assets/i18n/hu-HU.json, Size: 293 bytes, Commits: 20
# File: mobile/assets/i18n/it-IT.json, Size: 106 bytes, Commits: 35
# File: mobile/assets/i18n/ja-JP.json, Size: 106 bytes, Commits: 28
# File: mobile/assets/i18n/ko-KR.json, Size: 153 bytes, Commits: 26
# File: mobile/assets/i18n/lt-LT.json, Size: 513 bytes, Commits: 5
# File: mobile/assets/i18n/lv-LV.json, Size: 293 bytes, Commits: 21
# File: mobile/assets/i18n/mn.json, Size: 293 bytes, Commits: 20
# File: mobile/assets/i18n/nb-NO.json, Size: 0 bytes, Commits: 24
# File: mobile/assets/i18n/nl-NL.json, Size: 153 bytes, Commits: 32
# File: mobile/assets/i18n/pl-PL.json, Size: 106 bytes, Commits: 29
# File: mobile/assets/i18n/pt-PT.json, Size: 194 bytes, Commits: 12
# File: mobile/assets/i18n/ro-RO.json, Size: 513 bytes, Commits: 5
# File: mobile/assets/i18n/ru-RU.json, Size: 194 bytes, Commits: 29
# File: mobile/assets/i18n/sk-SK.json, Size: 194 bytes, Commits: 29
# File: mobile/assets/i18n/sl-SI.json, Size: 479 bytes, Commits: 6
# File: mobile/assets/i18n/sr-Cyrl.json, Size: 293 bytes, Commits: 20
# File: mobile/assets/i18n/sr-Latn.json, Size: 293 bytes, Commits: 19
# File: mobile/assets/i18n/sv-FI.json, Size: 293 bytes, Commits: 20
# File: mobile/assets/i18n/sv-SE.json, Size: 206 bytes, Commits: 28
# File: mobile/assets/i18n/th-TH.json, Size: 293 bytes, Commits: 22
# File: mobile/assets/i18n/uk-UA.json, Size: 293 bytes, Commits: 20
# File: mobile/assets/i18n/vi-VN.json, Size: 293 bytes, Commits: 19
# File: mobile/assets/i18n/zh-CN.json, Size: 194 bytes, Commits: 27
# File: mobile/assets/i18n/zh-Hans.json, Size: 293 bytes, Commits: 20
# File: mobile/assets/i18n/zh-TW.json, Size: 518 bytes, Commits: 4
# File: server/src/interfaces/machine-learning.interface.ts, Size: 0 bytes, Commits: 3
# File: server/src/repositories/machine-learning.repository.ts, Size: 0 bytes, Commits: 7
# File: mobile/lib/utils/image_url_builder.dart, Size: 16 bytes, Commits: 19
# File: README.md, Size: 33 bytes, Commits: 149
# File: readme_i18n/README_ar_JO.md, Size: 129 bytes, Commits: 4
# File: readme_i18n/README_ca_ES.md, Size: 2 bytes, Commits: 7
# File: readme_i18n/README_de_DE.md, Size: 2 bytes, Commits: 7
# File: readme_i18n/README_es_ES.md, Size: 2 bytes, Commits: 7
# File: readme_i18n/README_fr_FR.md, Size: 2 bytes, Commits: 8
# File: readme_i18n/README_it_IT.md, Size: 2 bytes, Commits: 7
# File: readme_i18n/README_ja_JP.md, Size: 2 bytes, Commits: 7
# File: readme_i18n/README_ko_KR.md, Size: 2 bytes, Commits: 7
# File: readme_i18n/README_nl_NL.md, Size: 2 bytes, Commits: 8
# File: readme_i18n/README_pt_BR.md, Size: 131 bytes, Commits: 5
# File: readme_i18n/README_ru_RU.md, Size: 0 bytes, Commits: 8
# File: readme_i18n/README_sv_SE.md, Size: 129 bytes, Commits: 2
# File: readme_i18n/README_tr_TR.md, Size: 2 bytes, Commits: 7
# File: web/src/lib/components/shared-components/drag-and-drop-upload-overlay.svelte, Size: 25 bytes, Commits: 15
# File: web/src/lib/components/admin-page/jobs/storage-migration-description.svelte, Size: 10 bytes, Commits: 7
# File: server/src/queries/user.repository.sql, Size: 0 bytes, Commits: 6
# File: server/src/repositories/user.repository.ts, Size: 4 bytes, Commits: 9
# File: server/src/services/media.service.spec.ts, Size: 2 bytes, Commits: 26
# File: web/src/lib/i18n/es_ES@new.json, Size: 781 bytes, Commits: 2
# File: e2e/src/web/specs/photo-viewer.e2e-spec.ts, Size: 57 bytes, Commits: 1
# File: web/src/lib/actions/zoom-image.ts, Size: 31 bytes, Commits: 1
# File: web/src/lib/components/asset-viewer/photo-viewer.spec.ts, Size: 83 bytes, Commits: 3
# File: web/src/lib/stores/zoom-image.store.ts, Size: 4 bytes, Commits: 3
# File: web/src/lib/stores/preferences.store.ts, Size: 21 bytes, Commits: 27
# File: web/src/routes/+layout.ts, Size: 25 bytes, Commits: 7
# File: docs/static/img/ios-app-store-badge.png, Size: 0 bytes, Commits: 3
# File: mobile/openapi/lib/api.dart, Size: 82 bytes, Commits: 132
# File: mobile/openapi/lib/api/notifications_api.dart, Size: 57 bytes, Commits: 1
# File: server/src/controllers/index.ts, Size: 50 bytes, Commits: 13
# File: server/src/controllers/notification.controller.ts, Size: 19 bytes, Commits: 1
# File: server/src/dtos/system-config.dto.ts, Size: 32 bytes, Commits: 10
# File: server/src/emails/test.email.tsx, Size: 134 bytes, Commits: 1
# File: server/src/interfaces/notification.interface.ts, Size: 44 bytes, Commits: 3
# File: server/src/repositories/notification.repository.ts, Size: 72 bytes, Commits: 4
# File: web/src/lib/components/admin-page/settings/notification-settings/notification-settings.svelte, Size: 109 bytes, Commits: 4
# File: web/src/lib/components/album-page/__tests__/album-card.spec.ts, Size: 144 bytes, Commits: 25
# File: web/src/lib/components/album-page/album-description.spec.ts, Size: 18 bytes, Commits: 3
# File: web/src/lib/components/shared-components/notification/__tests__/notification-card.spec.ts, Size: 39 bytes, Commits: 8
# File: web/src/lib/components/shared-components/notification/__tests__/notification-list.spec.ts, Size: 44 bytes, Commits: 8
# File: web/src/test-data/setup.ts, Size: 1 bytes, Commits: 2
# File: web/src/lib/components/user-settings-page/user-settings-list.svelte, Size: 27 bytes, Commits: 37
# File: web/src/lib/components/admin-page/settings/library-settings/library-settings.svelte, Size: 145 bytes, Commits: 14
# File: web/src/lib/components/album-page/albums-list.svelte, Size: 282 bytes, Commits: 14
# File: web/src/lib/components/onboarding-page/onboarding-storage-template.svelte, Size: 37 bytes, Commits: 9
# File: web/src/lib/components/photos-page/actions/stack-action.svelte, Size: 57 bytes, Commits: 10
# File: web/src/lib/components/slideshow-settings.svelte, Size: 37 bytes, Commits: 12
# File: machine-learning/app/config.py, Size: 22 bytes, Commits: 21
# File: machine-learning/app/main.py, Size: 84 bytes, Commits: 24
# File: machine-learning/app/models/__init__.py, Size: 3 bytes, Commits: 8
# File: machine-learning/app/models/base.py, Size: 52 bytes, Commits: 28
# File: machine-learning/app/models/cache.py, Size: 26 bytes, Commits: 10
# File: machine-learning/app/models/clip.py, Size: 37 bytes, Commits: 22
# File: machine-learning/app/models/clip/textual.py, Size: 98 bytes, Commits: 1
# File: machine-learning/app/models/clip/visual.py, Size: 69 bytes, Commits: 1
# File: machine-learning/app/models/constants.py, Size: 57 bytes, Commits: 7
# File: machine-learning/app/models/facial_recognition.py, Size: 59 bytes, Commits: 16
# File: machine-learning/app/models/facial_recognition/detection.py, Size: 48 bytes, Commits: 1
# File: machine-learning/app/models/facial_recognition/recognition.py, Size: 77 bytes, Commits: 1
# File: machine-learning/app/models/session.py, Size: 0 bytes, Commits: 1
# File: machine-learning/app/models/transforms.py, Size: 35 bytes, Commits: 4
# File: machine-learning/app/schemas.py, Size: 64 bytes, Commits: 15
# File: machine-learning/app/test_main.py, Size: 183 bytes, Commits: 19
# File: machine-learning/locustfile.py, Size: 52 bytes, Commits: 5
# File: machine-learning/responses.json, Size: 1570 bytes, Commits: 3
# File: mobile/openapi/lib/api_client.dart, Size: 327 bytes, Commits: 123
# File: mobile/openapi/lib/api_helper.dart, Size: 110 bytes, Commits: 42
# File: mobile/openapi/lib/model/clip_config.dart, Size: 140 bytes, Commits: 4
# File: mobile/openapi/lib/model/clip_mode.dart, Size: 85 bytes, Commits: 4
# File: mobile/openapi/lib/model/model_type.dart, Size: 88 bytes, Commits: 5
# File: mobile/openapi/lib/model/system_config_machine_learning_dto.dart, Size: 130 bytes, Commits: 7
# File: server/src/interfaces/search.interface.ts, Size: 0 bytes, Commits: 8
# File: server/src/services/smart-info.service.spec.ts, Size: 2 bytes, Commits: 10
# File: web/src/lib/components/photos-page/asset-grid.svelte, Size: 119 bytes, Commits: 79
# File: server/src/middleware/error.interceptor.ts, Size: 0 bytes, Commits: 5
# File: server/src/middleware/http-exception.filter.ts, Size: 37 bytes, Commits: 2
# File: server/src/utils/file.ts, Size: 25 bytes, Commits: 4
# File: e2e/docker-compose.yml, Size: 5 bytes, Commits: 16
# File: server/src/main.ts, Size: 11 bytes, Commits: 25
# File: e2e/src/responses.ts, Size: 103 bytes, Commits: 6
# File: server/src/app.module.ts, Size: 49 bytes, Commits: 21
# File: server/src/dtos/auth.dto.ts, Size: 0 bytes, Commits: 6
# File: server/src/middleware/logging.interceptor.ts, Size: 28 bytes, Commits: 2
# File: server/src/repositories/logger.repository.ts, Size: 27 bytes, Commits: 6
# File: server/src/middleware/asset-upload.interceptor.ts, Size: 25 bytes, Commits: 3
# File: web/src/lib/i18n/en-US.json, Size: 780 bytes, Commits: 2
# File: .dockerignore, Size: 20 bytes, Commits: 7
# File: server/src/services/system-config.service.spec.ts, Size: 2 bytes, Commits: 18
# File: server/start.sh, Size: 5 bytes, Commits: 10
# File: mobile/openapi/lib/model/asset_response_dto.dart, Size: 265 bytes, Commits: 50
# File: web/src/lib/components/asset-viewer/detail-panel.svelte, Size: 164 bytes, Commits: 114
# File: web/src/lib/components/faces-page/assign-face-side-panel.svelte, Size: 246 bytes, Commits: 16
# File: web/src/lib/utils/people-utils.ts, Size: 71 bytes, Commits: 2
# File: cli/Dockerfile, Size: 19 bytes, Commits: 22
# File: web/src/lib/components/admin-page/restore-dialogue.svelte, Size: 3 bytes, Commits: 5
# File: web/src/lib/components/admin-page/settings/auth/auth-settings.svelte, Size: 242 bytes, Commits: 4
# File: web/src/lib/components/admin-page/settings/image/image-settings.svelte, Size: 28 bytes, Commits: 8
# File: web/src/lib/components/admin-page/settings/logging-settings/logging-settings.svelte, Size: 110 bytes, Commits: 10
# File: web/src/lib/components/admin-page/settings/machine-learning-settings/machine-learning-settings.svelte, Size: 104 bytes, Commits: 23
# File: web/src/lib/components/admin-page/settings/map-settings/map-settings.svelte, Size: 98 bytes, Commits: 16
# File: web/src/lib/components/admin-page/settings/new-version-check-settings/new-version-check-settings.svelte, Size: 92 bytes, Commits: 13
# File: web/src/lib/components/admin-page/settings/server/server-settings.svelte, Size: 107 bytes, Commits: 7
# File: web/src/lib/components/admin-page/settings/storage-template/supported-datetime-panel.svelte, Size: 0 bytes, Commits: 9
# File: web/src/lib/components/admin-page/settings/storage-template/supported-variables-panel.svelte, Size: 0 bytes, Commits: 6
# File: web/src/lib/components/admin-page/settings/theme/theme-settings.svelte, Size: 98 bytes, Commits: 8
# File: web/src/lib/components/admin-page/settings/trash-settings/trash-settings.svelte, Size: 107 bytes, Commits: 12
# File: web/src/lib/components/admin-page/settings/user-settings/user-settings.svelte, Size: 45 bytes, Commits: 3
# File: web/src/lib/components/album-page/album-card.svelte, Size: 0 bytes, Commits: 59
# File: web/src/lib/components/album-page/album-cover.svelte, Size: 36 bytes, Commits: 3
# File: web/src/lib/components/album-page/album-description.svelte, Size: 45 bytes, Commits: 7
# File: web/src/lib/components/album-page/album-options.svelte, Size: 76 bytes, Commits: 14
# File: web/src/lib/components/album-page/album-title.svelte, Size: 42 bytes, Commits: 4
# File: web/src/lib/components/album-page/album-viewer.svelte, Size: 12 bytes, Commits: 95
# File: web/src/lib/components/album-page/albums-controls.svelte, Size: 68 bytes, Commits: 6
# File: web/src/lib/components/album-page/albums-table-row.svelte, Size: 64 bytes, Commits: 2
# File: web/src/lib/components/album-page/share-info-modal.svelte, Size: 98 bytes, Commits: 35
# File: web/src/lib/components/album-page/thumbnail-selection.svelte, Size: 54 bytes, Commits: 16
# File: web/src/lib/components/album-page/user-selection-modal.svelte, Size: 117 bytes, Commits: 39
# File: web/src/lib/components/asset-viewer/activity-status.svelte, Size: 33 bytes, Commits: 7
# File: web/src/lib/components/asset-viewer/activity-viewer.svelte, Size: 289 bytes, Commits: 28
# File: web/src/lib/components/asset-viewer/detail-panel-description.svelte, Size: 62 bytes, Commits: 3
# File: web/src/lib/components/asset-viewer/detail-panel-location.svelte, Size: 87 bytes, Commits: 2
# File: web/src/lib/components/asset-viewer/download-panel.svelte, Size: 26 bytes, Commits: 11
# File: web/src/lib/components/asset-viewer/slideshow-bar.svelte, Size: 78 bytes, Commits: 6
# File: web/src/lib/components/asset-viewer/video-native-viewer.svelte, Size: 0 bytes, Commits: 6
# File: web/src/lib/components/elements/search-bar.svelte, Size: 9 bytes, Commits: 8
# File: web/src/lib/components/faces-page/edit-name-input.svelte, Size: 42 bytes, Commits: 13
# File: web/src/lib/components/faces-page/people-card.svelte, Size: 64 bytes, Commits: 24
# File: web/src/lib/components/faces-page/people-list.svelte, Size: 106 bytes, Commits: 10
# File: web/src/lib/components/faces-page/people-search.svelte, Size: 100 bytes, Commits: 3
# File: web/src/lib/components/faces-page/set-birth-date-modal.svelte, Size: 43 bytes, Commits: 9
# File: web/src/lib/components/forms/api-key-form.svelte, Size: 57 bytes, Commits: 16
# File: web/src/lib/components/forms/api-key-secret.svelte, Size: 69 bytes, Commits: 16
# File: web/src/lib/components/forms/change-password-form.svelte, Size: 97 bytes, Commits: 23
# File: web/src/lib/components/forms/edit-album-form.svelte, Size: 59 bytes, Commits: 10
# File: web/src/lib/components/forms/library-rename-form.svelte, Size: 27 bytes, Commits: 4
# File: web/src/lib/components/forms/login-form.svelte, Size: 73 bytes, Commits: 39
# File: web/src/lib/components/map-page/map-settings-modal.svelte, Size: 40 bytes, Commits: 18
# File: web/src/lib/components/memory-page/memory-viewer.svelte, Size: 354 bytes, Commits: 39
# File: web/src/lib/components/onboarding-page/onboarding-hello.svelte, Size: 28 bytes, Commits: 3
# File: web/src/lib/components/onboarding-page/onboarding-theme.svelte, Size: 60 bytes, Commits: 6
# File: web/src/lib/components/photos-page/actions/add-to-album.svelte, Size: 0 bytes, Commits: 17
# File: web/src/lib/components/photos-page/actions/asset-job-actions.svelte, Size: 37 bytes, Commits: 7
# File: web/src/lib/components/photos-page/actions/change-date-action.svelte, Size: 39 bytes, Commits: 5
# File: web/src/lib/components/photos-page/actions/change-location-action.svelte, Size: 42 bytes, Commits: 5
# File: web/src/lib/components/photos-page/actions/create-shared-link.svelte, Size: 23 bytes, Commits: 11
# File: web/src/lib/components/photos-page/actions/download-action.svelte, Size: 8 bytes, Commits: 9
# File: web/src/lib/components/photos-page/actions/remove-from-album.svelte, Size: 35 bytes, Commits: 17
# File: web/src/lib/components/photos-page/actions/remove-from-shared-link.svelte, Size: 34 bytes, Commits: 14
# File: web/src/lib/components/photos-page/actions/restore-assets.svelte, Size: 43 bytes, Commits: 7
# File: web/src/lib/components/photos-page/actions/select-all-assets.svelte, Size: 41 bytes, Commits: 14
# File: web/src/lib/components/photos-page/delete-asset-dialog.svelte, Size: 57 bytes, Commits: 8
# File: web/src/lib/components/share-page/individual-shared-viewer.svelte, Size: 150 bytes, Commits: 40
# File: web/src/lib/components/shared-components/album-selection-modal.svelte, Size: 4 bytes, Commits: 26
# File: web/src/lib/components/shared-components/change-date.svelte, Size: 128 bytes, Commits: 16
# File: web/src/lib/components/shared-components/change-location.svelte, Size: 60 bytes, Commits: 18
# File: web/src/lib/components/shared-components/combobox.svelte, Size: 83 bytes, Commits: 16
# File: web/src/lib/components/shared-components/control-app-bar.svelte, Size: 0 bytes, Commits: 22
# File: web/src/lib/components/shared-components/create-share-link-modal/create-shared-link-modal.svelte, Size: 243 bytes, Commits: 40
# File: web/src/lib/components/shared-components/dialog/confirm-dialog.svelte, Size: 12 bytes, Commits: 3
# File: web/src/lib/components/shared-components/immich-logo.svelte, Size: 7 bytes, Commits: 6
# File: web/src/lib/components/shared-components/map/map.svelte, Size: 146 bytes, Commits: 25
# File: web/src/lib/components/shared-components/modal-header.svelte, Size: 40 bytes, Commits: 3
# File: web/src/lib/components/shared-components/navigation-bar/avatar-selector.svelte, Size: 39 bytes, Commits: 10
# File: web/src/lib/components/shared-components/notification/notification-card.svelte, Size: 70 bytes, Commits: 22
# File: web/src/lib/components/shared-components/password-field.svelte, Size: 50 bytes, Commits: 2
# File: web/src/lib/components/shared-components/profile-image-cropper.svelte, Size: 85 bytes, Commits: 15
# File: web/src/lib/components/shared-components/search-bar/search-bar.svelte, Size: 59 bytes, Commits: 37
# File: web/src/lib/components/shared-components/search-bar/search-camera-section.svelte, Size: 63 bytes, Commits: 5
# File: web/src/lib/components/shared-components/search-bar/search-date-section.svelte, Size: 37 bytes, Commits: 3
# File: web/src/lib/components/shared-components/search-bar/search-display-section.svelte, Size: 32 bytes, Commits: 3
# File: web/src/lib/components/shared-components/search-bar/search-filter-box.svelte, Size: 198 bytes, Commits: 19
# File: web/src/lib/components/shared-components/search-bar/search-history-box.svelte, Size: 62 bytes, Commits: 3
# File: web/src/lib/components/shared-components/search-bar/search-location-section.svelte, Size: 96 bytes, Commits: 5
# File: web/src/lib/components/shared-components/search-bar/search-media-section.svelte, Size: 47 bytes, Commits: 3
# File: web/src/lib/components/shared-components/search-bar/search-people-section.svelte, Size: 95 bytes, Commits: 8
# File: web/src/lib/components/shared-components/search-bar/search-text-section.svelte, Size: 57 bytes, Commits: 3
# File: web/src/lib/components/shared-components/settings/setting-buttons-row.svelte, Size: 0 bytes, Commits: 4
# File: web/src/lib/components/shared-components/show-shortcuts.svelte, Size: 79 bytes, Commits: 13
# File: web/src/lib/components/shared-components/side-bar/admin-side-bar.svelte, Size: 33 bytes, Commits: 7
# File: web/src/lib/components/shared-components/side-bar/side-bar.svelte, Size: 32 bytes, Commits: 53
# File: web/src/lib/components/shared-components/theme-button.svelte, Size: 77 bytes, Commits: 11
# File: web/src/lib/components/shared-components/upload-asset-preview.svelte, Size: 69 bytes, Commits: 20
# File: web/src/lib/components/shared-components/upload-panel.svelte, Size: 0 bytes, Commits: 27
# File: web/src/lib/components/shared-components/version-announcement-box.svelte, Size: 82 bytes, Commits: 17
# File: web/src/lib/components/sharedlinks-page/shared-link-card.svelte, Size: 142 bytes, Commits: 31
# File: web/src/lib/components/user-settings-page/device-card.svelte, Size: 72 bytes, Commits: 16
# File: web/src/lib/components/user-settings-page/device-list.svelte, Size: 71 bytes, Commits: 15
# File: web/src/lib/components/user-settings-page/memories-settings.svelte, Size: 49 bytes, Commits: 10
# File: web/src/lib/components/user-settings-page/partner-selection-modal.svelte, Size: 85 bytes, Commits: 22
# File: web/src/lib/components/user-settings-page/user-profile-settings.svelte, Size: 81 bytes, Commits: 18
# File: web/src/lib/components/utilities-page/utilities-menu.svelte, Size: 18 bytes, Commits: 3
# File: web/src/routes/(user)/albums/+page.svelte, Size: 0 bytes, Commits: 48
# File: web/src/routes/(user)/archive/[[photos=photos]]/[[assetId=id]]/+page.svelte, Size: 0 bytes, Commits: 2
# File: web/src/routes/(user)/favorites/[[photos=photos]]/[[assetId=id]]/+page.svelte, Size: 0 bytes, Commits: 2
# File: web/src/routes/(user)/partners/[userId]/[[photos=photos]]/[[assetId=id]]/+page.svelte, Size: 0 bytes, Commits: 2
# File: web/src/routes/(user)/photos/[[assetId=id]]/+page.svelte, Size: 0 bytes, Commits: 4
# File: web/src/routes/(user)/search/[[photos=photos]]/[[assetId=id]]/+page.svelte, Size: 6 bytes, Commits: 4
# File: web/src/routes/(user)/share/[key]/[[photos=photos]]/[[assetId=id]]/+page.svelte, Size: 0 bytes, Commits: 3
# File: web/src/routes/(user)/sharing/+page.svelte, Size: 0 bytes, Commits: 32
# File: web/src/routes/(user)/user-settings/+page.svelte, Size: 0 bytes, Commits: 12
# File: web/src/routes/+error.svelte, Size: 29 bytes, Commits: 17
# File: web/src/routes/+layout.svelte, Size: 16 bytes, Commits: 47
# File: web/src/routes/+page.svelte, Size: 29 bytes, Commits: 14
# File: .github/workflows/docker-cleanup.yml, Size: 77 bytes, Commits: 10
# File: cli/.nvmrc, Size: 1 bytes, Commits: 3
# File: docs/.nvmrc, Size: 1 bytes, Commits: 3
# File: docs/package.json, Size: 0 bytes, Commits: 20
# File: e2e/.nvmrc, Size: 1 bytes, Commits: 3
# File: server/.nvmrc, Size: 1 bytes, Commits: 3
# File: web/.nvmrc, Size: 1 bytes, Commits: 3
# File: machine-learning/export/Dockerfile, Size: 21 bytes, Commits: 22
# File: e2e/src/api/specs/user-admin.e2e-spec.ts, Size: 317 bytes, Commits: 3
# File: mobile/openapi/lib/model/email_notifications_response.dart, Size: 114 bytes, Commits: 1
# File: mobile/openapi/lib/model/email_notifications_update.dart, Size: 141 bytes, Commits: 1
# File: mobile/openapi/lib/model/user_preferences_response_dto.dart, Size: 106 bytes, Commits: 2
# File: mobile/openapi/lib/model/user_preferences_update_dto.dart, Size: 124 bytes, Commits: 2
# File: server/src/dtos/user-preferences.dto.ts, Size: 47 bytes, Commits: 2
# File: server/src/entities/user-metadata.entity.ts, Size: 63 bytes, Commits: 2
# File: docs/docs/administration/img/authentik-redirect-uris-example.webp, Size: 0 bytes, Commits: 1
# File: docs/docs/administration/img/google-redirect-uris-example.webp, Size: 0 bytes, Commits: 1
# File: docs/docs/administration/img/immich-google-example.webp, Size: 0 bytes, Commits: 2
# File: docs/docs/administration/img/oauth-settings.png, Size: 0 bytes, Commits: 2
# File: docs/docs/administration/oauth.md, Size: 0 bytes, Commits: 8
# File: docs/src/css/custom.css, Size: 0 bytes, Commits: 9
# File: deployment/modules/cloudflare/docs-release/.terraform.lock.hcl, Size: 25 bytes, Commits: 2
# File: deployment/modules/cloudflare/docs-release/config.tf, Size: 11 bytes, Commits: 2
# File: deployment/modules/cloudflare/docs/.terraform.lock.hcl, Size: 25 bytes, Commits: 2
# File: deployment/modules/cloudflare/docs/config.tf, Size: 11 bytes, Commits: 2
# File: web/src/lib/components/shared-components/full-screen-modal.svelte, Size: 0 bytes, Commits: 23
# File: web/src/lib/components/shared-components/settings/setting-switch.svelte, Size: 1 bytes, Commits: 6
# File: web/src/lib/stores/unique-id.store.spec.ts, Size: 14 bytes, Commits: 2
# File: web/src/lib/stores/unique-id.store.ts, Size: 16 bytes, Commits: 2
# File: web/src/lib/utils/generate-id.ts, Size: 2 bytes, Commits: 1
# File: web/src/lib/actions/click-outside.ts, Size: 2 bytes, Commits: 2
# File: web/src/lib/components/elements/dropdown.svelte, Size: 62 bytes, Commits: 18
# File: web/src/lib/components/photos-page/asset-select-context-menu.svelte, Size: 35 bytes, Commits: 9
# File: web/src/lib/components/shared-components/context-menu/context-menu.svelte, Size: 33 bytes, Commits: 18
# File: web/src/lib/components/shared-components/context-menu/right-click-context-menu.svelte, Size: 64 bytes, Commits: 2
# File: web/src/lib/components/shared-components/settings/setting-combobox.svelte, Size: 42 bytes, Commits: 3
# File: web/src/lib/components/shared-components/autogrow-textarea.spec.ts, Size: 60 bytes, Commits: 1
# File: web/src/lib/components/shared-components/autogrow-textarea.svelte, Size: 39 bytes, Commits: 1
# File: docs/src/components/timeline.tsx, Size: 86 bytes, Commits: 5
# File: cli/src/commands/asset.ts, Size: 48 bytes, Commits: 8
# File: docs/docs/guides/python-file-upload.md, Size: 42 bytes, Commits: 2
# File: e2e/src/api/specs/activity.e2e-spec.ts, Size: 293 bytes, Commits: 8
# File: e2e/src/api/specs/album.e2e-spec.ts, Size: 461 bytes, Commits: 16
# File: e2e/src/api/specs/download.e2e-spec.ts, Size: 62 bytes, Commits: 7
# File: e2e/src/api/specs/map.e2e-spec.ts, Size: 162 bytes, Commits: 2
# File: e2e/src/api/specs/memory.e2e-spec.ts, Size: 376 bytes, Commits: 2
# File: e2e/src/api/specs/search.e2e-spec.ts, Size: 224 bytes, Commits: 9
# File: e2e/src/api/specs/shared-link.e2e-spec.ts, Size: 320 bytes, Commits: 11
# File: e2e/src/api/specs/timeline.e2e-spec.ts, Size: 193 bytes, Commits: 3
# File: e2e/src/web/specs/asset-viewer/detail-panel.e2e-spec.ts, Size: 46 bytes, Commits: 3
# File: e2e/src/web/specs/asset-viewer/navbar.e2e-spec.ts, Size: 52 bytes, Commits: 2
# File: e2e/src/web/specs/shared-link.e2e-spec.ts, Size: 58 bytes, Commits: 7
# File: mobile/lib/pages/common/gallery_viewer.page.dart, Size: 2 bytes, Commits: 5
# File: mobile/lib/providers/image/immich_remote_image_provider.dart, Size: 6 bytes, Commits: 2
# File: mobile/lib/providers/image/immich_remote_thumbnail_provider.dart, Size: 4 bytes, Commits: 2
# File: mobile/lib/services/backup.service.dart, Size: 10 bytes, Commits: 3
# File: mobile/lib/services/backup_verification.service.dart, Size: 4 bytes, Commits: 3
# File: mobile/lib/services/image_viewer.service.dart, Size: 4 bytes, Commits: 2
# File: mobile/lib/services/share.service.dart, Size: 2 bytes, Commits: 2
# File: mobile/lib/utils/hooks/chewiew_controller_hook.dart, Size: 0 bytes, Commits: 3
# File: mobile/lib/widgets/album/album_thumbnail_listtile.dart, Size: 0 bytes, Commits: 2
# File: mobile/lib/widgets/search/curated_places_row.dart, Size: 6 bytes, Commits: 2
# File: mobile/lib/widgets/search/curated_row.dart, Size: 2 bytes, Commits: 2
# File: mobile/lib/widgets/search/explore_grid.dart, Size: 2 bytes, Commits: 2
# File: mobile/openapi/lib/api/assets_api.dart, Size: 4 bytes, Commits: 2
# File: mobile/openapi/lib/api/download_api.dart, Size: 184 bytes, Commits: 3
# File: mobile/openapi/lib/model/asset_file_upload_response_dto.dart, Size: 111 bytes, Commits: 12
# File: mobile/openapi/lib/model/asset_media_size.dart, Size: 48 bytes, Commits: 1
# File: mobile/openapi/lib/model/asset_media_status.dart, Size: 85 bytes, Commits: 2
# File: mobile/pubspec.lock, Size: 845 bytes, Commits: 103
# File: open-api/typescript-sdk/src/index.ts, Size: 0 bytes, Commits: 5
# File: server/src/controllers/asset-media.controller.ts, Size: 56 bytes, Commits: 4
# File: server/src/controllers/asset-v1.controller.ts, Size: 52 bytes, Commits: 9
# File: server/src/controllers/download.controller.ts, Size: 2 bytes, Commits: 7
# File: server/src/dtos/asset-media-response.dto.ts, Size: 11 bytes, Commits: 3
# File: server/src/dtos/asset-media.dto.ts, Size: 35 bytes, Commits: 3
# File: server/src/dtos/asset-v1-response.dto.ts, Size: 45 bytes, Commits: 4
# File: server/src/dtos/asset-v1.dto.ts, Size: 154 bytes, Commits: 6
# File: server/src/dtos/asset.dto.ts, Size: 132 bytes, Commits: 4
# File: server/src/dtos/user-profile.dto.ts, Size: 28 bytes, Commits: 3
# File: server/src/interfaces/asset-v1.interface.ts, Size: 25 bytes, Commits: 4
# File: server/src/middleware/file-upload.interceptor.ts, Size: 2 bytes, Commits: 8
# File: server/src/repositories/asset-v1.repository.ts, Size: 35 bytes, Commits: 5
# File: server/src/repositories/index.ts, Size: 90 bytes, Commits: 9
# File: server/src/services/asset-media.service.spec.ts, Size: 280 bytes, Commits: 3
# File: server/src/services/asset-v1.service.spec.ts, Size: 12 bytes, Commits: 8
# File: server/src/services/asset-v1.service.ts, Size: 38 bytes, Commits: 11
# File: server/src/services/download.service.spec.ts, Size: 2 bytes, Commits: 6
# File: server/src/services/download.service.ts, Size: 0 bytes, Commits: 4
# File: server/src/services/index.ts, Size: 59 bytes, Commits: 13
# File: server/src/services/shared-link.service.spec.ts, Size: 2 bytes, Commits: 4
# File: server/src/services/shared-link.service.ts, Size: 0 bytes, Commits: 5
# File: web/src/lib/components/asset-viewer/album-list-item.svelte, Size: 39 bytes, Commits: 21
# File: web/src/lib/components/asset-viewer/panorama-viewer.svelte, Size: 40 bytes, Commits: 13
# File: web/src/lib/components/photos-page/memory-lane.svelte, Size: 94 bytes, Commits: 21
# File: web/src/routes/(user)/share/[key]/[[photos=photos]]/[[assetId=id]]/+page.ts, Size: 4 bytes, Commits: 2
# File: docs/static/_redirects, Size: 1 bytes, Commits: 6
# File: docs/docs/FAQ.mdx, Size: 311 bytes, Commits: 19
# File: docs/docs/administration/jobs-workers.md, Size: 55 bytes, Commits: 1
# File: docs/docs/administration/jobs.md, Size: 2 bytes, Commits: 4
# File: docs/docs/developer/architecture.mdx, Size: 8 bytes, Commits: 4
# File: docs/docs/features/libraries.md, Size: 148 bytes, Commits: 20
# File: docs/docs/guides/custom-locations.md, Size: 50 bytes, Commits: 3
# File: docs/docs/guides/docker-help.md, Size: 23 bytes, Commits: 5
# File: docs/docs/guides/external-library.md, Size: 101 bytes, Commits: 11
# File: docs/docs/guides/remote-machine-learning.md, Size: 2 bytes, Commits: 7
# File: .github/workflows/docs-destroy.yml, Size: 32 bytes, Commits: 1
# File: deployment/modules/cloudflare/docs-release/domain.tf, Size: 8 bytes, Commits: 2
# File: deployment/modules/cloudflare/docs/domain.tf, Size: 18 bytes, Commits: 4
# File: .github/workflows/docs-deploy.yml, Size: 158 bytes, Commits: 4
# File: mobile/lib/providers/authentication.provider.dart, Size: 10 bytes, Commits: 4
# File: mobile/lib/providers/user.provider.dart, Size: 6 bytes, Commits: 4
# ...
# File: fastlane/README.md, Size: 3 bytes, Commits: 1
# File: fastlane/metadata, Size: 1 bytes, Commits: 1
# File: mobile/android/fastlane/metadata/android/en-US/changelogs/6.txt, Size: 1 bytes, Commits: 1
# File: mobile/android/fastlane/metadata/android/en-US/images/featureGraphic.png, Size: 0 bytes, Commits: 1
# File: mobile/android/fastlane/metadata/android/en-US/images/icon.png, Size: 0 bytes, Commits: 1
# File: mobile/android/fastlane/metadata/android/en-US/images/phoneScreenshots/1_en-US.png, Size: 0 bytes, Commits: 1
# File: mobile/android/fastlane/metadata/android/en-US/images/phoneScreenshots/3_en-US.png, Size: 0 bytes, Commits: 1
# File: mobile/android/fastlane/metadata/android/en-US/images/sevenInchScreenshots/1_en-US.png, Size: 0 bytes, Commits: 1
# File: mobile/android/fastlane/metadata/android/en-US/images/sevenInchScreenshots/2_en-US.png, Size: 0 bytes, Commits: 1
# File: mobile/android/fastlane/metadata/android/en-US/images/sevenInchScreenshots/3_en-US.png, Size: 0 bytes, Commits: 1
# File: mobile/android/fastlane/metadata/android/en-US/images/sevenInchScreenshots/4_en-US.png, Size: 0 bytes, Commits: 1
# File: mobile/android/fastlane/metadata/android/en-US/images/sevenInchScreenshots/5_en-US.png, Size: 0 bytes, Commits: 1
# File: mobile/android/fastlane/metadata/android/en-US/images/tenInchScreenshots/1_en-US.png, Size: 0 bytes, Commits: 1
# File: mobile/android/fastlane/metadata/android/en-US/images/tenInchScreenshots/2_en-US.png, Size: 0 bytes, Commits: 1
# File: mobile/android/fastlane/metadata/android/en-US/images/tenInchScreenshots/3_en-US.png, Size: 0 bytes, Commits: 1
# File: mobile/android/fastlane/metadata/android/en-US/images/tenInchScreenshots/4_en-US.png, Size: 0 bytes, Commits: 1
# File: mobile/android/fastlane/metadata/android/en-US/images/tenInchScreenshots/5_en-US.png, Size: 0 bytes, Commits: 1
# File: mobile/android/fastlane/metadata/android/en-US/title.txt, Size: 1 bytes, Commits: 1
# File: mobile/android/fastlane/metadata/android/en-US/video.txt, Size: 0 bytes, Commits: 1
# File: microservices/entrypoint.sh, Size: 2 bytes, Commits: 1
# File: microservices/Dockerfile, Size: 43 bytes, Commits: 2
# File: microservices/src/main.ts, Size: 15 bytes, Commits: 3
# File: microservices/.dockerignore, Size: 4 bytes, Commits: 1
# File: microservices/README.md, Size: 73 bytes, Commits: 2
# File: microservices/package-lock.json, Size: 6506 bytes, Commits: 2
# File: microservices/package.json, Size: 71 bytes, Commits: 2
# File: microservices/src/app.controller.ts, Size: 12 bytes, Commits: 2
# File: microservices/src/app.module.ts, Size: 10 bytes, Commits: 2
# File: microservices/src/app.service.ts, Size: 9 bytes, Commits: 2
# File: microservices/src/image-classifier/image-classifier.module.ts, Size: 9 bytes, Commits: 1
# File: microservices/src/object-detection/object-detection.module.ts, Size: 9 bytes, Commits: 1
# File: microservices/test/app.e2e-spec.ts, Size: 24 bytes, Commits: 2
# File: mobile/lib/utils/capitalize_first_letter.dart, Size: 5 bytes, Commits: 1
# File: server/src/api-v1/asset/entities/smart-info.entity.ts, Size: 19 bytes, Commits: 2
# File: microservices/.eslintrc.js, Size: 24 bytes, Commits: 1
# File: microservices/.gitignore, Size: 35 bytes, Commits: 1
# File: microservices/.prettierrc, Size: 4 bytes, Commits: 1
# File: microservices/nest-cli.json, Size: 4 bytes, Commits: 1
# File: microservices/test/jest-e2e.json, Size: 9 bytes, Commits: 1
# File: microservices/tsconfig.build.json, Size: 4 bytes, Commits: 1
# File: microservices/tsconfig.json, Size: 21 bytes, Commits: 1
# File: nest_microservices, Size: 1 bytes, Commits: 2
# File: server/src/api-v1/server-info/server-info.controller.ts, Size: 19 bytes, Commits: 4
# File: server/src/api-v1/server-info/server-info.service.ts, Size: 54 bytes, Commits: 2
# File: .DS_Store, Size: 0 bytes, Commits: 4
# File: mobile/ios/Gemfile, Size: 3 bytes, Commits: 3
# File: .github/workflows/build_push_server.yml, Size: 2 bytes, Commits: 2
# File: mobile/lib/modules/search/models/store_model_here.txt, Size: 0 bytes, Commits: 3
# File: mobile/test/widget_test.dart, Size: 30 bytes, Commits: 2
# File: mobile/ios/Runner/RunnerProfile.entitlements, Size: 5 bytes, Commits: 2
# File: .github/workflows/build_apk.yml, Size: 29 bytes, Commits: 11
# File: mobile/android/Gemfile, Size: 3 bytes, Commits: 1
# File: mobile/android/app/src/debug/AndroidManifest.xml, Size: 7 bytes, Commits: 2
# File: mobile/android/app/src/profile/AndroidManifest.xml, Size: 7 bytes, Commits: 2
# File: mobile/android/metadata/en-US/images/featureGraphic.png, Size: 0 bytes, Commits: 1
# File: mobile/android/metadata/en-US/images/icon.png, Size: 0 bytes, Commits: 1
# File: mobile/android/metadata/en-US/images/phoneScreenshots/1_en-US.png, Size: 0 bytes, Commits: 1
# File: mobile/android/metadata/en-US/images/phoneScreenshots/2_en-US.png, Size: 0 bytes, Commits: 1
# File: mobile/android/metadata/en-US/images/sevenInchScreenshots/1_en-US.png, Size: 0 bytes, Commits: 1
# File: mobile/android/metadata/en-US/images/sevenInchScreenshots/2_en-US.png, Size: 0 bytes, Commits: 1
# File: mobile/android/metadata/en-US/images/sevenInchScreenshots/3_en-US.png, Size: 0 bytes, Commits: 1
# File: mobile/android/metadata/en-US/images/sevenInchScreenshots/4_en-US.png, Size: 0 bytes, Commits: 1
# File: mobile/android/metadata/en-US/images/sevenInchScreenshots/5_en-US.png, Size: 0 bytes, Commits: 1
# File: mobile/android/metadata/en-US/images/tenInchScreenshots/1_en-US.png, Size: 0 bytes, Commits: 1
# File: mobile/android/metadata/en-US/images/tenInchScreenshots/2_en-US.png, Size: 0 bytes, Commits: 1
# File: mobile/android/metadata/en-US/images/tenInchScreenshots/3_en-US.png, Size: 0 bytes, Commits: 1
# File: mobile/android/metadata/en-US/images/tenInchScreenshots/4_en-US.png, Size: 0 bytes, Commits: 1
# File: mobile/android/metadata/en-US/images/tenInchScreenshots/5_en-US.png, Size: 0 bytes, Commits: 1
# File: mobile/android/metadata/en-US/short_description.txt, Size: 1 bytes, Commits: 1
# File: mobile/android/metadata/en-US/title.txt, Size: 1 bytes, Commits: 1
# File: mobile/android/metadata/en-US/video.txt, Size: 0 bytes, Commits: 1
# File: design/sc-multiselect.png, Size: 0 bytes, Commits: 2
# File: design/sc1.PNG, Size: 0 bytes, Commits: 2
# File: design/sc2.PNG, Size: 0 bytes, Commits: 3
# File: design/sc3.PNG, Size: 0 bytes, Commits: 2
# File: design/sc4.PNG, Size: 0 bytes, Commits: 2
# File: design/sc6.png, Size: 0 bytes, Commits: 1
# File: .github/workflows/Build+push Immich.yml, Size: 46 bytes, Commits: 8
# File: design/.DS_Store, Size: 0 bytes, Commits: 1
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/Icon-App-20x20@1x.png, Size: 0 bytes, Commits: 3
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/Icon-App-20x20@2x.png, Size: 0 bytes, Commits: 3
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/Icon-App-29x29@1x.png, Size: 0 bytes, Commits: 3
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/Icon-App-29x29@2x.png, Size: 0 bytes, Commits: 3
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/Icon-App-40x40@1x.png, Size: 0 bytes, Commits: 3
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/Icon-App-40x40@2x.png, Size: 0 bytes, Commits: 3
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/Icon-App-76x76@1x.png, Size: 0 bytes, Commits: 3
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/Icon-App-76x76@2x.png, Size: 0 bytes, Commits: 3
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/Icon-App-83.5x83.5@2x.png, Size: 0 bytes, Commits: 3
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/immich-logo-1024-1024.png, Size: 0 bytes, Commits: 2
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/immich-logo-1024-20.png, Size: 0 bytes, Commits: 2
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/immich-logo-1024-20@2x.png, Size: 0 bytes, Commits: 2
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/immich-logo-1024-20@3x.png, Size: 0 bytes, Commits: 2
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/immich-logo-1024-29.png, Size: 0 bytes, Commits: 2
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/immich-logo-1024-29@2x.png, Size: 0 bytes, Commits: 2
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/immich-logo-1024-29@3x.png, Size: 0 bytes, Commits: 2
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/immich-logo-1024-40.png, Size: 0 bytes, Commits: 2
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/immich-logo-1024-40@2x.png, Size: 0 bytes, Commits: 2
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/immich-logo-1024-40@3x.png, Size: 0 bytes, Commits: 2
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/immich-logo-1024-60@2x.png, Size: 0 bytes, Commits: 2
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/immich-logo-1024-60@3x.png, Size: 0 bytes, Commits: 2
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/immich-logo-1024-76.png, Size: 0 bytes, Commits: 2
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/immich-logo-1024-76@2x.png, Size: 0 bytes, Commits: 2
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/immich-logo-1024-83.5@2x.png, Size: 0 bytes, Commits: 2
# File: mobile/ios/fastlane/Appfile, Size: 6 bytes, Commits: 1
# File: mobile/android/gradle.properties, Size: 3 bytes, Commits: 2
# File: server/src/api-v1/asset/entities/exif.entity.ts, Size: 67 bytes, Commits: 2
# File: server/src/migration/1646710459852-AddLocationToExifTextSearch.ts, Size: 37 bytes, Commits: 1
# File: mobile/lib/modules/search/providers/search_result_page_state.provider.dart, Size: 111 bytes, Commits: 1
# File: mobile/lib/modules/search/services/store_services_here.txt, Size: 0 bytes, Commits: 2
# File: server/src/api-v1/asset/dto/search-asset.dto.ts, Size: 6 bytes, Commits: 1
# File: server/src/migration/1646249209023-AddExifTextSearchColumn.ts, Size: 25 bytes, Commits: 1
# File: server/src/migration/1646249734844-CreateExifTextSearchIndex.ts, Size: 17 bytes, Commits: 1
# File: machine_learning/Pipfile, Size: 17 bytes, Commits: 2
# File: machine_learning/Pipfile.lock, Size: 629 bytes, Commits: 2
# File: design/sc2.png, Size: 0 bytes, Commits: 1
# File: docker/.gitignore, Size: 1 bytes, Commits: 1
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/Icon-App-20x20@3x.png, Size: 0 bytes, Commits: 3
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/Icon-App-29x29@3x.png, Size: 0 bytes, Commits: 3
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/Icon-App-40x40@3x.png, Size: 0 bytes, Commits: 3
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/Icon-App-60x60@2x.png, Size: 0 bytes, Commits: 3
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/Icon-App-60x60@3x.png, Size: 0 bytes, Commits: 3
# File: server/src/migration/1645130759468-CreateUserTable.ts, Size: 22 bytes, Commits: 1
# File: server/src/migration/1645130777674-CreateDeviceInfoTable.ts, Size: 26 bytes, Commits: 1
# File: server/src/migration/1645130805273-CreateAssetsTable.ts, Size: 31 bytes, Commits: 1
# File: server/src/migration/1645130817965-CreateExifTable.ts, Size: 42 bytes, Commits: 1
# File: server/src/migration/1645130870184-CreateSmartInfoTable.ts, Size: 30 bytes, Commits: 1
# File: mobile/lib/modules/home/providers/asset.provider.dart, Size: 60 bytes, Commits: 5
# File: server/docker-compose.yml, Size: 54 bytes, Commits: 7
# File: server/src/api-v1/communication/communication.gateway.ts, Size: 47 bytes, Commits: 1
# File: server/src/api-v1/communication/communication.module.ts, Size: 16 bytes, Commits: 1
# File: server/src/api-v1/communication/communication.service.ts, Size: 4 bytes, Commits: 1
# File: server/src/modules/immich-jwt/immich-jwt.service.ts, Size: 14 bytes, Commits: 2
# File: server/src/api-v1/asset/dto/delete-asset.dto.ts, Size: 6 bytes, Commits: 1
# File: server/.env.example, Size: 14 bytes, Commits: 3
# File: server/src/constants/upload_location.constant.ts, Size: 1 bytes, Commits: 1
# File: mobile/lib/shared/views/image_viewer_page.dart, Size: 64 bytes, Commits: 2
# File: server/src/api-v1/asset/dto/create-exif.dto.ts, Size: 48 bytes, Commits: 1
# File: server/src/api-v1/asset/dto/update-exif.dto.ts, Size: 4 bytes, Commits: 1
# File: server/src/modules/image-optimize/machine-learning.processor.ts, Size: 39 bytes, Commits: 4
# File: design/sc5.PNG, Size: 0 bytes, Commits: 1
# File: design/gif/progress-02082022.gif, Size: 0 bytes, Commits: 2
# File: server/Dockerfile-minimal, Size: 40 bytes, Commits: 5
# File: server/yarn.lock, Size: 6625 bytes, Commits: 4
# File: mobile/lib/shared/views/video_viewer_page.dart, Size: 105 bytes, Commits: 2
# File: server/src/api-v1/asset/dto/get-asset.dto.ts, Size: 6 bytes, Commits: 2
# File: server/src/api-v1/asset/dto/get-new-asset-query.dto.ts, Size: 6 bytes, Commits: 1
# File: .github/dependabot.yml, Size: 7 bytes, Commits: 1
# File: binary/immich-release-02062022.apk, Size: 0 bytes, Commits: 2
# File: server/src/api-v1/asset/dto/create-asset.dto.ts, Size: 31 bytes, Commits: 2
# File: mobile/ios/Runner/Assets.xcassets/AppIcon.appiconset/Icon-App-1024x1024@1x.png, Size: 0 bytes, Commits: 2
# File: mobile/ios/Flutter/Debug.xcconfig, Size: 2 bytes, Commits: 1
# File: mobile/ios/Flutter/Release.xcconfig, Size: 2 bytes, Commits: 1
# File: mobile/ios/Runner.xcodeproj/project.xcworkspace/contents.xcworkspacedata, Size: 7 bytes, Commits: 1
# File: mobile/ios/Runner.xcodeproj/project.xcworkspace/xcshareddata/IDEWorkspaceChecks.plist, Size: 8 bytes, Commits: 1
# File: mobile/ios/Runner.xcodeproj/project.xcworkspace/xcshareddata/WorkspaceSettings.xcsettings, Size: 8 bytes, Commits: 1
# File: mobile/ios/Runner.xcworkspace/contents.xcworkspacedata, Size: 10 bytes, Commits: 1
# File: mobile/ios/Runner.xcworkspace/xcshareddata/IDEWorkspaceChecks.plist, Size: 8 bytes, Commits: 1
# File: mobile/ios/Runner.xcworkspace/xcshareddata/WorkspaceSettings.xcsettings, Size: 8 bytes, Commits: 1
# File: mobile/ios/Runner/Assets.xcassets/LaunchImage.imageset/README.md, Size: 5 bytes, Commits: 1
# File: mobile/ios/Runner/Base.lproj/Main.storyboard, Size: 26 bytes, Commits: 1
# File: mobile/ios/Runner/Runner-Bridging-Header.h, Size: 1 bytes, Commits: 1
# File: mobile/lib/module_template/ui/store_ui_here.txt, Size: 0 bytes, Commits: 1
# File: mobile/lib/modules/home/models/get_all_asset_respose.model.dart, Size: 113 bytes, Commits: 1
# File: server/src/api-v1/asset/dto/get-all-asset-query.dto.ts, Size: 6 bytes, Commits: 1
# File: server/src/api-v1/asset/dto/get-all-asset-response.dto.ts, Size: 7 bytes, Commits: 1
# File: server/src/api-v1/asset/dto/update-asset.dto.ts, Size: 4 bytes, Commits: 1
# File: server/src/api-v1/auth/auth.module.ts, Size: 16 bytes, Commits: 1
# File: server/src/api-v1/auth/dto/jwt-payload.dto.ts, Size: 9 bytes, Commits: 1
# File: server/src/api-v1/auth/dto/login-credential.dto.ts, Size: 9 bytes, Commits: 1
# File: server/src/api-v1/device-info/device-info.controller.ts, Size: 22 bytes, Commits: 1
# File: server/src/api-v1/device-info/device-info.module.ts, Size: 12 bytes, Commits: 1
# File: server/src/api-v1/device-info/device-info.service.ts, Size: 63 bytes, Commits: 1
# File: server/src/api-v1/device-info/dto/create-device-info.dto.ts, Size: 13 bytes, Commits: 1
# File: server/src/api-v1/device-info/dto/update-device-info.dto.ts, Size: 6 bytes, Commits: 1
# File: server/src/api-v1/device-info/entities/device-info.entity.ts, Size: 32 bytes, Commits: 1
# File: server/src/api-v1/server-info/dto/server-info.dto.ts, Size: 9 bytes, Commits: 1
# File: server/src/api-v1/server-info/server-info.module.ts, Size: 9 bytes, Commits: 1
# File: server/src/api-v1/user/dto/update-user.dto.ts, Size: 4 bytes, Commits: 1
# File: server/src/config/jwt.config.ts, Size: 7 bytes, Commits: 1
# File: server/src/constants/jwt.constant.ts, Size: 1 bytes, Commits: 1
# File: server/src/middlewares/app-logger.middleware.ts, Size: 22 bytes, Commits: 1
# File: server/src/modules/immich-jwt/guards/jwt-auth.guard.ts, Size: 5 bytes, Commits: 1
# File: server/src/modules/immich-jwt/immich-jwt.module.ts, Size: 14 bytes, Commits: 1
# File: server/src/modules/immich-jwt/strategies/jwt.strategy.ts, Size: 33 bytes, Commits: 1

# %%
file_data=[]
for file_path, info in file_info.items():
    files = {
        'File path': file_path,
        'Size': info['size'],
        'Commits': info['commits'],
    }
    file_data.append(files)
file_df = pd.DataFrame(file_data)
file_df.to_csv('files.csv', index = False)

# %%
def get_all_files(repo, path=""):
    contents = repo.get_contents(path)
    files = []
    while contents:
        file_content = contents.pop(0)
        if file_content.type == "dir":
            contents.extend(repo.get_contents(file_content.path))
        else:
            files.append(file_content)
    return files

all_files = get_all_files(repo)
file_data = []
for file in all_files:
    file_info = {
        "Path": file.path,
        "Size": file.size
    }
    file_data.append(file_info)
file_df = pd.DataFrame(file_data)
